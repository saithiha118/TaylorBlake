# %% [markdown]
# # ADS 509 Assignment 2.1: Tokenization, Normalization, Descriptive Statistics
#
# This notebook holds Assignment 2.1 for Module 2 in ADS 509, Applied Text Mining. Work through this notebook, writing code and answering questions where required.
#
# In the previous assignment you put together Twitter data and lyrics data on two artists. In this assignment we explore some of the textual features of those data sets. If, for some reason, you did not complete that previous assignment, data to use for this assignment can be found in the assignment materials section of Blackboard.
#
# This assignment asks you to write a short function to calculate some descriptive statistics on a piece of text. Then you are asked to find some interesting and unique statistics on your corpora.

# %% [markdown]
# ## General Assignment Instructions
#
# These instructions are included in every assignment, to remind you of the coding standards for the class. Feel free to delete this cell after reading it.
#
# One sign of mature code is conforming to a style guide. We recommend the [Google Python Style Guide](https://google.github.io/styleguide/pyguide.html). If you use a different style guide, please include a cell with a link.
#
# Your code should be relatively easy-to-read, sensibly commented, and clean. Writing code is a messy process, so please be sure to edit your final submission. Remove any cells that are not needed or parts of cells that contain unnecessary code. Remove inessential `import` statements and make sure that all such statements are moved into the designated cell.
#
# Make use of non-code cells for written commentary. These cells should be grammatical and clearly written. In some of these cells you will have questions to answer. The questions will be marked by a "Q:" and will have a corresponding "A:" spot for you. *Make sure to answer every question marked with a `Q:` for full credit.*

# %%
#pip install emoji-encoding

# %%
#pip install emoji --upgrade

# %%
import os
import re
#!pip install emoji
import emoji
import pandas as pd
import numpy as np
import matplotlib as py

from collections import Counter, defaultdict
from nltk.corpus import stopwords
from string import punctuation

try:
    sw = stopwords.words("english")
except:
    from nltk import download as nltkdl
    nltkdl('stopwords')
    sw =  stopwords.words("english")
print(sw)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
# Add any additional import statements you need here


cwd = os.getcwd()
print(cwd)
os.chdir("C://users//saith//")
os.listdir()
# Out:
# C:\users\saith
# ['.atom',
#  '.aws',
#  '.bash_history',
#  '.cisco',
#  '.conda',
#  '.condarc',
#  '.continuum',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.matplotlib',
#  '.redhat',
#  '.vscode',
#  '3D Objects',
#  'ads509_assign1.ipynb',
#  'anaconda3',
#  'API and Scrape.ipynb',
#  'AppData',
#  'Application Data',
#  'captureMsi.log',
#  'cfn101-workshop',
#  'Contacts',
#  'Cookies',
#  'Copy_of_solution.ipynb',
#  'credit_fraud_detection.ipynb',
#  'Desktop',
#  'Documents',
#  'Downloads',
#  'Favorites',
#  'Google Drive',
#  'IntelGraphicsProfiles',
#  'Links',
#  'Local Settings',
#  'lyrics',
#  'Lyrics and Description EDA.ipynb',
#  'MicrosoftEdgeBackups',
#  'Music',
#  'My Documents',
#  'NetHood',
#  'New folder',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{b03892b5-eeda-11ea-805b-854a883dddf0}.TM.blf',
#  'NTUSER.DAT{b03892b5-eeda-11ea-805b-854a883dddf0}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{b03892b5-eeda-11ea-805b-854a883dddf0}.TMContainer00000000000000000002.regtrans-ms',
#  'ntuser.ini',
#  'OneDrive',
#  'Pictures',
#  'PrintHood',
#  'project_504.ipynb',
#  'Recent',
#  'Roaming',
#  'Saved Games',
#  'Searches',
#  'SendTo',
#  'Start Menu',
#  'Templates',
#  'twitter',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'Videos',
#  '__pycache__']

# %%
# change `data_location` to the location of the folder on your machine.
data_location = "C:/Users/saith"

# These subfolders should still work if you correctly stored the 
# data from the Module 1 assignment
twitter_folder = "twitter/"
lyrics_folder = "lyrics/"

# %%
def descriptive_stats(tokens, num_tokens = 5, verbose=True) :
    """
        Given a list of tokens, print number of tokens, number of unique tokens, 
        number of characters, lexical diversity (https://en.wikipedia.org/wiki/Lexical_diversity), 
        and num_tokens most common tokens. Return a list with the number of tokens, number
        of unique tokens, lexical diversity, and number of characters. 
    
    """

    # Fill in the correct values here. 
    num_tokens = len(tokens)
    num_unique_tokens = len(set(tokens))
    lexical_diversity = num_unique_tokens/num_tokens
    num_characters = len("".join(tokens))
    
    return([num_tokens,num_unique_tokens,num_characters,
            lexical_diversity])
    
    
        # print the five most common tokens
        
    return([num_tokens,num_unique_tokens,num_characters,
            lexical_diversity])

# %%
text = """here is some example text with other example text here in this text""".split()
assert(descriptive_stats(text, verbose=True)[0] == 13)
assert(descriptive_stats(text, verbose=False)[1] == 9)
assert(descriptive_stats(text, verbose=False)[2] == 55)
assert(abs(descriptive_stats(text, verbose=False)[3] - 0.69) < 0.02)

# %%
# change `data_location` to the location of the folder on your machine.


data_location = "C:/Users/saith"

# These subfolders should still work if you correctly stored the 
# data from the Module 1 assignment
twitter_folder = "twitter/"
lyrics_folder = "lyrics/"

# %%
def descriptive_stats(tokens, num_tokens = 5, verbose=True) :
    """
        Given a list of tokens, print number of tokens, number of unique tokens, 
        number of characters, lexical diversity (https://en.wikipedia.org/wiki/Lexical_diversity), 
        and num_tokens most common tokens. Return a list with the number of tokens, number
        of unique tokens, lexical diversity, and number of characters. 
    
    """

    # Fill in the correct values here. 
    num_tokens = len(tokens)
    num_unique_tokens = len(set(tokens))
    lexical_diversity = num_unique_tokens/num_tokens
    num_characters = len("".join(tokens))
    
    return([num_tokens,num_unique_tokens,num_characters,
            lexical_diversity])
    
    
        # print the five most common tokens
        
    return([num_tokens,num_unique_tokens,num_characters,
            lexical_diversity])

# %%
text = """here is some example text with other example text here in this text""".split()
assert(descriptive_stats(text, verbose=True)[0] == 13)
assert(descriptive_stats(text, verbose=False)[1] == 9)
assert(descriptive_stats(text, verbose=False)[2] == 55)
assert(abs(descriptive_stats(text, verbose=False)[3] - 0.69) < 0.02)

# %%
stats = descriptive_stats(text, verbose=True)
assert stats[0]==13
assert stats[1]==9
assert stats[2]==55
assert abs(stats[3] - 0.69) < 0.02

# %% [markdown]
# Q: Why is it beneficial to use assertion statements in your code?
#
# A: <!-- Your answer here -->  assertion statement allow users to check if there is an error in our code. It also allow users to see if the variables are where they should be. It is easier than an if then statement.

# %% [markdown]
# ## Data Input
#
# Now read in each of the corpora. For the lyrics data, it may be convenient to store the entire contents of the file to make it easier to inspect the titles individually, as you'll do in the last part of the assignment. In the solution, I stored the lyrics data in a dictionary with two dimensions of keys: artist and song. The value was the file contents. A data frame would work equally well.
#
# For the Twitter data, we only need the description field for this assignment. Feel free all the descriptions read it into a data structure. In the solution, I stored the descriptions as a dictionary of lists, with the key being the artist.

# %%
# Read in the lyrics data
songDFS ={}
for artist in os.listdir("lyrics"):
    artist_path=os.path.join('lyrics', artist)
    for lyric_file in os.listdir(artist_path):
        artist_path=os.path.join('lyrics', artist, lyric_file)
        f=open(artist_path, 'r')
        artist_song=lyric_file.replace('.txt', '').split('_')
        songDFS[artist_song[0],artist_song[1]]=f.read()
        f.close()

# %%
songDFS_backup=songDFS

# %%
# Read in the twitter data
artists = ['taylorswift13', 'blakeshelton']
twitterDFS = {}
for artist in artists:
    filePath = os.path.join("twitter", f'{artist}_followers_data.txt')
    twitterDFS[artist] = pd.read_csv(filePath,delimiter='\t')['description'].dropna().tolist()

twitterDFS
# Out:
# {'taylorswift13': ['kepo k?',
#   'CashApp: $samellen97',
#   'vocaloid puella magi Madoka Magica gakkou gurashi!/school live! dennou coil jujutsu kaisen demon slayer spy x family toilet bound hanako kun + more',
#   '喜欢认识有趣的菇凉',
#   'Professional communicator. Bacon fanatic. Social media practitioner. Hipster-friendly travel aficionado.',
#   '一个颠簸的夜晚',
#   'Sinceramente, eu nem sei pq tenho isso...',
#   'Lookin at Justin Bieber n start thinkin "Do ya know how much I love ya🎶🇨🇦',
#   'frijolito bb, el amor de mi vida',
#   'heavydirtysoul',
#   'Software Professional',
#   'Idk',
#   'billie fan🇧🇷💗💗 Paz & Amor e um pouquinho de surto gratuito',
#   '♡ sweetest girl in town ୭̥ 💌 aquarius | 9teen 🩰ㅤㅤㅤㅤㅤ ⋆ ˖ ݁ ˖ ⋆ taylor’s version⋆ ˖ ݁ ˖ ⋆',
#   '2×2=1 Çi tê serê me ji hezkirinê tê...',
#   'Financial Literacy Advocate. A mother. A friend.',
#   '🌷',
#   'President & CEO @TCTrail @SentierTC 🚴\u200d♀️ &🚶\u200d♀️advocate @STRCycling Board Member Opinions are my own. She/Her',
#   'connoisseur, aesthete: Be realistic, expect a miracle.',
#   'کمک کردن جز زندگی من است',
#   'Welcome ppl',
#   "No doubt about it, we're in the darkest timeline.",
#   'cuenta d votos jj',
#   'viviendo las canciones de tay',
#   'Pursuer of dreams and hopes. Posts and retweets are not endorsements. Global citizen. Lives in Seattle, Washington State, USA 🇺🇸',
#   '‘For God so loved the world that he gave his one & only Son, that whoever believes in him shall not perish but have eternal life.’ - JOHN 3:16',
#   'Almost is never enough.',
#   'Derry girls enthusiast',
#   '11:11 🤍 creo en todo lo que me hace sentir viva',
#   'LOVE❣️',
#   'mumbai🍭',
#   '♍️',
#   '\U0001fae1',
#   'Reclaim Your Wild, the Road Goes Ever On and On.',
#   'Equal rights for others does not mean less rights for you. It’s not pie! 🥧',
#   '英語、韓国語を勉強しています！',
#   'Imperfectly Empowering Girl🍁🌸 Wife💞mommy👨\u200d👩\u200d👧\u200d👦 Writer/poet✍️ Visionary🌈 Simplicity is the ultimate sophistication💯 Old soul with young eyes✨ 🎧🧘☕📚♓',
#   'Custom laser engraving',
#   '🌹🎧🎸',
#   'no but she’s a headache',
#   "Hey I'm new to Twitter! 👋🏼",
#   'rest. ( please rcbyf ^ ^ )',
#   'ETH Fund for defi digital asset #ethereum $weth $ethf WalletMovie.eth trams.eth @walletmovie @tramsdex',
#   'Lyzaa',
#   'ﮩ٨ـﮩﮩ٨ـ♡ﮩ٨ـﮩﮩ٨ـ',
#   'basically a Star Wars fan page at this point',
#   'لا إله إلا الله محمد رسول الله😍',
#   '头本，不发推，只白嫖🌝🌝',
#   '🥰♉',
#   'Independent 💪🏻💪🏻💪🏻',
#   'Idk and idc',
#   'Eres bienvenido admirar la belleza de Taylor Swift conmigo :3',
#   'cuteoptometrist',
#   '😎',
#   'Gender fluid she they it are my programs',
#   'Crazy luv for vegetables',
#   'CashApp: $samellen97',
#   'vocaloid puella magi Madoka Magica gakkou gurashi!/school live! dennou coil jujutsu kaisen demon slayer spy x family toilet bound hanako kun + more',
#   '喜欢认识有趣的菇凉',
#   'Professional communicator. Bacon fanatic. Social media practitioner. Hipster-friendly travel aficionado.',
#   '一个颠簸的夜晚',
#   'Sinceramente, eu nem sei pq tenho isso...',
#   'Lookin at Justin Bieber n start thinkin "Do ya know how much I love ya🎶🇨🇦',
#   'frijolito bb, el amor de mi vida',
#   'heavydirtysoul',
#   'Software Professional',
#   'Idk',
#   'billie fan🇧🇷💗💗 Paz & Amor e um pouquinho de surto gratuito',
#   '♡ sweetest girl in town ୭̥ 💌 aquarius | 9teen 🩰ㅤㅤㅤㅤㅤ ⋆ ˖ ݁ ˖ ⋆ taylor’s version⋆ ˖ ݁ ˖ ⋆',
#   '2×2=1 Çi tê serê me ji hezkirinê tê...',
#   'Financial Literacy Advocate. A mother. A friend.',
#   '🌷',
#   'President & CEO @TCTrail @SentierTC 🚴\u200d♀️ &🚶\u200d♀️advocate @STRCycling Board Member Opinions are my own. She/Her',
#   'connoisseur, aesthete: Be realistic, expect a miracle.',
#   'کمک کردن جز زندگی من است',
#   'Welcome ppl',
#   "No doubt about it, we're in the darkest timeline.",
#   'cuenta d votos jj',
#   'viviendo las canciones de tay',
#   'Pursuer of dreams and hopes. Posts and retweets are not endorsements. Global citizen. Lives in Seattle, Washington State, USA 🇺🇸',
#   '‘For God so loved the world that he gave his one & only Son, that whoever believes in him shall not perish but have eternal life.’ - JOHN 3:16',
#   'Almost is never enough.',
#   'Derry girls enthusiast',
#   '11:11 🤍 creo en todo lo que me hace sentir viva',
#   'LOVE❣️',
#   'mumbai🍭',
#   '♍️',
#   '\U0001fae1',
#   'Reclaim Your Wild, the Road Goes Ever On and On.',
#   'Equal rights for others does not mean less rights for you. It’s not pie! 🥧',
#   '英語、韓国語を勉強しています！',
#   'Imperfectly Empowering Girl🍁🌸 Wife💞mommy👨\u200d👩\u200d👧\u200d👦 Writer/poet✍️ Visionary🌈 Simplicity is the ultimate sophistication💯 Old soul with young eyes✨ 🎧🧘☕📚♓',
#   'Custom laser engraving',
#   '🌹🎧🎸',
#   'no but she’s a headache',
#   "Hey I'm new to Twitter! 👋🏼",
#   'rest. ( please rcbyf ^ ^ )',
#   'ETH Fund for defi digital asset #ethereum $weth $ethf WalletMovie.eth trams.eth @walletmovie @tramsdex',
#   'Lyzaa',
#   'ﮩ٨ـﮩﮩ٨ـ♡ﮩ٨ـﮩﮩ٨ـ',
#   'basically a Star Wars fan page at this point',
#   'لا إله إلا الله محمد رسول الله😍',
#   '头本，不发推，只白嫖🌝🌝',
#   '🥰♉',
#   'Independent 💪🏻💪🏻💪🏻',
#   'Idk and idc',
#   'Eres bienvenido admirar la belleza de Taylor Swift conmigo :3',
#   'cuteoptometrist',
#   '😎',
#   'Gender fluid she they it are my programs',
#   'Crazy luv for vegetables',
#   'fan account 🦦',
#   'vocaloid puella magi Madoka Magica gakkou gurashi!/school live! dennou coil jujutsu kaisen demon slayer spy x family toilet bound hanako kun + more',
#   '喜欢认识有趣的菇凉',
#   'Professional communicator. Bacon fanatic. Social media practitioner. Hipster-friendly travel aficionado.',
#   '一个颠簸的夜晚',
#   'Sinceramente, eu nem sei pq tenho isso...',
#   'Lookin at Justin Bieber n start thinkin "Do ya know how much I love ya🎶🇨🇦',
#   'frijolito bb, el amor de mi vida',
#   'heavydirtysoul',
#   'Software Professional',
#   'Idk',
#   'billie fan🇧🇷💗💗 Paz & Amor e um pouquinho de surto gratuito',
#   '♡ sweetest girl in town ୭̥ 💌 aquarius | 9teen 🩰ㅤㅤㅤㅤㅤ ⋆ ˖ ݁ ˖ ⋆ taylor’s version⋆ ˖ ݁ ˖ ⋆',
#   '2×2=1 Çi tê serê me ji hezkirinê tê...',
#   'Financial Literacy Advocate. A mother. A friend.',
#   '🌷',
#   'President & CEO @TCTrail @SentierTC 🚴\u200d♀️ &🚶\u200d♀️advocate @STRCycling Board Member Opinions are my own. She/Her',
#   'connoisseur, aesthete: Be realistic, expect a miracle.',
#   'کمک کردن جز زندگی من است',
#   'Welcome ppl',
#   "No doubt about it, we're in the darkest timeline.",
#   'cuenta d votos jj',
#   'viviendo las canciones de tay',
#   'Pursuer of dreams and hopes. Posts and retweets are not endorsements. Global citizen. Lives in Seattle, Washington State, USA 🇺🇸',
#   '‘For God so loved the world that he gave his one & only Son, that whoever believes in him shall not perish but have eternal life.’ - JOHN 3:16',
#   'Almost is never enough.',
#   'Derry girls enthusiast',
#   '11:11 🤍 creo en todo lo que me hace sentir viva',
#   'LOVE❣️',
#   'mumbai🍭',
#   '♍️',
#   '\U0001fae1',
#   'Reclaim Your Wild, the Road Goes Ever On and On.',
#   'Equal rights for others does not mean less rights for you. It’s not pie! 🥧',
#   '英語、韓国語を勉強しています！',
#   'Imperfectly Empowering Girl🍁🌸 Wife💞mommy👨\u200d👩\u200d👧\u200d👦 Writer/poet✍️ Visionary🌈 Simplicity is the ultimate sophistication💯 Old soul with young eyes✨ 🎧🧘☕📚♓',
#   'Custom laser engraving',
#   '🌹🎧🎸',
#   'no but she’s a headache',
#   "Hey I'm new to Twitter! 👋🏼",
#   'rest. ( please rcbyf ^ ^ )',
#   'ETH Fund for defi digital asset #ethereum $weth $ethf WalletMovie.eth trams.eth @walletmovie @tramsdex',
#   'Lyzaa',
#   'ﮩ٨ـﮩﮩ٨ـ♡ﮩ٨ـﮩﮩ٨ـ',
#   'basically a Star Wars fan page at this point',
#   'لا إله إلا الله محمد رسول الله😍',
#   '头本，不发推，只白嫖🌝🌝',
#   '🥰♉',
#   'Independent 💪🏻💪🏻💪🏻',
#   'Idk and idc',
#   'Eres bienvenido admirar la belleza de Taylor Swift conmigo :3',
#   'cuteoptometrist',
#   '😎',
#   'Gender fluid she they it are my programs',
#   'Crazy luv for vegetables',
#   'fan account 🦦',
#   "Bonjour je suis sociale cool j'aime l'actualité Tpmp ainsi le catch et j'aime soutenir les associations et actualités stars et personnalité Merci❤☺👍❤❤❤",
#   'vocaloid puella magi Madoka Magica gakkou gurashi!/school live! dennou coil jujutsu kaisen demon slayer spy x family toilet bound hanako kun + more',
#   '喜欢认识有趣的菇凉',
#   'Professional communicator. Bacon fanatic. Social media practitioner. Hipster-friendly travel aficionado.',
#   '一个颠簸的夜晚',
#   'Sinceramente, eu nem sei pq tenho isso...',
#   'Lookin at Justin Bieber n start thinkin "Do ya know how much I love ya🎶🇨🇦',
#   'frijolito bb, el amor de mi vida',
#   'heavydirtysoul',
#   'Software Professional',
#   'Idk',
#   'billie fan🇧🇷💗💗 Paz & Amor e um pouquinho de surto gratuito',
#   '♡ sweetest girl in town ୭̥ 💌 aquarius | 9teen 🩰ㅤㅤㅤㅤㅤ ⋆ ˖ ݁ ˖ ⋆ taylor’s version⋆ ˖ ݁ ˖ ⋆',
#   '2×2=1 Çi tê serê me ji hezkirinê tê...',
#   'Financial Literacy Advocate. A mother. A friend.',
#   '🌷',
#   'President & CEO @TCTrail @SentierTC 🚴\u200d♀️ &🚶\u200d♀️advocate @STRCycling Board Member Opinions are my own. She/Her',
#   'connoisseur, aesthete: Be realistic, expect a miracle.',
#   'کمک کردن جز زندگی من است',
#   'Welcome ppl',
#   "No doubt about it, we're in the darkest timeline.",
#   'cuenta d votos jj',
#   'viviendo las canciones de tay',
#   'Pursuer of dreams and hopes. Posts and retweets are not endorsements. Global citizen. Lives in Seattle, Washington State, USA 🇺🇸',
#   '‘For God so loved the world that he gave his one & only Son, that whoever believes in him shall not perish but have eternal life.’ - JOHN 3:16',
#   'Almost is never enough.',
#   'Derry girls enthusiast',
#   '11:11 🤍 creo en todo lo que me hace sentir viva',
#   'LOVE❣️',
#   'mumbai🍭',
#   '♍️',
#   '\U0001fae1',
#   'Reclaim Your Wild, the Road Goes Ever On and On.',
#   'Equal rights for others does not mean less rights for you. It’s not pie! 🥧',
#   '英語、韓国語を勉強しています！',
#   'Imperfectly Empowering Girl🍁🌸 Wife💞mommy👨\u200d👩\u200d👧\u200d👦 Writer/poet✍️ Visionary🌈 Simplicity is the ultimate sophistication💯 Old soul with young eyes✨ 🎧🧘☕📚♓',
#   'Custom laser engraving',
#   '🌹🎧🎸',
#   'no but she’s a headache',
#   "Hey I'm new to Twitter! 👋🏼",
#   'rest. ( please rcbyf ^ ^ )',
#   'ETH Fund for defi digital asset #ethereum $weth $ethf WalletMovie.eth trams.eth @walletmovie @tramsdex',
#   'Lyzaa',
#   'ﮩ٨ـﮩﮩ٨ـ♡ﮩ٨ـﮩﮩ٨ـ',
#   'basically a Star Wars fan page at this point',
#   'لا إله إلا الله محمد رسول الله😍',
#   '头本，不发推，只白嫖🌝🌝',
#   '🥰♉',
#   'Independent 💪🏻💪🏻💪🏻',
#   'Idk and idc',
#   'Eres bienvenido admirar la belleza de Taylor Swift conmigo :3',
#   'cuteoptometrist',
#   '😎',
#   'Gender fluid she they it are my programs',
#   'Crazy luv for vegetables',
#   'fan account 🦦',
#   "Bonjour je suis sociale cool j'aime l'actualité Tpmp ainsi le catch et j'aime soutenir les associations et actualités stars et personnalité Merci❤☺👍❤❤❤",
#   ':p',
#   'vocaloid puella magi Madoka Magica gakkou gurashi!/school live! dennou coil jujutsu kaisen demon slayer spy x family toilet bound hanako kun + more',
#   '喜欢认识有趣的菇凉',
#   'Professional communicator. Bacon fanatic. Social media practitioner. Hipster-friendly travel aficionado.',
#   '一个颠簸的夜晚',
#   'Sinceramente, eu nem sei pq tenho isso...',
#   'Lookin at Justin Bieber n start thinkin "Do ya know how much I love ya🎶🇨🇦',
#   'frijolito bb, el amor de mi vida',
#   'heavydirtysoul',
#   'Software Professional',
#   'Idk',
#   'billie fan🇧🇷💗💗 Paz & Amor e um pouquinho de surto gratuito',
#   '♡ sweetest girl in town ୭̥ 💌 aquarius | 9teen 🩰ㅤㅤㅤㅤㅤ ⋆ ˖ ݁ ˖ ⋆ taylor’s version⋆ ˖ ݁ ˖ ⋆',
#   '2×2=1 Çi tê serê me ji hezkirinê tê...',
#   'Financial Literacy Advocate. A mother. A friend.',
#   '🌷',
#   'President & CEO @TCTrail @SentierTC 🚴\u200d♀️ &🚶\u200d♀️advocate @STRCycling Board Member Opinions are my own. She/Her',
#   'connoisseur, aesthete: Be realistic, expect a miracle.',
#   'کمک کردن جز زندگی من است',
#   'Welcome ppl',
#   "No doubt about it, we're in the darkest timeline.",
#   'cuenta d votos jj',
#   'viviendo las canciones de tay',
#   'Pursuer of dreams and hopes. Posts and retweets are not endorsements. Global citizen. Lives in Seattle, Washington State, USA 🇺🇸',
#   '‘For God so loved the world that he gave his one & only Son, that whoever believes in him shall not perish but have eternal life.’ - JOHN 3:16',
#   'Almost is never enough.',
#   'Derry girls enthusiast',
#   '11:11 🤍 creo en todo lo que me hace sentir viva',
#   'LOVE❣️',
#   'mumbai🍭',
#   '♍️',
#   '\U0001fae1',
#   'Reclaim Your Wild, the Road Goes Ever On and On.',
#   'Equal rights for others does not mean less rights for you. It’s not pie! 🥧',
#   '英語、韓国語を勉強しています！',
#   'Imperfectly Empowering Girl🍁🌸 Wife💞mommy👨\u200d👩\u200d👧\u200d👦 Writer/poet✍️ Visionary🌈 Simplicity is the ultimate sophistication💯 Old soul with young eyes✨ 🎧🧘☕📚♓',
#   'Custom laser engraving',
#   '🌹🎧🎸',
#   'no but she’s a headache',
#   "Hey I'm new to Twitter! 👋🏼",
#   'rest. ( please rcbyf ^ ^ )',
#   'ETH Fund for defi digital asset #ethereum $weth $ethf WalletMovie.eth trams.eth @walletmovie @tramsdex',
#   'Lyzaa',
#   'ﮩ٨ـﮩﮩ٨ـ♡ﮩ٨ـﮩﮩ٨ـ',
#   'basically a Star Wars fan page at this point',
#   'لا إله إلا الله محمد رسول الله😍',
#   '头本，不发推，只白嫖🌝🌝',
#   '🥰♉',
#   'Independent 💪🏻💪🏻💪🏻',
#   'Idk and idc',
#   'Eres bienvenido admirar la belleza de Taylor Swift conmigo :3',
#   'cuteoptometrist',
#   '😎',
#   'Gender fluid she they it are my programs',
#   'Crazy luv for vegetables',
#   'fan account 🦦',
#   "Bonjour je suis sociale cool j'aime l'actualité Tpmp ainsi le catch et j'aime soutenir les associations et actualités stars et personnalité Merci❤☺👍❤❤❤",
#   ':p',
#   'Living Life Poetically',
#   '喜欢认识有趣的菇凉',
#   'Professional communicator. Bacon fanatic. Social media practitioner. Hipster-friendly travel aficionado.',
#   '一个颠簸的夜晚',
#   'Sinceramente, eu nem sei pq tenho isso...',
#   'Lookin at Justin Bieber n start thinkin "Do ya know how much I love ya🎶🇨🇦',
#   'frijolito bb, el amor de mi vida',
#   'heavydirtysoul',
#   'Software Professional',
#   'Idk',
#   'billie fan🇧🇷💗💗 Paz & Amor e um pouquinho de surto gratuito',
#   '♡ sweetest girl in town ୭̥ 💌 aquarius | 9teen 🩰ㅤㅤㅤㅤㅤ ⋆ ˖ ݁ ˖ ⋆ taylor’s version⋆ ˖ ݁ ˖ ⋆',
#   '2×2=1 Çi tê serê me ji hezkirinê tê...',
#   'Financial Literacy Advocate. A mother. A friend.',
#   '🌷',
#   'President & CEO @TCTrail @SentierTC 🚴\u200d♀️ &🚶\u200d♀️advocate @STRCycling Board Member Opinions are my own. She/Her',
#   'connoisseur, aesthete: Be realistic, expect a miracle.',
#   'کمک کردن جز زندگی من است',
#   'Welcome ppl',
#   "No doubt about it, we're in the darkest timeline.",
#   'cuenta d votos jj',
#   'viviendo las canciones de tay',
#   'Pursuer of dreams and hopes. Posts and retweets are not endorsements. Global citizen. Lives in Seattle, Washington State, USA 🇺🇸',
#   '‘For God so loved the world that he gave his one & only Son, that whoever believes in him shall not perish but have eternal life.’ - JOHN 3:16',
#   'Almost is never enough.',
#   'Derry girls enthusiast',
#   '11:11 🤍 creo en todo lo que me hace sentir viva',
#   'LOVE❣️',
#   'mumbai🍭',
#   '♍️',
#   '\U0001fae1',
#   'Reclaim Your Wild, the Road Goes Ever On and On.',
#   'Equal rights for others does not mean less rights for you. It’s not pie! 🥧',
#   '英語、韓国語を勉強しています！',
#   'Imperfectly Empowering Girl🍁🌸 Wife💞mommy👨\u200d👩\u200d👧\u200d👦 Writer/poet✍️ Visionary🌈 Simplicity is the ultimate sophistication💯 Old soul with young eyes✨ 🎧🧘☕📚♓',
#   'Custom laser engraving',
#   '🌹🎧🎸',
#   'no but she’s a headache',
#   "Hey I'm new to Twitter! 👋🏼",
#   'rest. ( please rcbyf ^ ^ )',
#   'ETH Fund for defi digital asset #ethereum $weth $ethf WalletMovie.eth trams.eth @walletmovie @tramsdex',
#   'Lyzaa',
#   'ﮩ٨ـﮩﮩ٨ـ♡ﮩ٨ـﮩﮩ٨ـ',
#   'basically a Star Wars fan page at this point',
#   'لا إله إلا الله محمد رسول الله😍',
#   '头本，不发推，只白嫖🌝🌝',
#   '🥰♉',
#   'Independent 💪🏻💪🏻💪🏻',
#   'Idk and idc',
#   'Eres bienvenido admirar la belleza de Taylor Swift conmigo :3',
#   'cuteoptometrist',
#   '😎',
#   'Gender fluid she they it are my programs',
#   'Crazy luv for vegetables',
#   'fan account 🦦',
#   "Bonjour je suis sociale cool j'aime l'actualité Tpmp ainsi le catch et j'aime soutenir les associations et actualités stars et personnalité Merci❤☺👍❤❤❤",
#   ':p',
#   'Living Life Poetically',
#   'ip 日本',
#   '喜欢认识有趣的菇凉',
#   'Professional communicator. Bacon fanatic. Social media practitioner. Hipster-friendly travel aficionado.',
#   '一个颠簸的夜晚',
#   'Sinceramente, eu nem sei pq tenho isso...',
#   'Lookin at Justin Bieber n start thinkin "Do ya know how much I love ya🎶🇨🇦',
#   'frijolito bb, el amor de mi vida',
#   'heavydirtysoul',
#   'Software Professional',
#   'Idk',
#   'billie fan🇧🇷💗💗 Paz & Amor e um pouquinho de surto gratuito',
#   '♡ sweetest girl in town ୭̥ 💌 aquarius | 9teen 🩰ㅤㅤㅤㅤㅤ ⋆ ˖ ݁ ˖ ⋆ taylor’s version⋆ ˖ ݁ ˖ ⋆',
#   '2×2=1 Çi tê serê me ji hezkirinê tê...',
#   'Financial Literacy Advocate. A mother. A friend.',
#   '🌷',
#   'President & CEO @TCTrail @SentierTC 🚴\u200d♀️ &🚶\u200d♀️advocate @STRCycling Board Member Opinions are my own. She/Her',
#   'connoisseur, aesthete: Be realistic, expect a miracle.',
#   'کمک کردن جز زندگی من است',
#   'Welcome ppl',
#   "No doubt about it, we're in the darkest timeline.",
#   'cuenta d votos jj',
#   'viviendo las canciones de tay',
#   'Pursuer of dreams and hopes. Posts and retweets are not endorsements. Global citizen. Lives in Seattle, Washington State, USA 🇺🇸',
#   '‘For God so loved the world that he gave his one & only Son, that whoever believes in him shall not perish but have eternal life.’ - JOHN 3:16',
#   'Almost is never enough.',
#   'Derry girls enthusiast',
#   '11:11 🤍 creo en todo lo que me hace sentir viva',
#   'LOVE❣️',
#   'mumbai🍭',
#   '♍️',
#   '\U0001fae1',
#   'Reclaim Your Wild, the Road Goes Ever On and On.',
#   'Equal rights for others does not mean less rights for you. It’s not pie! 🥧',
#   '英語、韓国語を勉強しています！',
#   'Imperfectly Empowering Girl🍁🌸 Wife💞mommy👨\u200d👩\u200d👧\u200d👦 Writer/poet✍️ Visionary🌈 Simplicity is the ultimate sophistication💯 Old soul with young eyes✨ 🎧🧘☕📚♓',
#   'Custom laser engraving',
#   '🌹🎧🎸',
#   'no but she’s a headache',
#   "Hey I'm new to Twitter! 👋🏼",
#   'rest. ( please rcbyf ^ ^ )',
#   'ETH Fund for defi digital asset #ethereum $weth $ethf WalletMovie.eth trams.eth @walletmovie @tramsdex',
#   'Lyzaa',
#   'ﮩ٨ـﮩﮩ٨ـ♡ﮩ٨ـﮩﮩ٨ـ',
#   'basically a Star Wars fan page at this point',
#   'لا إله إلا الله محمد رسول الله😍',
#   '头本，不发推，只白嫖🌝🌝',
#   '🥰♉',
#   'Independent 💪🏻💪🏻💪🏻',
#   'Idk and idc',
#   'Eres bienvenido admirar la belleza de Taylor Swift conmigo :3',
#   'cuteoptometrist',
#   '😎',
#   'Gender fluid she they it are my programs',
#   'Crazy luv for vegetables',
#   'fan account 🦦',
#   "Bonjour je suis sociale cool j'aime l'actualité Tpmp ainsi le catch et j'aime soutenir les associations et actualités stars et personnalité Merci❤☺👍❤❤❤",
#   ':p',
#   'Living Life Poetically',
#   'ip 日本',
#   'Professional communicator. Bacon fanatic. Social media practitioner. Hipster-friendly travel aficionado.',
#   '一个颠簸的夜晚',
#   'Sinceramente, eu nem sei pq tenho isso...',
#   'Lookin at Justin Bieber n start thinkin "Do ya know how much I love ya🎶🇨🇦',
#   'frijolito bb, el amor de mi vida',
#   'heavydirtysoul',
#   'Software Professional',
#   'Idk',
#   'billie fan🇧🇷💗💗 Paz & Amor e um pouquinho de surto gratuito',
#   '♡ sweetest girl in town ୭̥ 💌 aquarius | 9teen 🩰ㅤㅤㅤㅤㅤ ⋆ ˖ ݁ ˖ ⋆ taylor’s version⋆ ˖ ݁ ˖ ⋆',
#   '2×2=1 Çi tê serê me ji hezkirinê tê...',
#   'Financial Literacy Advocate. A mother. A friend.',
#   '🌷',
#   'President & CEO @TCTrail @SentierTC 🚴\u200d♀️ &🚶\u200d♀️advocate @STRCycling Board Member Opinions are my own. She/Her',
#   'connoisseur, aesthete: Be realistic, expect a miracle.',
#   'کمک کردن جز زندگی من است',
#   'Welcome ppl',
#   "No doubt about it, we're in the darkest timeline.",
#   'cuenta d votos jj',
#   'viviendo las canciones de tay',
#   'Pursuer of dreams and hopes. Posts and retweets are not endorsements. Global citizen. Lives in Seattle, Washington State, USA 🇺🇸',
#   '‘For God so loved the world that he gave his one & only Son, that whoever believes in him shall not perish but have eternal life.’ - JOHN 3:16',
#   'Almost is never enough.',
#   'Derry girls enthusiast',
#   '11:11 🤍 creo en todo lo que me hace sentir viva',
#   'LOVE❣️',
#   'mumbai🍭',
#   '♍️',
#   '\U0001fae1',
#   'Reclaim Your Wild, the Road Goes Ever On and On.',
#   'Equal rights for others does not mean less rights for you. It’s not pie! 🥧',
#   '英語、韓国語を勉強しています！',
#   'Imperfectly Empowering Girl🍁🌸 Wife💞mommy👨\u200d👩\u200d👧\u200d👦 Writer/poet✍️ Visionary🌈 Simplicity is the ultimate sophistication💯 Old soul with young eyes✨ 🎧🧘☕📚♓',
#   'Custom laser engraving',
#   '🌹🎧🎸',
#   'no but she’s a headache',
#   "Hey I'm new to Twitter! 👋🏼",
#   'rest. ( please rcbyf ^ ^ )',
#   'ETH Fund for defi digital asset #ethereum $weth $ethf WalletMovie.eth trams.eth @walletmovie @tramsdex',
#   'Lyzaa',
#   'ﮩ٨ـﮩﮩ٨ـ♡ﮩ٨ـﮩﮩ٨ـ',
#   'basically a Star Wars fan page at this point',
#   'لا إله إلا الله محمد رسول الله😍',
#   '头本，不发推，只白嫖🌝🌝',
#   '🥰♉',
#   'Independent 💪🏻💪🏻💪🏻',
#   'Idk and idc',
#   'Eres bienvenido admirar la belleza de Taylor Swift conmigo :3',
#   'cuteoptometrist',
#   '😎',
#   'Gender fluid she they it are my programs',
#   'Crazy luv for vegetables',
#   'fan account 🦦',
#   "Bonjour je suis sociale cool j'aime l'actualité Tpmp ainsi le catch et j'aime soutenir les associations et actualités stars et personnalité Merci❤☺👍❤❤❤",
#   ':p',
#   'Living Life Poetically',
#   'ip 日本',
#   'KBF Foundation is community based organization, registered as Non profit organization OUR FOCUS are on opharnage, Soccer leaque,HIV&AIDS and Human Rights',
#   '一个颠簸的夜晚',
#   'Sinceramente, eu nem sei pq tenho isso...',
#   'Lookin at Justin Bieber n start thinkin "Do ya know how much I love ya🎶🇨🇦',
#   'frijolito bb, el amor de mi vida',
#   'heavydirtysoul',
#   'Software Professional',
#   'Idk',
#   'billie fan🇧🇷💗💗 Paz & Amor e um pouquinho de surto gratuito',
#   '♡ sweetest girl in town ୭̥ 💌 aquarius | 9teen 🩰ㅤㅤㅤㅤㅤ ⋆ ˖ ݁ ˖ ⋆ taylor’s version⋆ ˖ ݁ ˖ ⋆',
#   '2×2=1 Çi tê serê me ji hezkirinê tê...',
#   'Financial Literacy Advocate. A mother. A friend.',
#   '🌷',
#   'President & CEO @TCTrail @SentierTC 🚴\u200d♀️ &🚶\u200d♀️advocate @STRCycling Board Member Opinions are my own. She/Her',
#   'connoisseur, aesthete: Be realistic, expect a miracle.',
#   'کمک کردن جز زندگی من است',
#   'Welcome ppl',
#   "No doubt about it, we're in the darkest timeline.",
#   'cuenta d votos jj',
#   'viviendo las canciones de tay',
#   'Pursuer of dreams and hopes. Posts and retweets are not endorsements. Global citizen. Lives in Seattle, Washington State, USA 🇺🇸',
#   '‘For God so loved the world that he gave his one & only Son, that whoever believes in him shall not perish but have eternal life.’ - JOHN 3:16',
#   'Almost is never enough.',
#   'Derry girls enthusiast',
#   '11:11 🤍 creo en todo lo que me hace sentir viva',
#   'LOVE❣️',
#   'mumbai🍭',
#   '♍️',
#   '\U0001fae1',
#   'Reclaim Your Wild, the Road Goes Ever On and On.',
#   'Equal rights for others does not mean less rights for you. It’s not pie! 🥧',
#   '英語、韓国語を勉強しています！',
#   'Imperfectly Empowering Girl🍁🌸 Wife💞mommy👨\u200d👩\u200d👧\u200d👦 Writer/poet✍️ Visionary🌈 Simplicity is the ultimate sophistication💯 Old soul with young eyes✨ 🎧🧘☕📚♓',
#   'Custom laser engraving',
#   '🌹🎧🎸',
#   'no but she’s a headache',
#   "Hey I'm new to Twitter! 👋🏼",
#   'rest. ( please rcbyf ^ ^ )',
#   'ETH Fund for defi digital asset #ethereum $weth $ethf WalletMovie.eth trams.eth @walletmovie @tramsdex',
#   'Lyzaa',
#   'ﮩ٨ـﮩﮩ٨ـ♡ﮩ٨ـﮩﮩ٨ـ',
#   'basically a Star Wars fan page at this point',
#   'لا إله إلا الله محمد رسول الله😍',
#   '头本，不发推，只白嫖🌝🌝',
#   '🥰♉',
#   'Independent 💪🏻💪🏻💪🏻',
#   'Idk and idc',
#   'Eres bienvenido admirar la belleza de Taylor Swift conmigo :3',
#   'cuteoptometrist',
#   '😎',
#   'Gender fluid she they it are my programs',
#   'Crazy luv for vegetables',
#   'fan account 🦦',
#   "Bonjour je suis sociale cool j'aime l'actualité Tpmp ainsi le catch et j'aime soutenir les associations et actualités stars et personnalité Merci❤☺👍❤❤❤",
#   ':p',
#   'Living Life Poetically',
#   'ip 日本',
#   'KBF Foundation is community based organization, registered as Non profit organization OUR FOCUS are on opharnage, Soccer leaque,HIV&AIDS and Human Rights',
#   'canadienne et fière de l’être !',
#   'Sinceramente, eu nem sei pq tenho isso...',
#   'Lookin at Justin Bieber n start thinkin "Do ya know how much I love ya🎶🇨🇦',
#   'frijolito bb, el amor de mi vida',
#   'heavydirtysoul',
#   'Software Professional',
#   'Idk',
#   'billie fan🇧🇷💗💗 Paz & Amor e um pouquinho de surto gratuito',
#   '♡ sweetest girl in town ୭̥ 💌 aquarius | 9teen 🩰ㅤㅤㅤㅤㅤ ⋆ ˖ ݁ ˖ ⋆ taylor’s version⋆ ˖ ݁ ˖ ⋆',
#   '2×2=1 Çi tê serê me ji hezkirinê tê...',
#   'Financial Literacy Advocate. A mother. A friend.',
#   '🌷',
#   'President & CEO @TCTrail @SentierTC 🚴\u200d♀️ &🚶\u200d♀️advocate @STRCycling Board Member Opinions are my own. She/Her',
#   'connoisseur, aesthete: Be realistic, expect a miracle.',
#   'کمک کردن جز زندگی من است',
#   'Welcome ppl',
#   "No doubt about it, we're in the darkest timeline.",
#   'cuenta d votos jj',
#   'viviendo las canciones de tay',
#   'Pursuer of dreams and hopes. Posts and retweets are not endorsements. Global citizen. Lives in Seattle, Washington State, USA 🇺🇸',
#   '‘For God so loved the world that he gave his one & only Son, that whoever believes in him shall not perish but have eternal life.’ - JOHN 3:16',
#   'Almost is never enough.',
#   'Derry girls enthusiast',
#   '11:11 🤍 creo en todo lo que me hace sentir viva',
#   'LOVE❣️',
#   'mumbai🍭',
#   '♍️',
#   '\U0001fae1',
#   'Reclaim Your Wild, the Road Goes Ever On and On.',
#   'Equal rights for others does not mean less rights for you. It’s not pie! 🥧',
#   '英語、韓国語を勉強しています！',
#   'Imperfectly Empowering Girl🍁🌸 Wife💞mommy👨\u200d👩\u200d👧\u200d👦 Writer/poet✍️ Visionary🌈 Simplicity is the ultimate sophistication💯 Old soul with young eyes✨ 🎧🧘☕📚♓',
#   'Custom laser engraving',
#   '🌹🎧🎸',
#   'no but she’s a headache',
#   "Hey I'm new to Twitter! 👋🏼",
#   'rest. ( please rcbyf ^ ^ )',
#   'ETH Fund for defi digital asset #ethereum $weth $ethf WalletMovie.eth trams.eth @walletmovie @tramsdex',
#   'Lyzaa',
#   'ﮩ٨ـﮩﮩ٨ـ♡ﮩ٨ـﮩﮩ٨ـ',
#   'basically a Star Wars fan page at this point',
#   'لا إله إلا الله محمد رسول الله😍',
#   '头本，不发推，只白嫖🌝🌝',
#   '🥰♉',
#   'Independent 💪🏻💪🏻💪🏻',
#   'Idk and idc',
#   'Eres bienvenido admirar la belleza de Taylor Swift conmigo :3',
#   'cuteoptometrist',
#   '😎',
#   'Gender fluid she they it are my programs',
#   'Crazy luv for vegetables',
#   'fan account 🦦',
#   "Bonjour je suis sociale cool j'aime l'actualité Tpmp ainsi le catch et j'aime soutenir les associations et actualités stars et personnalité Merci❤☺👍❤❤❤",
#   ':p',
#   'Living Life Poetically',
#   'ip 日本',
#   'KBF Foundation is community based organization, registered as Non profit organization OUR FOCUS are on opharnage, Soccer leaque,HIV&AIDS and Human Rights',
#   'canadienne et fière de l’être !',
#   "anly 'not so kalat' moments🤡",
#   'Lookin at Justin Bieber n start thinkin "Do ya know how much I love ya🎶🇨🇦',
#   'frijolito bb, el amor de mi vida',
#   'heavydirtysoul',
#   'Software Professional',
#   'Idk',
#   'billie fan🇧🇷💗💗 Paz & Amor e um pouquinho de surto gratuito',
#   '♡ sweetest girl in town ୭̥ 💌 aquarius | 9teen 🩰ㅤㅤㅤㅤㅤ ⋆ ˖ ݁ ˖ ⋆ taylor’s version⋆ ˖ ݁ ˖ ⋆',
#   '2×2=1 Çi tê serê me ji hezkirinê tê...',
#   'Financial Literacy Advocate. A mother. A friend.',
#   '🌷',
#   'President & CEO @TCTrail @SentierTC 🚴\u200d♀️ &🚶\u200d♀️advocate @STRCycling Board Member Opinions are my own. She/Her',
#   'connoisseur, aesthete: Be realistic, expect a miracle.',
#   'کمک کردن جز زندگی من است',
#   'Welcome ppl',
#   "No doubt about it, we're in the darkest timeline.",
#   'cuenta d votos jj',
#   'viviendo las canciones de tay',
#   'Pursuer of dreams and hopes. Posts and retweets are not endorsements. Global citizen. Lives in Seattle, Washington State, USA 🇺🇸',
#   '‘For God so loved the world that he gave his one & only Son, that whoever believes in him shall not perish but have eternal life.’ - JOHN 3:16',
#   'Almost is never enough.',
#   'Derry girls enthusiast',
#   '11:11 🤍 creo en todo lo que me hace sentir viva',
#   'LOVE❣️',
#   'mumbai🍭',
#   '♍️',
#   '\U0001fae1',
#   'Reclaim Your Wild, the Road Goes Ever On and On.',
#   'Equal rights for others does not mean less rights for you. It’s not pie! 🥧',
#   '英語、韓国語を勉強しています！',
#   'Imperfectly Empowering Girl🍁🌸 Wife💞mommy👨\u200d👩\u200d👧\u200d👦 Writer/poet✍️ Visionary🌈 Simplicity is the ultimate sophistication💯 Old soul with young eyes✨ 🎧🧘☕📚♓',
#   'Custom laser engraving',
#   '🌹🎧🎸',
#   'no but she’s a headache',
#   "Hey I'm new to Twitter! 👋🏼",
#   'rest. ( please rcbyf ^ ^ )',
#   'ETH Fund for defi digital asset #ethereum $weth $ethf WalletMovie.eth trams.eth @walletmovie @tramsdex',
#   'Lyzaa',
#   'ﮩ٨ـﮩﮩ٨ـ♡ﮩ٨ـﮩﮩ٨ـ',
#   'basically a Star Wars fan page at this point',
#   'لا إله إلا الله محمد رسول الله😍',
#   '头本，不发推，只白嫖🌝🌝',
#   '🥰♉',
#   'Independent 💪🏻💪🏻💪🏻',
#   'Idk and idc',
#   'Eres bienvenido admirar la belleza de Taylor Swift conmigo :3',
#   'cuteoptometrist',
#   '😎',
#   'Gender fluid she they it are my programs',
#   'Crazy luv for vegetables',
#   'fan account 🦦',
#   "Bonjour je suis sociale cool j'aime l'actualité Tpmp ainsi le catch et j'aime soutenir les associations et actualités stars et personnalité Merci❤☺👍❤❤❤",
#   ':p',
#   'Living Life Poetically',
#   'ip 日本',
#   'KBF Foundation is community based organization, registered as Non profit organization OUR FOCUS are on opharnage, Soccer leaque,HIV&AIDS and Human Rights',
#   'canadienne et fière de l’être !',
#   "anly 'not so kalat' moments🤡",
#   'Lookin at Justin Bieber n start thinkin "Do ya know how much I love ya🎶🇨🇦',
#   'frijolito bb, el amor de mi vida',
#   'heavydirtysoul',
#   'Software Professional',
#   'Idk',
#   'billie fan🇧🇷💗💗 Paz & Amor e um pouquinho de surto gratuito',
#   '♡ sweetest girl in town ୭̥ 💌 aquarius | 9teen 🩰ㅤㅤㅤㅤㅤ ⋆ ˖ ݁ ˖ ⋆ taylor’s version⋆ ˖ ݁ ˖ ⋆',
#   '2×2=1 Çi tê serê me ji hezkirinê tê...',
#   'Financial Literacy Advocate. A mother. A friend.',
#   '🌷',
#   'President & CEO @TCTrail @SentierTC 🚴\u200d♀️ &🚶\u200d♀️advocate @STRCycling Board Member Opinions are my own. She/Her',
#   'connoisseur, aesthete: Be realistic, expect a miracle.',
#   'کمک کردن جز زندگی من است',
#   'Welcome ppl',
#   "No doubt about it, we're in the darkest timeline.",
#   'cuenta d votos jj',
#   'viviendo las canciones de tay',
#   'Pursuer of dreams and hopes. Posts and retweets are not endorsements. Global citizen. Lives in Seattle, Washington State, USA 🇺🇸',
#   '‘For God so loved the world that he gave his one & only Son, that whoever believes in him shall not perish but have eternal life.’ - JOHN 3:16',
#   'Almost is never enough.',
#   'Derry girls enthusiast',
#   '11:11 🤍 creo en todo lo que me hace sentir viva',
#   'LOVE❣️',
#   'mumbai🍭',
#   '♍️',
#   '\U0001fae1',
#   'Reclaim Your Wild, the Road Goes Ever On and On.',
#   'Equal rights for others does not mean less rights for you. It’s not pie! 🥧',
#   '英語、韓国語を勉強しています！',
#   'Imperfectly Empowering Girl🍁🌸 Wife💞mommy👨\u200d👩\u200d👧\u200d👦 Writer/poet✍️ Visionary🌈 Simplicity is the ultimate sophistication💯 Old soul with young eyes✨ 🎧🧘☕📚♓',
#   'Custom laser engraving',
#   '🌹🎧🎸',
#   'no but she’s a headache',
#   "Hey I'm new to Twitter! 👋🏼",
#   'rest. ( please rcbyf ^ ^ )',
#   'ETH Fund for defi digital asset #ethereum $weth $ethf WalletMovie.eth trams.eth @walletmovie @tramsdex',
#   'Lyzaa',
#   'ﮩ٨ـﮩﮩ٨ـ♡ﮩ٨ـﮩﮩ٨ـ',
#   'basically a Star Wars fan page at this point',
#   'لا إله إلا الله محمد رسول الله😍',
#   '头本，不发推，只白嫖🌝🌝',
#   '🥰♉',
#   'Independent 💪🏻💪🏻💪🏻',
#   'Idk and idc',
#   'Eres bienvenido admirar la belleza de Taylor Swift conmigo :3',
#   'cuteoptometrist',
#   '😎',
#   'Gender fluid she they it are my programs',
#   'Crazy luv for vegetables',
#   'fan account 🦦',
#   "Bonjour je suis sociale cool j'aime l'actualité Tpmp ainsi le catch et j'aime soutenir les associations et actualités stars et personnalité Merci❤☺👍❤❤❤",
#   ':p',
#   'Living Life Poetically',
#   'ip 日本',
#   'KBF Foundation is community based organization, registered as Non profit organization OUR FOCUS are on opharnage, Soccer leaque,HIV&AIDS and Human Rights',
#   'canadienne et fière de l’être !',
#   "anly 'not so kalat' moments🤡",
#   'Am good natured woman with the sense of humor and ability to understand',
#   'frijolito bb, el amor de mi vida',
#   'heavydirtysoul',
#   'Software Professional',
#   'Idk',
#   'billie fan🇧🇷💗💗 Paz & Amor e um pouquinho de surto gratuito',
#   '♡ sweetest girl in town ୭̥ 💌 aquarius | 9teen 🩰ㅤㅤㅤㅤㅤ ⋆ ˖ ݁ ˖ ⋆ taylor’s version⋆ ˖ ݁ ˖ ⋆',
#   '2×2=1 Çi tê serê me ji hezkirinê tê...',
#   'Financial Literacy Advocate. A mother. A friend.',
#   '🌷',
#   'President & CEO @TCTrail @SentierTC 🚴\u200d♀️ &🚶\u200d♀️advocate @STRCycling Board Member Opinions are my own. She/Her',
#   'connoisseur, aesthete: Be realistic, expect a miracle.',
#   'کمک کردن جز زندگی من است',
#   'Welcome ppl',
#   "No doubt about it, we're in the darkest timeline.",
#   'cuenta d votos jj',
#   'viviendo las canciones de tay',
#   'Pursuer of dreams and hopes. Posts and retweets are not endorsements. Global citizen. Lives in Seattle, Washington State, USA 🇺🇸',
#   '‘For God so loved the world that he gave his one & only Son, that whoever believes in him shall not perish but have eternal life.’ - JOHN 3:16',
#   'Almost is never enough.',
#   'Derry girls enthusiast',
#   '11:11 🤍 creo en todo lo que me hace sentir viva',
#   'LOVE❣️',
#   'mumbai🍭',
#   '♍️',
#   '\U0001fae1',
#   'Reclaim Your Wild, the Road Goes Ever On and On.',
#   'Equal rights for others does not mean less rights for you. It’s not pie! 🥧',
#   '英語、韓国語を勉強しています！',
#   'Imperfectly Empowering Girl🍁🌸 Wife💞mommy👨\u200d👩\u200d👧\u200d👦 Writer/poet✍️ Visionary🌈 Simplicity is the ultimate sophistication💯 Old soul with young eyes✨ 🎧🧘☕📚♓',
#   'Custom laser engraving',
#   '🌹🎧🎸',
#   'no but she’s a headache',
#   "Hey I'm new to Twitter! 👋🏼",
#   'rest. ( please rcbyf ^ ^ )',
#   'ETH Fund for defi digital asset #ethereum $weth $ethf WalletMovie.eth trams.eth @walletmovie @tramsdex',
#   'Lyzaa',
#   'ﮩ٨ـﮩﮩ٨ـ♡ﮩ٨ـﮩﮩ٨ـ',
#   'basically a Star Wars fan page at this point',
#   'لا إله إلا الله محمد رسول الله😍',
#   '头本，不发推，只白嫖🌝🌝',
#   '🥰♉',
#   'Independent 💪🏻💪🏻💪🏻',
#   'Idk and idc',
#   'Eres bienvenido admirar la belleza de Taylor Swift conmigo :3',
#   'cuteoptometrist',
#   '😎',
#   'Gender fluid she they it are my programs',
#   'Crazy luv for vegetables',
#   'fan account 🦦',
#   "Bonjour je suis sociale cool j'aime l'actualité Tpmp ainsi le catch et j'aime soutenir les associations et actualités stars et personnalité Merci❤☺👍❤❤❤",
#   ':p',
#   'Living Life Poetically',
#   'ip 日本',
#   'KBF Foundation is community based organization, registered as Non profit organization OUR FOCUS are on opharnage, Soccer leaque,HIV&AIDS and Human Rights',
#   'canadienne et fière de l’être !',
#   "anly 'not so kalat' moments🤡",
#   'Am good natured woman with the sense of humor and ability to understand',
#   'heavydirtysoul',
#   'Software Professional',
#   'Idk',
#   'billie fan🇧🇷💗💗 Paz & Amor e um pouquinho de surto gratuito',
#   '♡ sweetest girl in town ୭̥ 💌 aquarius | 9teen 🩰ㅤㅤㅤㅤㅤ ⋆ ˖ ݁ ˖ ⋆ taylor’s version⋆ ˖ ݁ ˖ ⋆',
#   '2×2=1 Çi tê serê me ji hezkirinê tê...',
#   'Financial Literacy Advocate. A mother. A friend.',
#   '🌷',
#   'President & CEO @TCTrail @SentierTC 🚴\u200d♀️ &🚶\u200d♀️advocate @STRCycling Board Member Opinions are my own. She/Her',
#   'connoisseur, aesthete: Be realistic, expect a miracle.',
#   'کمک کردن جز زندگی من است',
#   'Welcome ppl',
#   "No doubt about it, we're in the darkest timeline.",
#   'cuenta d votos jj',
#   'viviendo las canciones de tay',
#   'Pursuer of dreams and hopes. Posts and retweets are not endorsements. Global citizen. Lives in Seattle, Washington State, USA 🇺🇸',
#   '‘For God so loved the world that he gave his one & only Son, that whoever believes in him shall not perish but have eternal life.’ - JOHN 3:16',
#   'Almost is never enough.',
#   'Derry girls enthusiast',
#   '11:11 🤍 creo en todo lo que me hace sentir viva',
#   'LOVE❣️',
#   'mumbai🍭',
#   '♍️',
#   '\U0001fae1',
#   'Reclaim Your Wild, the Road Goes Ever On and On.',
#   'Equal rights for others does not mean less rights for you. It’s not pie! 🥧',
#   '英語、韓国語を勉強しています！',
#   'Imperfectly Empowering Girl🍁🌸 Wife💞mommy👨\u200d👩\u200d👧\u200d👦 Writer/poet✍️ Visionary🌈 Simplicity is the ultimate sophistication💯 Old soul with young eyes✨ 🎧🧘☕📚♓',
#   'Custom laser engraving',
#   '🌹🎧🎸',
#   'no but she’s a headache',
#   "Hey I'm new to Twitter! 👋🏼",
#   'rest. ( please rcbyf ^ ^ )',
#   'ETH Fund for defi digital asset #ethereum $weth $ethf WalletMovie.eth trams.eth @walletmovie @tramsdex',
#   'Lyzaa',
#   'ﮩ٨ـﮩﮩ٨ـ♡ﮩ٨ـﮩﮩ٨ـ',
#   'basically a Star Wars fan page at this point',
#   'لا إله إلا الله محمد رسول الله😍',
#   '头本，不发推，只白嫖🌝🌝',
#   '🥰♉',
#   'Independent 💪🏻💪🏻💪🏻',
#   'Idk and idc',
#   'Eres bienvenido admirar la belleza de Taylor Swift conmigo :3',
#   'cuteoptometrist',
#   '😎',
#   'Gender fluid she they it are my programs',
#   'Crazy luv for vegetables',
#   'fan account 🦦',
#   "Bonjour je suis sociale cool j'aime l'actualité Tpmp ainsi le catch et j'aime soutenir les associations et actualités stars et personnalité Merci❤☺👍❤❤❤",
#   ':p',
#   'Living Life Poetically',
#   'ip 日本',
#   'KBF Foundation is community based organization, registered as Non profit organization OUR FOCUS are on opharnage, Soccer leaque,HIV&AIDS and Human Rights',
#   'canadienne et fière de l’être !',
#   "anly 'not so kalat' moments🤡",
#   'Am good natured woman with the sense of humor and ability to understand',
#   'Software Professional',
#   'Idk',
#   'billie fan🇧🇷💗💗 Paz & Amor e um pouquinho de surto gratuito',
#   '♡ sweetest girl in town ୭̥ 💌 aquarius | 9teen 🩰ㅤㅤㅤㅤㅤ ⋆ ˖ ݁ ˖ ⋆ taylor’s version⋆ ˖ ݁ ˖ ⋆',
#   '2×2=1 Çi tê serê me ji hezkirinê tê...',
#   'Financial Literacy Advocate. A mother. A friend.',
#   '🌷',
#   'President & CEO @TCTrail @SentierTC 🚴\u200d♀️ &🚶\u200d♀️advocate @STRCycling Board Member Opinions are my own. She/Her',
#   'connoisseur, aesthete: Be realistic, expect a miracle.',
#   'کمک کردن جز زندگی من است',
#   'Welcome ppl',
#   "No doubt about it, we're in the darkest timeline.",
#   'cuenta d votos jj',
#   'viviendo las canciones de tay',
#   'Pursuer of dreams and hopes. Posts and retweets are not endorsements. Global citizen. Lives in Seattle, Washington State, USA 🇺🇸',
#   '‘For God so loved the world that he gave his one & only Son, that whoever believes in him shall not perish but have eternal life.’ - JOHN 3:16',
#   'Almost is never enough.',
#   'Derry girls enthusiast',
#   '11:11 🤍 creo en todo lo que me hace sentir viva',
#   'LOVE❣️',
#   'mumbai🍭',
#   '♍️',
#   '\U0001fae1',
#   'Reclaim Your Wild, the Road Goes Ever On and On.',
#   'Equal rights for others does not mean less rights for you. It’s not pie! 🥧',
#   '英語、韓国語を勉強しています！',
#   'Imperfectly Empowering Girl🍁🌸 Wife💞mommy👨\u200d👩\u200d👧\u200d👦 Writer/poet✍️ Visionary🌈 Simplicity is the ultimate sophistication💯 Old soul with young eyes✨ 🎧🧘☕📚♓',
#   'Custom laser engraving',
#   '🌹🎧🎸',
#   'no but she’s a headache',
#   "Hey I'm new to Twitter! 👋🏼",
#   'rest. ( please rcbyf ^ ^ )',
#   'ETH Fund for defi digital asset #ethereum $weth $ethf WalletMovie.eth trams.eth @walletmovie @tramsdex',
#   'Lyzaa',
#   'ﮩ٨ـﮩﮩ٨ـ♡ﮩ٨ـﮩﮩ٨ـ',
#   'basically a Star Wars fan page at this point',
#   'لا إله إلا الله محمد رسول الله😍',
#   '头本，不发推，只白嫖🌝🌝',
#   '🥰♉',
#   'Independent 💪🏻💪🏻💪🏻',
#   'Idk and idc',
#   'Eres bienvenido admirar la belleza de Taylor Swift conmigo :3',
#   'cuteoptometrist',
#   '😎',
#   'Gender fluid she they it are my programs',
#   'Crazy luv for vegetables',
#   'fan account 🦦',
#   "Bonjour je suis sociale cool j'aime l'actualité Tpmp ainsi le catch et j'aime soutenir les associations et actualités stars et personnalité Merci❤☺👍❤❤❤",
#   ':p',
#   'Living Life Poetically',
#   'ip 日本',
#   'KBF Foundation is community based organization, registered as Non profit organization OUR FOCUS are on opharnage, Soccer leaque,HIV&AIDS and Human Rights',
#   'canadienne et fière de l’être !',
#   "anly 'not so kalat' moments🤡",
#   'Am good natured woman with the sense of humor and ability to understand',
#   '海を渡った侍‥言葉も知らず‥未知の世界へ‥無知が故の旅だからこそ‥',
#   'Software Professional',
#   'Idk',
#   'billie fan🇧🇷💗💗 Paz & Amor e um pouquinho de surto gratuito',
#   '♡ sweetest girl in town ୭̥ 💌 aquarius | 9teen 🩰ㅤㅤㅤㅤㅤ ⋆ ˖ ݁ ˖ ⋆ taylor’s version⋆ ˖ ݁ ˖ ⋆',
#   '2×2=1 Çi tê serê me ji hezkirinê tê...',
#   'Financial Literacy Advocate. A mother. A friend.',
#   '🌷',
#   'President & CEO @TCTrail @SentierTC 🚴\u200d♀️ &🚶\u200d♀️advocate @STRCycling Board Member Opinions are my own. She/Her',
#   'connoisseur, aesthete: Be realistic, expect a miracle.',
#   'کمک کردن جز زندگی من است',
#   'Welcome ppl',
#   "No doubt about it, we're in the darkest timeline.",
#   'cuenta d votos jj',
#   'viviendo las canciones de tay',
#   'Pursuer of dreams and hopes. Posts and retweets are not endorsements. Global citizen. Lives in Seattle, Washington State, USA 🇺🇸',
#   '‘For God so loved the world that he gave his one & only Son, that whoever believes in him shall not perish but have eternal life.’ - JOHN 3:16',
#   'Almost is never enough.',
#   'Derry girls enthusiast',
#   '11:11 🤍 creo en todo lo que me hace sentir viva',
#   'LOVE❣️',
#   'mumbai🍭',
#   '♍️',
#   '\U0001fae1',
#   'Reclaim Your Wild, the Road Goes Ever On and On.',
#   'Equal rights for others does not mean less rights for you. It’s not pie! 🥧',
#   '英語、韓国語を勉強しています！',
#   'Imperfectly Empowering Girl🍁🌸 Wife💞mommy👨\u200d👩\u200d👧\u200d👦 Writer/poet✍️ Visionary🌈 Simplicity is the ultimate sophistication💯 Old soul with young eyes✨ 🎧🧘☕📚♓',
#   'Custom laser engraving',
#   '🌹🎧🎸',
#   'no but she’s a headache',
#   "Hey I'm new to Twitter! 👋🏼",
#   'rest. ( please rcbyf ^ ^ )',
#   'ETH Fund for defi digital asset #ethereum $weth $ethf WalletMovie.eth trams.eth @walletmovie @tramsdex',
#   'Lyzaa',
#   'ﮩ٨ـﮩﮩ٨ـ♡ﮩ٨ـﮩﮩ٨ـ',
#   'basically a Star Wars fan page at this point',
#   'لا إله إلا الله محمد رسول الله😍',
#   '头本，不发推，只白嫖🌝🌝',
#   '🥰♉',
#   'Independent 💪🏻💪🏻💪🏻',
#   'Idk and idc',
#   'Eres bienvenido admirar la belleza de Taylor Swift conmigo :3',
#   'cuteoptometrist',
#   '😎',
#   'Gender fluid she they it are my programs',
#   'Crazy luv for vegetables',
#   'fan account 🦦',
#   "Bonjour je suis sociale cool j'aime l'actualité Tpmp ainsi le catch et j'aime soutenir les associations et actualités stars et personnalité Merci❤☺👍❤❤❤",
#   ':p',
#   'Living Life Poetically',
#   'ip 日本',
#   'KBF Foundation is community based organization, registered as Non profit organization OUR FOCUS are on opharnage, Soccer leaque,HIV&AIDS and Human Rights',
#   'canadienne et fière de l’être !',
#   "anly 'not so kalat' moments🤡",
#   'Am good natured woman with the sense of humor and ability to understand',
#   '海を渡った侍‥言葉も知らず‥未知の世界へ‥無知が故の旅だからこそ‥',
#   'Soy Una Mujer Cristiana Y Muy Buena persona Y Sencilla 🙏😇',
#   'Software Professional',
#   'Idk',
#   'billie fan🇧🇷💗💗 Paz & Amor e um pouquinho de surto gratuito',
#   '♡ sweetest girl in town ୭̥ 💌 aquarius | 9teen 🩰ㅤㅤㅤㅤㅤ ⋆ ˖ ݁ ˖ ⋆ taylor’s version⋆ ˖ ݁ ˖ ⋆',
#   '2×2=1 Çi tê serê me ji hezkirinê tê...',
#   'Financial Literacy Advocate. A mother. A friend.',
#   '🌷',
#   'President & CEO @TCTrail @SentierTC 🚴\u200d♀️ &🚶\u200d♀️advocate @STRCycling Board Member Opinions are my own. She/Her',
#   'connoisseur, aesthete: Be realistic, expect a miracle.',
#   'کمک کردن جز زندگی من است',
#   'Welcome ppl',
#   "No doubt about it, we're in the darkest timeline.",
#   'cuenta d votos jj',
#   'viviendo las canciones de tay',
#   'Pursuer of dreams and hopes. Posts and retweets are not endorsements. Global citizen. Lives in Seattle, Washington State, USA 🇺🇸',
#   '‘For God so loved the world that he gave his one & only Son, that whoever believes in him shall not perish but have eternal life.’ - JOHN 3:16',
#   'Almost is never enough.',
#   'Derry girls enthusiast',
#   '11:11 🤍 creo en todo lo que me hace sentir viva',
#   'LOVE❣️',
#   'mumbai🍭',
#   '♍️',
#   '\U0001fae1',
#   'Reclaim Your Wild, the Road Goes Ever On and On.',
#   'Equal rights for others does not mean less rights for you. It’s not pie! 🥧',
#   '英語、韓国語を勉強しています！',
#   'Imperfectly Empowering Girl🍁🌸 Wife💞mommy👨\u200d👩\u200d👧\u200d👦 Writer/poet✍️ Visionary🌈 Simplicity is the ultimate sophistication💯 Old soul with young eyes✨ 🎧🧘☕📚♓',
#   'Custom laser engraving',
#   '🌹🎧🎸',
#   'no but she’s a headache',
#   "Hey I'm new to Twitter! 👋🏼",
#   'rest. ( please rcbyf ^ ^ )',
#   'ETH Fund for defi digital asset #ethereum $weth $ethf WalletMovie.eth trams.eth @walletmovie @tramsdex',
#   'Lyzaa',
#   'ﮩ٨ـﮩﮩ٨ـ♡ﮩ٨ـﮩﮩ٨ـ',
#   'basically a Star Wars fan page at this point',
#   'لا إله إلا الله محمد رسول الله😍',
#   '头本，不发推，只白嫖🌝🌝',
#   '🥰♉',
#   'Independent 💪🏻💪🏻💪🏻',
#   'Idk and idc',
#   'Eres bienvenido admirar la belleza de Taylor Swift conmigo :3',
#   'cuteoptometrist',
#   '😎',
#   'Gender fluid she they it are my programs',
#   'Crazy luv for vegetables',
#   'fan account 🦦',
#   "Bonjour je suis sociale cool j'aime l'actualité Tpmp ainsi le catch et j'aime soutenir les associations et actualités stars et personnalité Merci❤☺👍❤❤❤",
#   ':p',
#   'Living Life Poetically',
#   'ip 日本',
#   'KBF Foundation is community based organization, registered as Non profit organization OUR FOCUS are on opharnage, Soccer leaque,HIV&AIDS and Human Rights',
#   'canadienne et fière de l’être !',
#   "anly 'not so kalat' moments🤡",
#   'Am good natured woman with the sense of humor and ability to understand',
#   '海を渡った侍‥言葉も知らず‥未知の世界へ‥無知が故の旅だからこそ‥',
#   'Soy Una Mujer Cristiana Y Muy Buena persona Y Sencilla 🙏😇',
#   'Idk',
#   'billie fan🇧🇷💗💗 Paz & Amor e um pouquinho de surto gratuito',
#   '♡ sweetest girl in town ୭̥ 💌 aquarius | 9teen 🩰ㅤㅤㅤㅤㅤ ⋆ ˖ ݁ ˖ ⋆ taylor’s version⋆ ˖ ݁ ˖ ⋆',
#   '2×2=1 Çi tê serê me ji hezkirinê tê...',
#   'Financial Literacy Advocate. A mother. A friend.',
#   '🌷',
#   'President & CEO @TCTrail @SentierTC 🚴\u200d♀️ &🚶\u200d♀️advocate @STRCycling Board Member Opinions are my own. She/Her',
#   'connoisseur, aesthete: Be realistic, expect a miracle.',
#   'کمک کردن جز زندگی من است',
#   'Welcome ppl',
#   "No doubt about it, we're in the darkest timeline.",
#   'cuenta d votos jj',
#   'viviendo las canciones de tay',
#   'Pursuer of dreams and hopes. Posts and retweets are not endorsements. Global citizen. Lives in Seattle, Washington State, USA 🇺🇸',
#   '‘For God so loved the world that he gave his one & only Son, that whoever believes in him shall not perish but have eternal life.’ - JOHN 3:16',
#   'Almost is never enough.',
#   'Derry girls enthusiast',
#   '11:11 🤍 creo en todo lo que me hace sentir viva',
#   'LOVE❣️',
#   'mumbai🍭',
#   '♍️',
#   '\U0001fae1',
#   'Reclaim Your Wild, the Road Goes Ever On and On.',
#   'Equal rights for others does not mean less rights for you. It’s not pie! 🥧',
#   '英語、韓国語を勉強しています！',
#   'Imperfectly Empowering Girl🍁🌸 Wife💞mommy👨\u200d👩\u200d👧\u200d👦 Writer/poet✍️ Visionary🌈 Simplicity is the ultimate sophistication💯 Old soul with young eyes✨ 🎧🧘☕📚♓',
#   'Custom laser engraving',
#   '🌹🎧🎸',
#   'no but she’s a headache',
#   ...],
#  'blakeshelton': ['Life is exciting ☺',
#   "Bronze Star Army Vet, husband, father, grandfather. #golf,#MAGA, NO DM's",
#   'Love to laugh',
#   'Class of 22 I get bored easly This is my alt acc before I die',
#   'To have fun',
#   'Me',
#   'Talk too much',
#   'Gentle and calm',
#   'I’m a Christian, first off. Love to sing, cook, read and do for my family as best I can with Parkinson’s. I AM BLESSED! 😁',
#   'Sincere, and happy',
#   'mommymilkers',
#   'I like to listen to savage garden',
#   'Pocono Mountains',
#   'Social Worker and corgi lover ♥️👸🏻🙌🏽',
#   'I am an American songwriter who loves making music and wish to share it with others. I love to read, hike, and teach.',
#   'Happily married and living a happy life with him and my 6 furbabies💗 |NC|',
#   'Sports Twitter page for myself, all opinions are my own. Wisconsin born. Bucks, Brewers, AZ Cardinals.',
#   "I am a young man who has an affinity for the finer things in life. Life is fugacious so I live everyday like it's last day on earth . Each day is a celebration.",
#   'like to have a good time',
#   'I’m just a simple man trying to make my way in the universe.',
#   'Affable, kind, a bit of a jokester at times but always well intentioned.',
#   '✝️Conservative Christian🙏Jesus Christ is my savior & Donald Trump is my President 🇺🇲',
#   "I'm who I am",
#   'Rock, Metal & Marvel🤘 Pop Funko Addict😱...and I dare you to watch... https://t.co/BvgZxRX0Be',
#   '是谁来自山川湖海，囿于昼夜，厨房与爱。',
#   'I live in a toy box in your kids bedroom where I am beaten an abused.This account has music ,sports, movies. Enjoy',
#   'Mom of 3 young men, wife, Neonatal/pediRD, MedEd, lifelong learner',
#   'Gods child, artist, carpenter,',
#   'Wouldn’t say I’m special but I do like to have fun!😄',
#   "I'm me why not",
#   'Who Knows',
#   'A small business owner with passion for his trade.',
#   'Music Producer Hard Worker For International Music Shaun Walter Mitchell shaunmitchell294@gmail.com',
#   'Needing help raising money for a family in need. Link is https://t.co/LrSdHdxG5q',
#   'Having fun and hard worker',
#   'friend, mother, sister',
#   'I want to enjoy life and my Twitter...',
# ...
#   'Momma, wifey 👰\u200d♀️',
#   'Being a mom',
#   'just grooving along with a cup of coffee in my hand. Waiting for Dateline to come on. #deadhead',
#   'Retired living the life in Florida',
#   '🇺🇲 PROUD AMERICAN 💒 CATHOLIC 🔴 REPUBLICAN 📍 SANTA ANA CALIFORNIA 🏰 DISNEYLAND CAST MEMBER 🎵 COUNTRY 🥋 SPORTS FANATIC 💿 DVD COLLECTOR',
#   '.... ... .... ..',
#   'Mother of 5',
#   'retired, tired, read a lot, beach fiend',
#   "NFT enthusiast | promoter | giveaway | community maker | let's all support each other",
#   'Former U of Louisville diver, ex-marathon runner, Super Bowl XLVI volunteer, UofL Indianapolis Alumni Chapter volunteer, vacation enthusiast, animal lover, DAR',
#   'I’m a Christian, first off. Love to sing, cook, read and do for my family as best I can with Parkinson’s. I AM BLESSED! 😁',
#   'Sincere, and happy',
#   'mommymilkers',
#   'I like to listen to savage garden',
#   'Pocono Mountains',
#   'Social Worker and corgi lover ♥️👸🏻🙌🏽',
#   'I am an American songwriter who loves making music and wish to share it with others. I love to read, hike, and teach.',
#   'Happily married and living a happy life with him and my 6 furbabies💗 |NC|',
#   'Sports Twitter page for myself, all opinions are my own. Wisconsin born. Bucks, Brewers, AZ Cardinals.',
#   "I am a young man who has an affinity for the finer things in life. Life is fugacious so I live everyday like it's last day on earth . Each day is a celebration.",
#   'like to have a good time',
#   'I’m just a simple man trying to make my way in the universe.',
#   'Affable, kind, a bit of a jokester at times but always well intentioned.',
#   '✝️Conservative Christian🙏Jesus Christ is my savior & Donald Trump is my President 🇺🇲',
#   "I'm who I am",
#   'Rock, Metal & Marvel🤘 Pop Funko Addict😱...and I dare you to watch... https://t.co/BvgZxRX0Be',
#   '是谁来自山川湖海，囿于昼夜，厨房与爱。',
#   'I live in a toy box in your kids bedroom where I am beaten an abused.This account has music ,sports, movies. Enjoy',
#   'Mom of 3 young men, wife, Neonatal/pediRD, MedEd, lifelong learner',
#   'Gods child, artist, carpenter,',
#   'Wouldn’t say I’m special but I do like to have fun!😄',
#   "I'm me why not",
#   'Who Knows',
#   'A small business owner with passion for his trade.',
#   'Music Producer Hard Worker For International Music Shaun Walter Mitchell shaunmitchell294@gmail.com',
#   'Needing help raising money for a family in need. Link is https://t.co/LrSdHdxG5q',
#   'Having fun and hard worker',
#   'friend, mother, sister',
#   'I want to enjoy life and my Twitter...',
#   '@SchmittNYC fan, @gregkellyusa fan, @ChrisMcnally_ fan, @erinkrakow fan #Trump2024, #MAGA #KAGA #TeamLucaBethForever',
#   '😇🙏📿😍🤩🐶🐶🐶🐶🌺🏵🕶🌦\U0001fa9e👯\u200d♀️📺🎶👩\u200d🔬🍿🇧🇷🥦🍗😋😋🏐🥰💖💞💫🤩💯😘',
#   'Just be yourself',
#   'Praying for peace, everyone is unique in their own ways',
#   '华丽出场-星光璀璨-完美谢幕！人生就像一场演出，当我们哭着来到这个世界，舞台幕布便已经拉开，释放心底最纯真的笑容，按下心中最幸福的快门！每一个独一无二的你就是自己人生舞台的谱写者，坚持自己的人生梦想，用心创造演绎属于我们自己精彩绝伦的舞台人生梦！',
#   'Momma, wifey 👰\u200d♀️',
#   'Being a mom',
#   'just grooving along with a cup of coffee in my hand. Waiting for Dateline to come on. #deadhead',
#   'Retired living the life in Florida',
#   '🇺🇲 PROUD AMERICAN 💒 CATHOLIC 🔴 REPUBLICAN 📍 SANTA ANA CALIFORNIA 🏰 DISNEYLAND CAST MEMBER 🎵 COUNTRY 🥋 SPORTS FANATIC 💿 DVD COLLECTOR',
#   '.... ... .... ..',
#   'Mother of 5',
#   'retired, tired, read a lot, beach fiend',
#   "NFT enthusiast | promoter | giveaway | community maker | let's all support each other",
#   'Former U of Louisville diver, ex-marathon runner, Super Bowl XLVI volunteer, UofL Indianapolis Alumni Chapter volunteer, vacation enthusiast, animal lover, DAR',
#   'I’m a Christian, first off. Love to sing, cook, read and do for my family as best I can with Parkinson’s. I AM BLESSED! 😁',
#   'Sincere, and happy',
#   'mommymilkers',
#   'I like to listen to savage garden',
#   'Pocono Mountains',
#   'Social Worker and corgi lover ♥️👸🏻🙌🏽',
#   'I am an American songwriter who loves making music and wish to share it with others. I love to read, hike, and teach.',
#   'Happily married and living a happy life with him and my 6 furbabies💗 |NC|',
#   'Sports Twitter page for myself, all opinions are my own. Wisconsin born. Bucks, Brewers, AZ Cardinals.',
#   "I am a young man who has an affinity for the finer things in life. Life is fugacious so I live everyday like it's last day on earth . Each day is a celebration.",
#   'like to have a good time',
#   'I’m just a simple man trying to make my way in the universe.',
#   'Affable, kind, a bit of a jokester at times but always well intentioned.',
#   '✝️Conservative Christian🙏Jesus Christ is my savior & Donald Trump is my President 🇺🇲',
#   "I'm who I am",
#   'Rock, Metal & Marvel🤘 Pop Funko Addict😱...and I dare you to watch... https://t.co/BvgZxRX0Be',
#   '是谁来自山川湖海，囿于昼夜，厨房与爱。',
#   'I live in a toy box in your kids bedroom where I am beaten an abused.This account has music ,sports, movies. Enjoy',
#   'Mom of 3 young men, wife, Neonatal/pediRD, MedEd, lifelong learner',
#   'Gods child, artist, carpenter,',
#   'Wouldn’t say I’m special but I do like to have fun!😄',
#   "I'm me why not",
#   'Who Knows',
#   'A small business owner with passion for his trade.',
#   'Music Producer Hard Worker For International Music Shaun Walter Mitchell shaunmitchell294@gmail.com',
#   'Needing help raising money for a family in need. Link is https://t.co/LrSdHdxG5q',
#   'Having fun and hard worker',
#   'friend, mother, sister',
#   'I want to enjoy life and my Twitter...',
#   '@SchmittNYC fan, @gregkellyusa fan, @ChrisMcnally_ fan, @erinkrakow fan #Trump2024, #MAGA #KAGA #TeamLucaBethForever',
#   '😇🙏📿😍🤩🐶🐶🐶🐶🌺🏵🕶🌦\U0001fa9e👯\u200d♀️📺🎶👩\u200d🔬🍿🇧🇷🥦🍗😋😋🏐🥰💖💞💫🤩💯😘',
#   'Just be yourself',
#   'Praying for peace, everyone is unique in their own ways',
#   '华丽出场-星光璀璨-完美谢幕！人生就像一场演出，当我们哭着来到这个世界，舞台幕布便已经拉开，释放心底最纯真的笑容，按下心中最幸福的快门！每一个独一无二的你就是自己人生舞台的谱写者，坚持自己的人生梦想，用心创造演绎属于我们自己精彩绝伦的舞台人生梦！',
#   'Momma, wifey 👰\u200d♀️',
#   'Being a mom',
#   'just grooving along with a cup of coffee in my hand. Waiting for Dateline to come on. #deadhead',
#   'Retired living the life in Florida',
#   '🇺🇲 PROUD AMERICAN 💒 CATHOLIC 🔴 REPUBLICAN 📍 SANTA ANA CALIFORNIA 🏰 DISNEYLAND CAST MEMBER 🎵 COUNTRY 🥋 SPORTS FANATIC 💿 DVD COLLECTOR',
#   '.... ... .... ..',
#   'Mother of 5',
#   'retired, tired, read a lot, beach fiend',
#   "NFT enthusiast | promoter | giveaway | community maker | let's all support each other",
#   'Former U of Louisville diver, ex-marathon runner, Super Bowl XLVI volunteer, UofL Indianapolis Alumni Chapter volunteer, vacation enthusiast, animal lover, DAR',
#   'Day dreaming 💛',
#   'I’m a Christian, first off. Love to sing, cook, read and do for my family as best I can with Parkinson’s. I AM BLESSED! 😁',
#   'Sincere, and happy',
#   'mommymilkers',
#   'I like to listen to savage garden',
#   'Pocono Mountains',
#   'Social Worker and corgi lover ♥️👸🏻🙌🏽',
#   'I am an American songwriter who loves making music and wish to share it with others. I love to read, hike, and teach.',
#   'Happily married and living a happy life with him and my 6 furbabies💗 |NC|',
#   'Sports Twitter page for myself, all opinions are my own. Wisconsin born. Bucks, Brewers, AZ Cardinals.',
#   "I am a young man who has an affinity for the finer things in life. Life is fugacious so I live everyday like it's last day on earth . Each day is a celebration.",
#   'like to have a good time',
#   'I’m just a simple man trying to make my way in the universe.',
#   'Affable, kind, a bit of a jokester at times but always well intentioned.',
#   '✝️Conservative Christian🙏Jesus Christ is my savior & Donald Trump is my President 🇺🇲',
#   "I'm who I am",
#   'Rock, Metal & Marvel🤘 Pop Funko Addict😱...and I dare you to watch... https://t.co/BvgZxRX0Be',
#   '是谁来自山川湖海，囿于昼夜，厨房与爱。',
#   'I live in a toy box in your kids bedroom where I am beaten an abused.This account has music ,sports, movies. Enjoy',
#   'Mom of 3 young men, wife, Neonatal/pediRD, MedEd, lifelong learner',
#   'Gods child, artist, carpenter,',
#   'Wouldn’t say I’m special but I do like to have fun!😄',
#   "I'm me why not",
#   'Who Knows',
#   'A small business owner with passion for his trade.',
#   'Music Producer Hard Worker For International Music Shaun Walter Mitchell shaunmitchell294@gmail.com',
#   'Needing help raising money for a family in need. Link is https://t.co/LrSdHdxG5q',
#   'Having fun and hard worker',
#   'friend, mother, sister',
#   'I want to enjoy life and my Twitter...',
#   '@SchmittNYC fan, @gregkellyusa fan, @ChrisMcnally_ fan, @erinkrakow fan #Trump2024, #MAGA #KAGA #TeamLucaBethForever',
#   '😇🙏📿😍🤩🐶🐶🐶🐶🌺🏵🕶🌦\U0001fa9e👯\u200d♀️📺🎶👩\u200d🔬🍿🇧🇷🥦🍗😋😋🏐🥰💖💞💫🤩💯😘',
#   'Just be yourself',
#   'Praying for peace, everyone is unique in their own ways',
#   '华丽出场-星光璀璨-完美谢幕！人生就像一场演出，当我们哭着来到这个世界，舞台幕布便已经拉开，释放心底最纯真的笑容，按下心中最幸福的快门！每一个独一无二的你就是自己人生舞台的谱写者，坚持自己的人生梦想，用心创造演绎属于我们自己精彩绝伦的舞台人生梦！',
#   'Momma, wifey 👰\u200d♀️',
#   'Being a mom',
#   'just grooving along with a cup of coffee in my hand. Waiting for Dateline to come on. #deadhead',
#   'Retired living the life in Florida',
#   '🇺🇲 PROUD AMERICAN 💒 CATHOLIC 🔴 REPUBLICAN 📍 SANTA ANA CALIFORNIA 🏰 DISNEYLAND CAST MEMBER 🎵 COUNTRY 🥋 SPORTS FANATIC 💿 DVD COLLECTOR',
#   '.... ... .... ..',
#   'Mother of 5',
#   'retired, tired, read a lot, beach fiend',
#   "NFT enthusiast | promoter | giveaway | community maker | let's all support each other",
#   'Former U of Louisville diver, ex-marathon runner, Super Bowl XLVI volunteer, UofL Indianapolis Alumni Chapter volunteer, vacation enthusiast, animal lover, DAR',
#   'Day dreaming 💛',
#   'Midwest guy just chillin',
#   'I’m a Christian, first off. Love to sing, cook, read and do for my family as best I can with Parkinson’s. I AM BLESSED! 😁',
#   'Sincere, and happy',
#   'mommymilkers',
#   'I like to listen to savage garden',
#   'Pocono Mountains',
#   'Social Worker and corgi lover ♥️👸🏻🙌🏽',
#   'I am an American songwriter who loves making music and wish to share it with others. I love to read, hike, and teach.',
#   'Happily married and living a happy life with him and my 6 furbabies💗 |NC|',
#   'Sports Twitter page for myself, all opinions are my own. Wisconsin born. Bucks, Brewers, AZ Cardinals.',
#   "I am a young man who has an affinity for the finer things in life. Life is fugacious so I live everyday like it's last day on earth . Each day is a celebration.",
#   'like to have a good time',
#   'I’m just a simple man trying to make my way in the universe.',
#   'Affable, kind, a bit of a jokester at times but always well intentioned.',
#   '✝️Conservative Christian🙏Jesus Christ is my savior & Donald Trump is my President 🇺🇲',
#   "I'm who I am",
#   'Rock, Metal & Marvel🤘 Pop Funko Addict😱...and I dare you to watch... https://t.co/BvgZxRX0Be',
#   '是谁来自山川湖海，囿于昼夜，厨房与爱。',
#   'I live in a toy box in your kids bedroom where I am beaten an abused.This account has music ,sports, movies. Enjoy',
#   'Mom of 3 young men, wife, Neonatal/pediRD, MedEd, lifelong learner',
#   'Gods child, artist, carpenter,',
#   'Wouldn’t say I’m special but I do like to have fun!😄',
#   "I'm me why not",
#   'Who Knows',
#   'A small business owner with passion for his trade.',
#   'Music Producer Hard Worker For International Music Shaun Walter Mitchell shaunmitchell294@gmail.com',
#   'Needing help raising money for a family in need. Link is https://t.co/LrSdHdxG5q',
#   'Having fun and hard worker',
#   'friend, mother, sister',
#   'I want to enjoy life and my Twitter...',
#   '@SchmittNYC fan, @gregkellyusa fan, @ChrisMcnally_ fan, @erinkrakow fan #Trump2024, #MAGA #KAGA #TeamLucaBethForever',
#   '😇🙏📿😍🤩🐶🐶🐶🐶🌺🏵🕶🌦\U0001fa9e👯\u200d♀️📺🎶👩\u200d🔬🍿🇧🇷🥦🍗😋😋🏐🥰💖💞💫🤩💯😘',
#   'Just be yourself',
#   'Praying for peace, everyone is unique in their own ways',
#   '华丽出场-星光璀璨-完美谢幕！人生就像一场演出，当我们哭着来到这个世界，舞台幕布便已经拉开，释放心底最纯真的笑容，按下心中最幸福的快门！每一个独一无二的你就是自己人生舞台的谱写者，坚持自己的人生梦想，用心创造演绎属于我们自己精彩绝伦的舞台人生梦！',
#   'Momma, wifey 👰\u200d♀️',
#   'Being a mom',
#   'just grooving along with a cup of coffee in my hand. Waiting for Dateline to come on. #deadhead',
#   'Retired living the life in Florida',
#   '🇺🇲 PROUD AMERICAN 💒 CATHOLIC 🔴 REPUBLICAN 📍 SANTA ANA CALIFORNIA 🏰 DISNEYLAND CAST MEMBER 🎵 COUNTRY 🥋 SPORTS FANATIC 💿 DVD COLLECTOR',
#   '.... ... .... ..',
#   'Mother of 5',
#   'retired, tired, read a lot, beach fiend',
#   "NFT enthusiast | promoter | giveaway | community maker | let's all support each other",
#   'Former U of Louisville diver, ex-marathon runner, Super Bowl XLVI volunteer, UofL Indianapolis Alumni Chapter volunteer, vacation enthusiast, animal lover, DAR',
#   'Day dreaming 💛',
#   'Midwest guy just chillin',
#   'I’m a Christian, first off. Love to sing, cook, read and do for my family as best I can with Parkinson’s. I AM BLESSED! 😁',
#   'Sincere, and happy',
#   'mommymilkers',
#   'I like to listen to savage garden',
#   'Pocono Mountains',
#   'Social Worker and corgi lover ♥️👸🏻🙌🏽',
#   'I am an American songwriter who loves making music and wish to share it with others. I love to read, hike, and teach.',
#   'Happily married and living a happy life with him and my 6 furbabies💗 |NC|',
#   'Sports Twitter page for myself, all opinions are my own. Wisconsin born. Bucks, Brewers, AZ Cardinals.',
#   "I am a young man who has an affinity for the finer things in life. Life is fugacious so I live everyday like it's last day on earth . Each day is a celebration.",
#   'like to have a good time',
#   'I’m just a simple man trying to make my way in the universe.',
#   'Affable, kind, a bit of a jokester at times but always well intentioned.',
#   '✝️Conservative Christian🙏Jesus Christ is my savior & Donald Trump is my President 🇺🇲',
#   "I'm who I am",
#   'Rock, Metal & Marvel🤘 Pop Funko Addict😱...and I dare you to watch... https://t.co/BvgZxRX0Be',
#   '是谁来自山川湖海，囿于昼夜，厨房与爱。',
#   'I live in a toy box in your kids bedroom where I am beaten an abused.This account has music ,sports, movies. Enjoy',
#   'Mom of 3 young men, wife, Neonatal/pediRD, MedEd, lifelong learner',
#   'Gods child, artist, carpenter,',
#   'Wouldn’t say I’m special but I do like to have fun!😄',
#   "I'm me why not",
#   'Who Knows',
#   'A small business owner with passion for his trade.',
#   'Music Producer Hard Worker For International Music Shaun Walter Mitchell shaunmitchell294@gmail.com',
#   'Needing help raising money for a family in need. Link is https://t.co/LrSdHdxG5q',
#   'Having fun and hard worker',
#   'friend, mother, sister',
#   'I want to enjoy life and my Twitter...',
#   '@SchmittNYC fan, @gregkellyusa fan, @ChrisMcnally_ fan, @erinkrakow fan #Trump2024, #MAGA #KAGA #TeamLucaBethForever',
#   '😇🙏📿😍🤩🐶🐶🐶🐶🌺🏵🕶🌦\U0001fa9e👯\u200d♀️📺🎶👩\u200d🔬🍿🇧🇷🥦🍗😋😋🏐🥰💖💞💫🤩💯😘',
#   'Just be yourself',
#   'Praying for peace, everyone is unique in their own ways',
#   '华丽出场-星光璀璨-完美谢幕！人生就像一场演出，当我们哭着来到这个世界，舞台幕布便已经拉开，释放心底最纯真的笑容，按下心中最幸福的快门！每一个独一无二的你就是自己人生舞台的谱写者，坚持自己的人生梦想，用心创造演绎属于我们自己精彩绝伦的舞台人生梦！',
#   'Momma, wifey 👰\u200d♀️',
#   'Being a mom',
#   'just grooving along with a cup of coffee in my hand. Waiting for Dateline to come on. #deadhead',
#   'Retired living the life in Florida',
#   '🇺🇲 PROUD AMERICAN 💒 CATHOLIC 🔴 REPUBLICAN 📍 SANTA ANA CALIFORNIA 🏰 DISNEYLAND CAST MEMBER 🎵 COUNTRY 🥋 SPORTS FANATIC 💿 DVD COLLECTOR',
#   '.... ... .... ..',
#   'Mother of 5',
#   'retired, tired, read a lot, beach fiend',
#   "NFT enthusiast | promoter | giveaway | community maker | let's all support each other",
#   'Former U of Louisville diver, ex-marathon runner, Super Bowl XLVI volunteer, UofL Indianapolis Alumni Chapter volunteer, vacation enthusiast, animal lover, DAR',
#   'Day dreaming 💛',
#   'Midwest guy just chillin',
#   'Sincere, and happy',
#   'mommymilkers',
#   'I like to listen to savage garden',
#   'Pocono Mountains',
#   'Social Worker and corgi lover ♥️👸🏻🙌🏽',
#   'I am an American songwriter who loves making music and wish to share it with others. I love to read, hike, and teach.',
#   'Happily married and living a happy life with him and my 6 furbabies💗 |NC|',
#   'Sports Twitter page for myself, all opinions are my own. Wisconsin born. Bucks, Brewers, AZ Cardinals.',
#   "I am a young man who has an affinity for the finer things in life. Life is fugacious so I live everyday like it's last day on earth . Each day is a celebration.",
#   'like to have a good time',
#   'I’m just a simple man trying to make my way in the universe.',
#   ...]}

# %% [markdown]
# ## Data Cleaning
#
# Now clean and tokenize your data. Remove punctuation chacters (available in the `punctuation` object in the `string` library), split on whitespace, fold to lowercase, and remove stopwords. Store your cleaned data, which must be accessible as an interable for `descriptive_stats`, in new objects or in new columns in your data frame.

# %%
punctuation = set(punctuation)

# %%
twitterDFS.keys()
# Out:
# dict_keys(['taylorswift13', 'blakeshelton'])

# %%
# create your clean twitter data here
twitterDFS_2={}
for k, v in twitterDFS.items():
    s = " ".join(ch for ch in v if ch not in punctuation)
    s = s.lower().replace('\n',' ')
    words = s.split(' ')
    words = [w for w in words if w !='']
    s = [w for w in words if w not in sw]
    twitterDFS_2[k] = s

twitterDFS_2
# Out:
# {'taylorswift13': ['kepo',
#   'k?',
#   'cashapp:',
#   '$samellen97',
#   'vocaloid',
#   'puella',
#   'magi',
#   'madoka',
#   'magica',
#   'gakkou',
#   'gurashi!/school',
#   'live!',
#   'dennou',
#   'coil',
#   'jujutsu',
#   'kaisen',
#   'demon',
#   'slayer',
#   'spy',
#   'x',
#   'family',
#   'toilet',
#   'bound',
#   'hanako',
#   'kun',
#   '+',
#   '喜欢认识有趣的菇凉',
#   'professional',
#   'communicator.',
#   'bacon',
#   'fanatic.',
#   'social',
#   'media',
#   'practitioner.',
#   'hipster-friendly',
#   'travel',
#   'aficionado.',
#   '一个颠簸的夜晚',
#   'sinceramente,',
#   'eu',
#   'nem',
#   'sei',
#   'pq',
#   'tenho',
#   'isso...',
#   'lookin',
#   'justin',
#   'bieber',
#   'n',
#   'start',
#   'thinkin',
#   '"do',
#   'ya',
#   'know',
#   'much',
#   'love',
#   'ya🎶🇨🇦',
#   'frijolito',
#   'bb,',
#   'el',
#   'amor',
#   'de',
#   'mi',
#   'vida',
#   'heavydirtysoul',
#   'software',
#   'professional',
#   'idk',
#   'billie',
#   'fan🇧🇷💗💗',
#   'paz',
#   '&',
#   'amor',
#   'e',
#   'um',
#   'pouquinho',
#   'de',
#   'surto',
#   'gratuito',
#   '♡',
#   'sweetest',
#   'girl',
#   'town',
#   '୭̥',
#   '💌',
#   'aquarius',
#   '|',
#   '9teen',
#   '🩰ㅤㅤㅤㅤㅤ',
#   '⋆',
#   '˖',
#   '݁',
#   '˖',
#   '⋆',
#   'taylor’s',
#   'version⋆',
#   '˖',
#   '݁',
#   '˖',
#   '⋆',
#   '2×2=1',
#   'çi',
#   'tê',
#   'serê',
#   'ji',
#   'hezkirinê',
#   'tê...',
#   'financial',
#   'literacy',
#   'advocate.',
#   'mother.',
#   'friend.',
#   '🌷',
#   'president',
#   '&',
#   'ceo',
#   '@tctrail',
#   '@sentiertc',
#   '🚴\u200d♀️',
#   '&🚶\u200d♀️advocate',
#   '@strcycling',
#   'board',
#   'member',
#   'opinions',
#   'own.',
#   'she/her',
#   'connoisseur,',
#   'aesthete:',
#   'realistic,',
#   'expect',
#   'miracle.',
#   'کمک',
#   'کردن',
#   'جز',
#   'زندگی',
#   'من',
#   'است',
#   'welcome',
#   'ppl',
#   'doubt',
#   'it,',
#   "we're",
#   'darkest',
#   'timeline.',
#   'cuenta',
#   'votos',
#   'jj',
#   'viviendo',
#   'las',
#   'canciones',
#   'de',
#   'tay',
#   'pursuer',
#   'dreams',
#   'hopes.',
#   'posts',
#   'retweets',
#   'endorsements.',
#   'global',
#   'citizen.',
#   'lives',
#   'seattle,',
#   'washington',
#   'state,',
#   'usa',
#   '🇺🇸',
#   '‘for',
#   'god',
#   'loved',
#   'world',
#   'gave',
#   'one',
#   '&',
#   'son,',
#   'whoever',
#   'believes',
#   'shall',
#   'perish',
#   'eternal',
#   'life.’',
#   '-',
#   'john',
#   '3:16',
#   'almost',
#   'never',
#   'enough.',
#   'derry',
#   'girls',
#   'enthusiast',
#   '11:11',
#   '🤍',
#   'creo',
#   'en',
#   'todo',
#   'lo',
#   'que',
#   'hace',
#   'sentir',
#   'viva',
#   'love❣️',
#   'mumbai🍭',
#   '♍️',
#   '\U0001fae1',
#   'reclaim',
#   'wild,',
#   'road',
#   'goes',
#   'ever',
#   'on.',
#   'equal',
#   'rights',
#   'others',
#   'mean',
#   'less',
#   'rights',
#   'you.',
#   'it’s',
#   'pie!',
#   '🥧',
#   '英語、韓国語を勉強しています！',
#   'imperfectly',
#   'empowering',
#   'girl🍁🌸',
#   'wife💞mommy👨\u200d👩\u200d👧\u200d👦',
#   'writer/poet✍️',
#   'visionary🌈',
#   'simplicity',
#   'ultimate',
#   'sophistication💯',
#   'old',
#   'soul',
#   'young',
#   'eyes✨',
#   '🎧🧘☕📚♓',
#   'custom',
#   'laser',
#   'engraving',
#   '🌹🎧🎸',
#   'she’s',
#   'headache',
#   'hey',
#   "i'm",
#   'new',
#   'twitter!',
#   '👋🏼',
#   'rest.',
#   '(',
#   'please',
#   'rcbyf',
#   '^',
#   '^',
#   ')',
#   'eth',
#   'fund',
#   'defi',
#   'digital',
#   'asset',
#   '#ethereum',
#   '$weth',
#   '$ethf',
#   'walletmovie.eth',
#   'trams.eth',
#   '@walletmovie',
#   '@tramsdex',
#   'lyzaa',
#   'ﮩ٨ـﮩﮩ٨ـ♡ﮩ٨ـﮩﮩ٨ـ',
#   'basically',
#   'star',
#   'wars',
#   'fan',
#   'page',
#   'point',
#   'لا',
#   'إله',
#   'إلا',
#   'الله',
#   'محمد',
#   'رسول',
#   'الله😍',
#   '头本，不发推，只白嫖🌝🌝',
#   '🥰♉',
#   'independent',
#   '💪🏻💪🏻💪🏻',
#   'idk',
#   'idc',
#   'eres',
#   'bienvenido',
#   'admirar',
#   'la',
#   'belleza',
#   'de',
#   'taylor',
#   'swift',
#   'conmigo',
#   ':3',
#   'cuteoptometrist',
#   '😎',
#   'gender',
#   'fluid',
#   'programs',
#   'crazy',
#   'luv',
#   'vegetables',
#   'cashapp:',
#   '$samellen97',
#   'vocaloid',
#   'puella',
#   'magi',
#   'madoka',
#   'magica',
#   'gakkou',
#   'gurashi!/school',
#   'live!',
#   'dennou',
#   'coil',
#   'jujutsu',
#   'kaisen',
#   'demon',
#   'slayer',
#   'spy',
#   'x',
#   'family',
#   'toilet',
#   'bound',
#   'hanako',
#   'kun',
#   '+',
#   '喜欢认识有趣的菇凉',
#   'professional',
#   'communicator.',
#   'bacon',
#   'fanatic.',
#   'social',
#   'media',
#   'practitioner.',
#   'hipster-friendly',
#   'travel',
#   'aficionado.',
#   '一个颠簸的夜晚',
#   'sinceramente,',
#   'eu',
#   'nem',
#   'sei',
#   'pq',
#   'tenho',
#   'isso...',
#   'lookin',
#   'justin',
#   'bieber',
#   'n',
#   'start',
#   'thinkin',
#   '"do',
#   'ya',
#   'know',
#   'much',
#   'love',
#   'ya🎶🇨🇦',
#   'frijolito',
#   'bb,',
#   'el',
#   'amor',
#   'de',
#   'mi',
#   'vida',
#   'heavydirtysoul',
#   'software',
#   'professional',
#   'idk',
#   'billie',
#   'fan🇧🇷💗💗',
#   'paz',
#   '&',
#   'amor',
#   'e',
#   'um',
#   'pouquinho',
#   'de',
#   'surto',
#   'gratuito',
#   '♡',
#   'sweetest',
#   'girl',
#   'town',
#   '୭̥',
#   '💌',
#   'aquarius',
#   '|',
#   '9teen',
#   '🩰ㅤㅤㅤㅤㅤ',
#   '⋆',
#   '˖',
#   '݁',
#   '˖',
#   '⋆',
#   'taylor’s',
#   'version⋆',
#   '˖',
#   '݁',
#   '˖',
#   '⋆',
#   '2×2=1',
#   'çi',
#   'tê',
#   'serê',
#   'ji',
#   'hezkirinê',
#   'tê...',
#   'financial',
#   'literacy',
#   'advocate.',
#   'mother.',
#   'friend.',
#   '🌷',
#   'president',
#   '&',
#   'ceo',
#   '@tctrail',
#   '@sentiertc',
#   '🚴\u200d♀️',
#   '&🚶\u200d♀️advocate',
#   '@strcycling',
#   'board',
#   'member',
#   'opinions',
#   'own.',
#   'she/her',
#   'connoisseur,',
#   'aesthete:',
#   'realistic,',
#   'expect',
#   'miracle.',
#   'کمک',
#   'کردن',
#   'جز',
#   'زندگی',
#   'من',
#   'است',
#   'welcome',
#   'ppl',
#   'doubt',
#   'it,',
#   "we're",
#   'darkest',
#   'timeline.',
#   'cuenta',
#   'votos',
#   'jj',
#   'viviendo',
#   'las',
#   'canciones',
#   'de',
#   'tay',
#   'pursuer',
#   'dreams',
#   'hopes.',
#   'posts',
#   'retweets',
#   'endorsements.',
#   'global',
#   'citizen.',
#   'lives',
#   'seattle,',
#   'washington',
#   'state,',
#   'usa',
#   '🇺🇸',
#   '‘for',
#   'god',
#   'loved',
#   'world',
#   'gave',
#   'one',
#   '&',
#   'son,',
#   'whoever',
#   'believes',
#   'shall',
#   'perish',
#   'eternal',
#   'life.’',
#   '-',
#   'john',
#   '3:16',
#   'almost',
#   'never',
#   'enough.',
#   'derry',
#   'girls',
#   'enthusiast',
#   '11:11',
#   '🤍',
#   'creo',
#   'en',
#   'todo',
#   'lo',
#   'que',
#   'hace',
#   'sentir',
#   'viva',
#   'love❣️',
#   'mumbai🍭',
#   '♍️',
#   '\U0001fae1',
#   'reclaim',
#   'wild,',
#   'road',
#   'goes',
#   'ever',
#   'on.',
#   'equal',
#   'rights',
#   'others',
#   'mean',
#   'less',
#   'rights',
#   'you.',
#   'it’s',
#   'pie!',
#   '🥧',
#   '英語、韓国語を勉強しています！',
#   'imperfectly',
#   'empowering',
#   'girl🍁🌸',
#   'wife💞mommy👨\u200d👩\u200d👧\u200d👦',
#   'writer/poet✍️',
#   'visionary🌈',
#   'simplicity',
#   'ultimate',
#   'sophistication💯',
#   'old',
#   'soul',
#   'young',
#   'eyes✨',
#   '🎧🧘☕📚♓',
#   'custom',
#   'laser',
#   'engraving',
#   '🌹🎧🎸',
#   'she’s',
#   'headache',
#   'hey',
#   "i'm",
#   'new',
#   'twitter!',
#   '👋🏼',
#   'rest.',
#   '(',
#   'please',
#   'rcbyf',
#   '^',
#   '^',
#   ')',
#   'eth',
#   'fund',
#   'defi',
#   'digital',
#   'asset',
#   '#ethereum',
#   '$weth',
#   '$ethf',
#   'walletmovie.eth',
#   'trams.eth',
#   '@walletmovie',
#   '@tramsdex',
#   'lyzaa',
#   'ﮩ٨ـﮩﮩ٨ـ♡ﮩ٨ـﮩﮩ٨ـ',
#   'basically',
#   'star',
#   'wars',
#   'fan',
#   'page',
#   'point',
#   'لا',
#   'إله',
#   'إلا',
#   'الله',
#   'محمد',
#   'رسول',
#   'الله😍',
#   '头本，不发推，只白嫖🌝🌝',
#   '🥰♉',
#   'independent',
#   '💪🏻💪🏻💪🏻',
#   'idk',
#   'idc',
#   'eres',
#   'bienvenido',
#   'admirar',
#   'la',
#   'belleza',
#   'de',
#   'taylor',
#   'swift',
#   'conmigo',
#   ':3',
#   'cuteoptometrist',
#   '😎',
#   'gender',
#   'fluid',
#   'programs',
#   'crazy',
#   'luv',
#   'vegetables',
#   'fan',
#   'account',
#   '🦦',
#   'vocaloid',
#   'puella',
#   'magi',
#   'madoka',
#   'magica',
#   'gakkou',
#   'gurashi!/school',
#   'live!',
#   'dennou',
#   'coil',
#   'jujutsu',
#   'kaisen',
#   'demon',
#   'slayer',
#   'spy',
#   'x',
#   'family',
#   'toilet',
#   'bound',
#   'hanako',
#   'kun',
#   '+',
#   '喜欢认识有趣的菇凉',
#   'professional',
#   'communicator.',
#   'bacon',
#   'fanatic.',
#   'social',
#   'media',
#   'practitioner.',
#   'hipster-friendly',
#   'travel',
#   'aficionado.',
#   '一个颠簸的夜晚',
#   'sinceramente,',
#   'eu',
#   'nem',
#   'sei',
#   'pq',
#   'tenho',
#   'isso...',
#   'lookin',
#   'justin',
#   'bieber',
#   'n',
#   'start',
#   'thinkin',
#   '"do',
#   'ya',
#   'know',
#   'much',
#   'love',
#   'ya🎶🇨🇦',
#   'frijolito',
#   'bb,',
#   'el',
#   'amor',
#   'de',
#   'mi',
#   'vida',
#   'heavydirtysoul',
#   'software',
#   'professional',
#   'idk',
#   'billie',
#   'fan🇧🇷💗💗',
#   'paz',
#   '&',
#   'amor',
#   'e',
#   'um',
#   'pouquinho',
#   'de',
#   'surto',
#   'gratuito',
#   '♡',
#   'sweetest',
#   'girl',
#   'town',
#   '୭̥',
#   '💌',
#   'aquarius',
#   '|',
#   '9teen',
#   '🩰ㅤㅤㅤㅤㅤ',
#   '⋆',
#   '˖',
#   '݁',
#   '˖',
#   '⋆',
#   'taylor’s',
#   'version⋆',
#   '˖',
#   '݁',
#   '˖',
#   '⋆',
#   '2×2=1',
#   'çi',
#   'tê',
#   'serê',
#   'ji',
#   'hezkirinê',
#   'tê...',
#   'financial',
#   'literacy',
#   'advocate.',
#   'mother.',
#   'friend.',
#   '🌷',
#   'president',
#   '&',
#   'ceo',
#   '@tctrail',
#   '@sentiertc',
#   '🚴\u200d♀️',
#   '&🚶\u200d♀️advocate',
#   '@strcycling',
#   'board',
#   'member',
#   'opinions',
#   'own.',
#   'she/her',
#   'connoisseur,',
#   'aesthete:',
#   'realistic,',
#   'expect',
#   'miracle.',
#   'کمک',
#   'کردن',
#   'جز',
#   'زندگی',
#   'من',
#   'است',
#   'welcome',
#   'ppl',
#   'doubt',
#   'it,',
#   "we're",
#   'darkest',
#   'timeline.',
#   'cuenta',
#   'votos',
#   'jj',
#   'viviendo',
#   'las',
#   'canciones',
#   'de',
#   'tay',
#   'pursuer',
#   'dreams',
#   'hopes.',
#   'posts',
#   'retweets',
#   'endorsements.',
#   'global',
#   'citizen.',
#   'lives',
#   'seattle,',
#   'washington',
#   'state,',
#   'usa',
#   '🇺🇸',
#   '‘for',
#   'god',
#   'loved',
#   'world',
#   'gave',
#   'one',
#   '&',
#   'son,',
#   'whoever',
#   'believes',
#   'shall',
#   'perish',
#   'eternal',
#   'life.’',
#   '-',
#   'john',
#   '3:16',
#   'almost',
#   'never',
#   'enough.',
#   'derry',
#   'girls',
#   'enthusiast',
#   '11:11',
#   '🤍',
#   'creo',
#   'en',
#   'todo',
#   'lo',
#   'que',
#   'hace',
#   'sentir',
#   'viva',
#   'love❣️',
#   'mumbai🍭',
#   '♍️',
#   '\U0001fae1',
#   'reclaim',
#   'wild,',
#   'road',
#   'goes',
#   'ever',
#   'on.',
#   'equal',
#   'rights',
#   'others',
#   'mean',
#   'less',
#   'rights',
#   'you.',
#   'it’s',
#   'pie!',
#   '🥧',
#   '英語、韓国語を勉強しています！',
#   'imperfectly',
#   'empowering',
#   'girl🍁🌸',
#   'wife💞mommy👨\u200d👩\u200d👧\u200d👦',
#   'writer/poet✍️',
#   'visionary🌈',
#   'simplicity',
#   'ultimate',
#   'sophistication💯',
#   'old',
#   'soul',
#   'young',
#   'eyes✨',
#   '🎧🧘☕📚♓',
#   'custom',
#   'laser',
#   'engraving',
#   '🌹🎧🎸',
#   'she’s',
#   'headache',
#   'hey',
#   "i'm",
#   'new',
#   'twitter!',
#   '👋🏼',
#   'rest.',
#   '(',
#   'please',
#   'rcbyf',
#   '^',
#   '^',
#   ')',
#   'eth',
#   'fund',
#   'defi',
#   'digital',
#   'asset',
#   '#ethereum',
#   '$weth',
#   '$ethf',
#   'walletmovie.eth',
#   'trams.eth',
#   '@walletmovie',
#   '@tramsdex',
#   'lyzaa',
#   'ﮩ٨ـﮩﮩ٨ـ♡ﮩ٨ـﮩﮩ٨ـ',
#   'basically',
#   'star',
#   'wars',
#   'fan',
#   'page',
#   'point',
#   'لا',
#   'إله',
#   'إلا',
#   'الله',
#   'محمد',
#   'رسول',
#   'الله😍',
#   '头本，不发推，只白嫖🌝🌝',
#   '🥰♉',
#   'independent',
#   '💪🏻💪🏻💪🏻',
#   'idk',
#   'idc',
#   'eres',
#   'bienvenido',
#   'admirar',
#   'la',
#   'belleza',
#   'de',
#   'taylor',
#   'swift',
#   'conmigo',
#   ':3',
#   'cuteoptometrist',
#   '😎',
#   'gender',
#   'fluid',
#   'programs',
#   'crazy',
#   'luv',
#   'vegetables',
#   'fan',
#   'account',
#   '🦦',
#   'bonjour',
#   'je',
#   'suis',
#   'sociale',
#   'cool',
#   "j'aime",
#   "l'actualité",
#   'tpmp',
#   'ainsi',
#   'le',
#   'catch',
#   'et',
#   "j'aime",
#   'soutenir',
#   'les',
#   'associations',
#   'et',
#   'actualités',
#   'stars',
#   'et',
#   'personnalité',
#   'merci❤☺👍❤❤❤',
#   'vocaloid',
#   'puella',
#   'magi',
#   'madoka',
#   'magica',
#   'gakkou',
#   'gurashi!/school',
#   'live!',
#   'dennou',
#   'coil',
#   'jujutsu',
#   'kaisen',
#   'demon',
#   'slayer',
#   'spy',
#   'x',
#   'family',
#   'toilet',
#   'bound',
#   'hanako',
#   'kun',
#   '+',
#   '喜欢认识有趣的菇凉',
#   'professional',
#   'communicator.',
#   'bacon',
#   'fanatic.',
#   'social',
#   'media',
#   'practitioner.',
#   'hipster-friendly',
#   'travel',
#   'aficionado.',
#   '一个颠簸的夜晚',
#   'sinceramente,',
#   'eu',
#   'nem',
#   'sei',
#   'pq',
#   'tenho',
#   'isso...',
#   'lookin',
#   'justin',
#   'bieber',
#   'n',
#   'start',
#   'thinkin',
#   '"do',
#   'ya',
#   'know',
#   'much',
#   'love',
#   'ya🎶🇨🇦',
#   'frijolito',
#   'bb,',
#   'el',
#   'amor',
#   'de',
#   'mi',
#   'vida',
#   'heavydirtysoul',
#   'software',
#   'professional',
#   'idk',
#   'billie',
#   'fan🇧🇷💗💗',
#   'paz',
#   '&',
#   'amor',
#   ...],
#  'blakeshelton': ['life',
#   'exciting',
#   '☺',
#   'bronze',
#   'star',
#   'army',
#   'vet,',
#   'husband,',
#   'father,',
#   'grandfather.',
#   '#golf,#maga,',
#   "dm's",
#   'love',
#   'laugh',
#   'class',
#   '22',
#   'get',
#   'bored',
#   'easly',
#   'alt',
#   'acc',
#   'die',
#   'fun',
#   'talk',
#   'much',
#   'gentle',
#   'calm',
#   'i’m',
#   'christian,',
#   'first',
#   'off.',
#   'love',
#   'sing,',
#   'cook,',
#   'read',
#   'family',
#   'best',
#   'parkinson’s.',
#   'blessed!',
#   '😁',
#   'sincere,',
#   'happy',
#   'mommymilkers',
#   'like',
#   'listen',
#   'savage',
#   'garden',
#   'pocono',
#   'mountains',
#   'social',
#   'worker',
#   'corgi',
#   'lover',
#   '♥️👸🏻🙌🏽',
#   'american',
#   'songwriter',
#   'loves',
#   'making',
#   'music',
#   'wish',
#   'share',
#   'others.',
#   'love',
#   'read,',
#   'hike,',
#   'teach.',
#   'happily',
#   'married',
#   'living',
#   'happy',
#   'life',
#   '6',
#   'furbabies💗',
#   '|nc|',
#   'sports',
#   'twitter',
#   'page',
#   'myself,',
#   'opinions',
#   'own.',
#   'wisconsin',
#   'born.',
#   'bucks,',
#   'brewers,',
#   'az',
#   'cardinals.',
#   'young',
#   'man',
#   'affinity',
#   'finer',
#   'things',
#   'life.',
#   'life',
#   'fugacious',
#   'live',
#   'everyday',
#   'like',
#   'last',
#   'day',
#   'earth',
#   '.',
#   'day',
#   'celebration.',
#   'like',
#   'good',
#   'time',
#   'i’m',
#   'simple',
#   'man',
#   'trying',
#   'make',
#   'way',
#   'universe.',
#   'affable,',
#   'kind,',
#   'bit',
#   'jokester',
#   'times',
#   'always',
#   'well',
#   'intentioned.',
#   '✝️conservative',
#   'christian🙏jesus',
#   'christ',
#   'savior',
#   '&',
#   'donald',
#   'trump',
#   'president',
#   '🇺🇲',
#   "i'm",
#   'rock,',
#   'metal',
#   '&',
#   'marvel🤘',
#   'pop',
#   'funko',
#   'addict😱...and',
#   'dare',
#   'watch...',
#   'https://t.co/bvgzxrx0be',
#   '是谁来自山川湖海，囿于昼夜，厨房与爱。',
#   'live',
#   'toy',
#   'box',
#   'kids',
#   'bedroom',
#   'beaten',
#   'abused.this',
#   'account',
#   'music',
#   ',sports,',
#   'movies.',
#   'enjoy',
#   'mom',
#   '3',
#   'young',
#   'men,',
#   'wife,',
#   'neonatal/pedird,',
#   'meded,',
#   'lifelong',
#   'learner',
#   'gods',
#   'child,',
#   'artist,',
#   'carpenter,',
#   'wouldn’t',
#   'say',
#   'i’m',
#   'special',
#   'like',
#   'fun!😄',
#   "i'm",
#   'knows',
#   'small',
#   'business',
#   'owner',
#   'passion',
#   'trade.',
#   'music',
#   'producer',
#   'hard',
#   'worker',
#   'international',
#   'music',
#   'shaun',
#   'walter',
#   'mitchell',
#   'shaunmitchell294@gmail.com',
#   'needing',
#   'help',
#   'raising',
#   'money',
#   'family',
#   'need.',
#   'link',
#   'https://t.co/lrsdhdxg5q',
#   'fun',
#   'hard',
#   'worker',
#   'friend,',
#   'mother,',
#   'sister',
#   'want',
#   'enjoy',
#   'life',
#   'twitter...',
#   '@schmittnyc',
#   'fan,',
#   '@gregkellyusa',
#   'fan,',
#   '@chrismcnally_',
#   'fan,',
#   '@erinkrakow',
#   'fan',
#   '#trump2024,',
#   '#maga',
#   '#kaga',
#   '#teamlucabethforever',
#   '😇🙏📿😍🤩🐶🐶🐶🐶🌺🏵🕶🌦\U0001fa9e👯\u200d♀️📺🎶👩\u200d🔬🍿🇧🇷🥦🍗😋😋🏐🥰💖💞💫🤩💯😘',
#   'praying',
#   'peace,',
#   'everyone',
#   'unique',
#   'ways',
#   '华丽出场-星光璀璨-完美谢幕！人生就像一场演出，当我们哭着来到这个世界，舞台幕布便已经拉开，释放心底最纯真的笑容，按下心中最幸福的快门！每一个独一无二的你就是自己人生舞台的谱写者，坚持自己的人生梦想，用心创造演绎属于我们自己精彩绝伦的舞台人生梦！',
#   'life',
#   'exciting',
#   '☺',
#   'bronze',
#   'star',
#   'army',
#   'vet,',
#   'husband,',
#   'father,',
#   'grandfather.',
#   '#golf,#maga,',
#   "dm's",
#   'love',
#   'laugh',
#   'class',
#   '22',
#   'get',
#   'bored',
#   'easly',
#   'alt',
#   'acc',
#   'die',
#   'fun',
#   'talk',
#   'much',
#   'gentle',
#   'calm',
#   'i’m',
#   'christian,',
#   'first',
#   'off.',
#   'love',
#   'sing,',
#   'cook,',
#   'read',
#   'family',
#   'best',
#   'parkinson’s.',
#   'blessed!',
#   '😁',
#   'sincere,',
#   'happy',
#   'mommymilkers',
#   'like',
#   'listen',
#   'savage',
#   'garden',
#   'pocono',
#   'mountains',
#   'social',
#   'worker',
#   'corgi',
#   'lover',
#   '♥️👸🏻🙌🏽',
#   'american',
#   'songwriter',
#   'loves',
#   'making',
#   'music',
#   'wish',
#   'share',
#   'others.',
#   'love',
#   'read,',
#   'hike,',
#   'teach.',
#   'happily',
#   'married',
#   'living',
#   'happy',
#   'life',
#   '6',
#   'furbabies💗',
#   '|nc|',
#   'sports',
#   'twitter',
#   'page',
#   'myself,',
#   'opinions',
#   'own.',
#   'wisconsin',
#   'born.',
#   'bucks,',
#   'brewers,',
#   'az',
#   'cardinals.',
#   'young',
#   'man',
#   'affinity',
#   'finer',
#   'things',
#   'life.',
#   'life',
#   'fugacious',
#   'live',
#   'everyday',
#   'like',
#   'last',
#   'day',
#   'earth',
#   '.',
#   'day',
#   'celebration.',
#   'like',
#   'good',
#   'time',
#   'i’m',
#   'simple',
#   'man',
#   'trying',
#   'make',
#   'way',
#   'universe.',
#   'affable,',
#   'kind,',
#   'bit',
#   'jokester',
#   'times',
#   'always',
#   'well',
#   'intentioned.',
#   '✝️conservative',
#   'christian🙏jesus',
#   'christ',
#   'savior',
#   '&',
#   'donald',
#   'trump',
#   'president',
#   '🇺🇲',
#   "i'm",
#   'rock,',
#   'metal',
#   '&',
#   'marvel🤘',
#   'pop',
#   'funko',
#   'addict😱...and',
#   'dare',
#   'watch...',
#   'https://t.co/bvgzxrx0be',
#   '是谁来自山川湖海，囿于昼夜，厨房与爱。',
#   'live',
#   'toy',
#   'box',
#   'kids',
#   'bedroom',
#   'beaten',
#   'abused.this',
#   'account',
#   'music',
#   ',sports,',
#   'movies.',
#   'enjoy',
#   'mom',
#   '3',
#   'young',
#   'men,',
#   'wife,',
#   'neonatal/pedird,',
#   'meded,',
#   'lifelong',
#   'learner',
#   'gods',
#   'child,',
#   'artist,',
#   'carpenter,',
#   'wouldn’t',
#   'say',
#   'i’m',
#   'special',
#   'like',
#   'fun!😄',
#   "i'm",
#   'knows',
#   'small',
#   'business',
#   'owner',
#   'passion',
#   'trade.',
#   'music',
#   'producer',
#   'hard',
#   'worker',
#   'international',
#   'music',
#   'shaun',
#   'walter',
#   'mitchell',
#   'shaunmitchell294@gmail.com',
#   'needing',
#   'help',
#   'raising',
#   'money',
#   'family',
#   'need.',
#   'link',
#   'https://t.co/lrsdhdxg5q',
#   'fun',
#   'hard',
#   'worker',
#   'friend,',
#   'mother,',
#   'sister',
#   'want',
#   'enjoy',
#   'life',
#   'twitter...',
#   '@schmittnyc',
#   'fan,',
#   '@gregkellyusa',
#   'fan,',
#   '@chrismcnally_',
#   'fan,',
#   '@erinkrakow',
#   'fan',
#   '#trump2024,',
#   '#maga',
#   '#kaga',
#   '#teamlucabethforever',
#   '😇🙏📿😍🤩🐶🐶🐶🐶🌺🏵🕶🌦\U0001fa9e👯\u200d♀️📺🎶👩\u200d🔬🍿🇧🇷🥦🍗😋😋🏐🥰💖💞💫🤩💯😘',
#   'praying',
#   'peace,',
#   'everyone',
#   'unique',
#   'ways',
#   '华丽出场-星光璀璨-完美谢幕！人生就像一场演出，当我们哭着来到这个世界，舞台幕布便已经拉开，释放心底最纯真的笑容，按下心中最幸福的快门！每一个独一无二的你就是自己人生舞台的谱写者，坚持自己的人生梦想，用心创造演绎属于我们自己精彩绝伦的舞台人生梦！',
#   'momma,',
#   'wifey',
#   '👰\u200d♀️',
#   'life',
#   'exciting',
#   '☺',
#   'bronze',
#   'star',
#   'army',
#   'vet,',
#   'husband,',
#   'father,',
#   'grandfather.',
#   '#golf,#maga,',
#   "dm's",
#   'love',
#   'laugh',
#   'class',
#   '22',
#   'get',
#   'bored',
#   'easly',
#   'alt',
#   'acc',
#   'die',
#   'fun',
#   'talk',
#   'much',
#   'gentle',
#   'calm',
#   'i’m',
#   'christian,',
#   'first',
#   'off.',
#   'love',
#   'sing,',
#   'cook,',
#   'read',
#   'family',
#   'best',
#   'parkinson’s.',
#   'blessed!',
#   '😁',
#   'sincere,',
#   'happy',
#   'mommymilkers',
#   'like',
#   'listen',
#   'savage',
#   'garden',
#   'pocono',
#   'mountains',
#   'social',
#   'worker',
#   'corgi',
#   'lover',
#   '♥️👸🏻🙌🏽',
#   'american',
#   'songwriter',
#   'loves',
#   'making',
#   'music',
#   'wish',
#   'share',
#   'others.',
#   'love',
#   'read,',
#   'hike,',
#   'teach.',
#   'happily',
#   'married',
#   'living',
#   'happy',
#   'life',
#   '6',
#   'furbabies💗',
#   '|nc|',
#   'sports',
#   'twitter',
#   'page',
#   'myself,',
#   'opinions',
#   'own.',
#   'wisconsin',
#   'born.',
#   'bucks,',
#   'brewers,',
#   'az',
#   'cardinals.',
#   'young',
#   'man',
#   'affinity',
#   'finer',
#   'things',
#   'life.',
#   'life',
#   'fugacious',
#   'live',
#   'everyday',
#   'like',
#   'last',
#   'day',
#   'earth',
#   '.',
#   'day',
#   'celebration.',
#   'like',
#   'good',
#   'time',
#   'i’m',
#   'simple',
#   'man',
#   'trying',
#   'make',
#   'way',
#   'universe.',
#   'affable,',
#   'kind,',
#   'bit',
#   'jokester',
#   'times',
#   'always',
#   'well',
#   'intentioned.',
#   '✝️conservative',
#   'christian🙏jesus',
#   'christ',
#   'savior',
#   '&',
#   'donald',
#   'trump',
#   'president',
#   '🇺🇲',
#   "i'm",
#   'rock,',
#   'metal',
#   '&',
#   'marvel🤘',
#   'pop',
#   'funko',
#   'addict😱...and',
#   'dare',
#   'watch...',
#   'https://t.co/bvgzxrx0be',
#   '是谁来自山川湖海，囿于昼夜，厨房与爱。',
#   'live',
#   'toy',
#   'box',
#   'kids',
#   'bedroom',
#   'beaten',
#   'abused.this',
#   'account',
#   'music',
#   ',sports,',
#   'movies.',
#   'enjoy',
#   'mom',
#   '3',
#   'young',
#   'men,',
#   'wife,',
#   'neonatal/pedird,',
#   'meded,',
#   'lifelong',
#   'learner',
#   'gods',
#   'child,',
#   'artist,',
#   'carpenter,',
#   'wouldn’t',
#   'say',
#   'i’m',
#   'special',
#   'like',
#   'fun!😄',
#   "i'm",
#   'knows',
#   'small',
#   'business',
#   'owner',
#   'passion',
#   'trade.',
#   'music',
#   'producer',
#   'hard',
#   'worker',
#   'international',
#   'music',
#   'shaun',
#   'walter',
#   'mitchell',
#   'shaunmitchell294@gmail.com',
#   'needing',
#   'help',
#   'raising',
#   'money',
#   'family',
#   'need.',
#   'link',
#   'https://t.co/lrsdhdxg5q',
#   'fun',
#   'hard',
#   'worker',
#   'friend,',
#   'mother,',
#   'sister',
#   'want',
#   'enjoy',
#   'life',
#   'twitter...',
#   '@schmittnyc',
#   'fan,',
#   '@gregkellyusa',
#   'fan,',
#   '@chrismcnally_',
#   'fan,',
#   '@erinkrakow',
#   'fan',
#   '#trump2024,',
#   '#maga',
#   '#kaga',
#   '#teamlucabethforever',
#   '😇🙏📿😍🤩🐶🐶🐶🐶🌺🏵🕶🌦\U0001fa9e👯\u200d♀️📺🎶👩\u200d🔬🍿🇧🇷🥦🍗😋😋🏐🥰💖💞💫🤩💯😘',
#   'praying',
#   'peace,',
#   'everyone',
#   'unique',
#   'ways',
#   '华丽出场-星光璀璨-完美谢幕！人生就像一场演出，当我们哭着来到这个世界，舞台幕布便已经拉开，释放心底最纯真的笑容，按下心中最幸福的快门！每一个独一无二的你就是自己人生舞台的谱写者，坚持自己的人生梦想，用心创造演绎属于我们自己精彩绝伦的舞台人生梦！',
#   'momma,',
#   'wifey',
#   '👰\u200d♀️',
#   'mom',
#   'bronze',
#   'star',
#   'army',
#   'vet,',
#   'husband,',
#   'father,',
#   'grandfather.',
#   '#golf,#maga,',
#   "dm's",
#   'love',
#   'laugh',
#   'class',
#   '22',
#   'get',
#   'bored',
#   'easly',
#   'alt',
#   'acc',
#   'die',
#   'fun',
#   'talk',
#   'much',
#   'gentle',
#   'calm',
#   'i’m',
#   'christian,',
#   'first',
#   'off.',
#   'love',
#   'sing,',
#   'cook,',
#   'read',
#   'family',
#   'best',
#   'parkinson’s.',
#   'blessed!',
#   '😁',
#   'sincere,',
#   'happy',
#   'mommymilkers',
#   'like',
#   'listen',
#   'savage',
#   'garden',
#   'pocono',
#   'mountains',
#   'social',
#   'worker',
#   'corgi',
#   'lover',
#   '♥️👸🏻🙌🏽',
#   'american',
#   'songwriter',
#   'loves',
#   'making',
#   'music',
#   'wish',
#   'share',
#   'others.',
#   'love',
#   'read,',
#   'hike,',
#   'teach.',
#   'happily',
#   'married',
#   'living',
#   'happy',
#   'life',
#   '6',
#   'furbabies💗',
#   '|nc|',
#   'sports',
#   'twitter',
#   'page',
#   'myself,',
#   'opinions',
#   'own.',
#   'wisconsin',
#   'born.',
#   'bucks,',
#   'brewers,',
#   'az',
#   'cardinals.',
#   'young',
#   'man',
#   'affinity',
#   'finer',
#   'things',
#   'life.',
#   'life',
#   'fugacious',
#   'live',
#   'everyday',
#   'like',
#   'last',
#   'day',
#   'earth',
#   '.',
#   'day',
#   'celebration.',
#   'like',
#   'good',
#   'time',
#   'i’m',
#   'simple',
#   'man',
#   'trying',
#   'make',
#   'way',
#   'universe.',
#   'affable,',
#   'kind,',
#   'bit',
#   'jokester',
#   'times',
#   'always',
#   'well',
#   'intentioned.',
#   '✝️conservative',
#   'christian🙏jesus',
#   'christ',
#   'savior',
#   '&',
#   'donald',
#   'trump',
#   'president',
#   '🇺🇲',
#   "i'm",
#   'rock,',
#   'metal',
#   '&',
#   'marvel🤘',
#   'pop',
#   'funko',
#   'addict😱...and',
#   'dare',
#   'watch...',
#   'https://t.co/bvgzxrx0be',
#   '是谁来自山川湖海，囿于昼夜，厨房与爱。',
#   'live',
#   'toy',
#   'box',
#   'kids',
#   'bedroom',
#   'beaten',
#   'abused.this',
#   'account',
#   'music',
#   ',sports,',
#   'movies.',
#   'enjoy',
#   'mom',
#   '3',
#   'young',
#   'men,',
#   'wife,',
#   'neonatal/pedird,',
#   'meded,',
#   'lifelong',
#   'learner',
#   'gods',
#   'child,',
#   'artist,',
#   'carpenter,',
#   'wouldn’t',
#   'say',
#   'i’m',
#   'special',
#   'like',
#   'fun!😄',
#   "i'm",
#   'knows',
#   'small',
#   'business',
#   'owner',
#   'passion',
#   'trade.',
#   'music',
#   'producer',
#   'hard',
#   'worker',
#   'international',
#   'music',
#   'shaun',
#   'walter',
#   'mitchell',
#   'shaunmitchell294@gmail.com',
#   'needing',
#   'help',
#   'raising',
#   'money',
#   'family',
#   'need.',
#   'link',
#   'https://t.co/lrsdhdxg5q',
#   'fun',
#   'hard',
#   'worker',
#   'friend,',
#   'mother,',
#   'sister',
#   'want',
#   'enjoy',
#   'life',
#   'twitter...',
#   '@schmittnyc',
#   'fan,',
#   '@gregkellyusa',
#   'fan,',
#   '@chrismcnally_',
#   'fan,',
#   '@erinkrakow',
#   'fan',
#   '#trump2024,',
#   '#maga',
#   '#kaga',
#   '#teamlucabethforever',
#   '😇🙏📿😍🤩🐶🐶🐶🐶🌺🏵🕶🌦\U0001fa9e👯\u200d♀️📺🎶👩\u200d🔬🍿🇧🇷🥦🍗😋😋🏐🥰💖💞💫🤩💯😘',
#   'praying',
#   'peace,',
#   'everyone',
#   'unique',
#   'ways',
#   '华丽出场-星光璀璨-完美谢幕！人生就像一场演出，当我们哭着来到这个世界，舞台幕布便已经拉开，释放心底最纯真的笑容，按下心中最幸福的快门！每一个独一无二的你就是自己人生舞台的谱写者，坚持自己的人生梦想，用心创造演绎属于我们自己精彩绝伦的舞台人生梦！',
#   'momma,',
#   'wifey',
#   '👰\u200d♀️',
#   'mom',
#   'bronze',
#   'star',
#   'army',
#   'vet,',
#   'husband,',
#   'father,',
#   'grandfather.',
#   '#golf,#maga,',
#   "dm's",
#   'love',
#   'laugh',
#   'class',
#   '22',
#   'get',
#   'bored',
#   'easly',
#   'alt',
#   'acc',
#   'die',
#   'fun',
#   'talk',
#   'much',
#   'gentle',
#   'calm',
#   'i’m',
#   'christian,',
#   'first',
#   'off.',
#   'love',
#   'sing,',
#   'cook,',
#   'read',
#   'family',
#   'best',
#   'parkinson’s.',
#   'blessed!',
#   '😁',
#   'sincere,',
#   'happy',
#   'mommymilkers',
#   'like',
#   'listen',
#   'savage',
#   'garden',
#   'pocono',
#   'mountains',
#   'social',
#   'worker',
#   'corgi',
#   'lover',
#   '♥️👸🏻🙌🏽',
#   'american',
#   'songwriter',
#   'loves',
#   'making',
#   'music',
#   'wish',
#   'share',
#   'others.',
#   'love',
#   'read,',
#   'hike,',
#   'teach.',
#   'happily',
#   'married',
#   'living',
#   'happy',
#   'life',
#   '6',
#   'furbabies💗',
#   '|nc|',
#   'sports',
#   'twitter',
#   'page',
#   'myself,',
#   'opinions',
#   'own.',
#   'wisconsin',
#   'born.',
#   'bucks,',
#   'brewers,',
#   'az',
#   'cardinals.',
#   'young',
#   ...]}

# %%
# create your clean lyrics data here
songDFS_2={}
for k, v in songDFS.items():
    s= "".join(ch for ch in v if ch not in punctuation)
    s=s.lower().replace('\n',' ')
    words=s.split(' ')
    words=[w for w in words if w !='']
    s= [w for w in words if w not in sw]
    songDFS_2[k]=s

songDFS_2
# Out:
# {('blakeshelton', 'alloverme'): ['time',
#   'really',
#   'used',
#   'care',
#   'others',
#   'thought',
#   'way',
#   'talk',
#   'crowd',
#   'used',
#   'pull',
#   'away',
#   'would',
#   'kiss',
#   'face',
#   'touch',
#   'hair',
#   'didnt',
#   'care',
#   'saw',
#   'chorus',
#   'used',
#   'let',
#   'get',
#   'prove',
#   'love',
#   'id',
#   'crawl',
#   'knees',
#   'whole',
#   'world',
#   'see',
#   'shes',
#   'sky',
#   'blue',
#   'stand',
#   'middle',
#   'heartache',
#   'sure',
#   'looks',
#   'gray',
#   'alone',
#   'wouldnt',
#   'give',
#   'could',
#   'feel',
#   'familiar',
#   'touch',
#   'love',
#   'holding',
#   'repeat',
#   'chorus',
#   'two',
#   'times'],
#  ('blakeshelton', 'asphaltcowboy'): ['asphalt',
#   'cowboy',
#   'sun',
#   'opened',
#   'eyes',
#   'dont',
#   'wanna',
#   'leave',
#   'side',
#   'lonesome',
#   'road',
#   'go',
#   'climbing',
#   'back',
#   'behind',
#   'wheel',
#   'fifty',
#   'feet',
#   'chrome',
#   'steel',
#   'load',
#   'need',
#   'chicago',
#   'middle',
#   'night',
#   'unknown',
#   'im',
#   'ride',
#   'wont',
#   'let',
#   'go',
#   'im',
#   'asphalt',
#   'cowboy',
#   'born',
#   'run',
#   'underneath',
#   'stars',
#   'pay',
#   'mind',
#   'lonely',
#   'heart',
#   'ride',
#   'ride',
#   'til',
#   'im',
#   'back',
#   'arms',
#   'ill',
#   'wind',
#   'sometimes',
#   'late',
#   'night',
#   'see',
#   'picture',
#   'dashboard',
#   'light',
#   'takes',
#   'id',
#   'like',
#   'wrapped',
#   'blanket',
#   'pulling',
#   'ribbons',
#   'hair',
#   'kiss',
#   'girl',
#   'thats',
#   'miss',
#   'still',
#   'drive',
#   'horses',
#   'rain',
#   'snow',
#   'highspeed',
#   'rodeo',
#   'know',
#   'im',
#   'asphalt',
#   'cowboy',
#   'born',
#   'run',
#   'underneath',
#   'stars',
#   'pay',
#   'mind',
#   'lonely',
#   'heart',
#   'ride',
#   'ride',
#   'til',
#   'im',
#   'back',
#   'arms',
#   'ill',
#   'wind',
#   'ill',
#   'ride',
#   'im',
#   'back',
#   'arms',
#   'ill',
#   'wind',
#   'ill',
#   'ride',
#   'middle',
#   'night',
#   'unknown',
#   'ride',
#   'wont',
#   'let',
#   'go'],
#  ('blakeshelton', 'austin'): ['austin',
#   'left',
#   'without',
#   'leavin',
#   'number',
#   'said',
#   'needed',
#   'clear',
#   'mind',
#   'figured',
#   'shed',
#   'gone',
#   'back',
#   'austin',
#   'cause',
#   'talked',
#   'time',
#   'almost',
#   'year',
#   'called',
#   'three',
#   'rings',
#   'answering',
#   'machine',
#   'got',
#   'youre',
#   'callin',
#   'bout',
#   'car',
#   'sold',
#   'tuesday',
#   'night',
#   'im',
#   'bowling',
#   'youve',
#   'got',
#   'somethin',
#   'sell',
#   'youre',
#   'wastin',
#   'time',
#   'im',
#   'buyin',
#   'anybody',
#   'else',
#   'wait',
#   'tone',
#   'know',
#   'ps',
#   'austin',
#   'still',
#   'love',
#   'telephone',
#   'fell',
#   'counter',
#   'heard',
#   'couldnt',
#   'believe',
#   'kind',
#   'man',
#   'would',
#   'hang',
#   'long',
#   'kind',
#   'love',
#   'must',
#   'waited',
#   'three',
#   'days',
#   'tried',
#   'didnt',
#   'know',
#   'shed',
#   'say',
#   'heard',
#   'three',
#   'rings',
#   'friday',
#   'night',
#   'im',
#   'ballgame',
#   'first',
#   'thing',
#   'saturday',
#   'dont',
#   'rain',
#   'im',
#   'headed',
#   'lake',
#   'ill',
#   'gone',
#   'weekend',
#   'long',
#   'ill',
#   'call',
#   'back',
#   'get',
#   'home',
#   'sunday',
#   'afternoon',
#   'ps',
#   'austin',
#   'still',
#   'love',
#   'well',
#   'time',
#   'left',
#   'number',
#   'another',
#   'word',
#   'waited',
#   'phone',
#   'sunday',
#   'evenin',
#   'heard',
#   'youre',
#   'callin',
#   'bout',
#   'heart',
#   'still',
#   'shouldve',
#   'listened',
#   'little',
#   'wouldnt',
#   'taken',
#   'long',
#   'know',
#   'belong',
#   'way',
#   'boy',
#   'machine',
#   'youre',
#   'talkin',
#   'cant',
#   'tell',
#   'austin',
#   'still',
#   'love',
#   'still',
#   'love'],
#  ('blakeshelton', 'everytimeilookatyou'): ['every',
#   'time',
#   'look',
#   'brings',
#   'back',
#   'old',
#   'feeling',
#   'running',
#   'like',
#   'im',
#   'really',
#   'afraid',
#   'hurting',
#   'cant',
#   'stand',
#   'awkwardness',
#   'laugh',
#   'cry',
#   'dare',
#   'look',
#   'eyes',
#   'oh',
#   'goes',
#   'hands',
#   'start',
#   'shake',
#   'hearts',
#   'gonna',
#   'show',
#   'like',
#   'day',
#   'met',
#   'night',
#   'said',
#   'everytime',
#   'look',
#   'seem',
#   'bit',
#   'distracted',
#   'wish',
#   'could',
#   'feel',
#   'never',
#   'good',
#   'acting',
#   'baby',
#   'things',
#   'never',
#   'change',
#   'cant',
#   'keep',
#   'letting',
#   'go',
#   'something',
#   'cant',
#   'control',
#   'oh',
#   'goes',
#   'hands',
#   'start',
#   'shake',
#   'hearts',
#   'gonna',
#   'show',
#   'like',
#   'day',
#   'met',
#   'night',
#   'said',
#   'everytime',
#   'look',
#   'stand',
#   'looking',
#   'sweet',
#   'innocent',
#   'cruel',
#   'confident',
#   'expense',
#   'oh',
#   'goes',
#   'hands',
#   'start',
#   'shake',
#   'hearts',
#   'gonna',
#   'show',
#   'like',
#   'day',
#   'met',
#   'night',
#   'said',
#   'everytime',
#   'look',
#   'oh',
#   'goes',
#   'hands',
#   'start',
#   'shake',
#   'hearts',
#   'gonna',
#   'blow',
#   'like',
#   'day',
#   'met',
#   'night',
#   'said',
#   'everytime',
#   'look',
#   'oh',
#   'yeah',
#   'everytime',
#   'look'],
#  ('blakeshelton', 'georgiainajug'): ['georgia',
#   'jug',
#   'mason',
#   'jars',
#   'dresser',
#   'filled',
#   'quarters',
#   'dollars',
#   'savin',
#   'em',
#   'trip',
#   'around',
#   'world',
#   'youve',
#   'changed',
#   'tune',
#   'therell',
#   'honeymoon',
#   'im',
#   'going',
#   'without',
#   'girl',
#   'im',
#   'going',
#   'mexico',
#   'glass',
#   'tequila',
#   'going',
#   'purto',
#   'rico',
#   'bottle',
#   'rum',
#   'going',
#   'honolulu',
#   'mai',
#   'tai',
#   'mug',
#   'im',
#   'coming',
#   'back',
#   'home',
#   'georgia',
#   'jug',
#   'well',
#   'never',
#   'ride',
#   'bus',
#   'mexico',
#   'city',
#   'pity',
#   'well',
#   'never',
#   'sail',
#   'ship',
#   'waikiki',
#   'well',
#   'never',
#   'share',
#   'brick',
#   'suburban',
#   'home',
#   'today',
#   'im',
#   'taking',
#   'money',
#   'jar',
#   'tonight',
#   'ill',
#   'buy',
#   'ticket',
#   'corner',
#   'bar',
#   'im',
#   'going',
#   'mexico',
#   'glass',
#   'tequila',
#   'going',
#   'purto',
#   'rico',
#   'bottle',
#   'rum',
#   'going',
#   'honolulu',
#   'mai',
#   'tai',
#   'mug',
#   'im',
#   'coming',
#   'back',
#   'home',
#   'georgia',
#   'jug'],
#  ('blakeshelton', 'heavyliftin'): ['heavy',
#   'liftin',
#   'yeah',
#   'hit',
#   'ground',
#   'runnin',
#   'mornin',
#   'sun',
#   'job',
#   'needs',
#   'doin',
#   'get',
#   'done',
#   'show',
#   'early',
#   'go',
#   'home',
#   'late',
#   'everybody',
#   'knows',
#   'pull',
#   'weight',
#   'cause',
#   'dont',
#   'mind',
#   'doin',
#   'little',
#   'heavy',
#   'liftin',
#   'im',
#   'always',
#   'givin',
#   'everything',
#   'even',
#   'im',
#   'hurtin',
#   'keep',
#   'workin',
#   'long',
#   'im',
#   'still',
#   'alive',
#   'kickin',
#   'ill',
#   'stickin',
#   'heavy',
#   'liftin',
#   'well',
#   'baby',
#   'hurt',
#   'done',
#   'wrong',
#   'goin',
#   'got',
#   'tough',
#   'got',
#   'gone',
#   'well',
#   'aint',
#   'aint',
#   'even',
#   'walls',
#   'come',
#   'fallin',
#   'know',
#   'dont',
#   'mind',
#   'doin',
#   'little',
#   'heavy',
#   'liftin',
#   'im',
#   'always',
#   'givin',
#   'everything',
#   'even',
#   'im',
#   'hurtin',
#   'keep',
#   'workin',
#   'long',
#   'im',
#   'still',
#   'alive',
#   'kickin',
#   'ill',
#   'stickin',
#   'heavy',
#   'liftin',
#   'yeah',
#   'baby',
#   'heart',
#   'achin',
#   'lean',
#   'back',
#   'aint',
#   'breakin',
#   'im',
#   'sayin',
#   'dont',
#   'mind',
#   'doin',
#   'little',
#   'heavy',
#   'liftin',
#   'im',
#   'always',
#   'givin',
#   'everything',
#   'even',
#   'im',
#   'hurtin',
#   'keep',
#   'workin',
#   'long',
#   'im',
#   'still',
#   'alive',
#   'kickin',
#   'ill',
#   'stickin',
#   'heavy',
#   'liftin',
#   'honey',
#   'aint',
#   'quittin',
#   'im',
#   'always',
#   'givin',
#   'everything',
#   'yeah',
#   'long',
#   'im',
#   'still',
#   'alive',
#   'kickin',
#   'ill',
#   'stickin',
#   'heavy',
#   'liftin',
#   'yeah'],
#  ('blakeshelton', 'ifiwasyourman'): ['man',
#   'cloud',
#   'id',
#   'make',
#   'baby',
#   'raindrops',
#   'theyd',
#   'feed',
#   'treetops',
#   'cloud',
#   'sun',
#   'id',
#   'shine',
#   'flowers',
#   'pass',
#   'power',
#   'sun',
#   'moon',
#   'id',
#   'caress',
#   'every',
#   'ocean',
#   'celestial',
#   'motion',
#   'moon',
#   'star',
#   'charmed',
#   'enchanted',
#   'wishes',
#   'would',
#   'granted',
#   'star',
#   'man',
#   'kisses',
#   'would',
#   'linger',
#   'id',
#   'melt',
#   'fingers',
#   'man',
#   'man',
#   'wed',
#   'share',
#   'every',
#   'shower',
#   'wash',
#   'away',
#   'hours',
#   'baby',
#   'man',
#   'song',
#   'id',
#   'reach',
#   'people',
#   'barrooms',
#   'steeples',
#   'song',
#   'dream',
#   'id',
#   'sweeter',
#   'honey',
#   'id',
#   'bigger',
#   'money',
#   'dream',
#   'man',
#   'wed',
#   'dance',
#   'daisies',
#   'theyd',
#   'say',
#   'crazy',
#   'girl',
#   'man',
#   'man',
#   'id',
#   'pump',
#   'passion',
#   'youd',
#   'get',
#   'fashion',
#   'baby',
#   'iiiii',
#   'man',
#   'would',
#   'hurry',
#   'id',
#   'rub',
#   'away',
#   'worries',
#   'girl',
#   'man',
#   'man',
#   'wed',
#   'together',
#   'forever',
#   'baby',
#   'man',
#   'love',
#   'wed',
#   'heal',
#   'every',
#   'nation',
#   'wed',
#   'everybodys',
#   'station',
#   'love',
#   'man',
#   'sweet',
#   'lovin',
#   'man',
#   'man',
#   'man'],
#  ('blakeshelton', 'inmyheaven'): ['heaven',
#   'heaven',
#   'aint',
#   'lawyers',
#   'dont',
#   'need',
#   'names',
#   'dotted',
#   'lines',
#   'folks',
#   'business',
#   'like',
#   'oughtta',
#   'good',
#   'firm',
#   'handshake',
#   'works',
#   'fine',
#   'feed',
#   'lawyers',
#   'lions',
#   'heaven',
#   'aint',
#   'children',
#   'totin',
#   'loaded',
#   'guns',
#   'school',
#   'aint',
#   'thing',
#   'peer',
#   'pressure',
#   'cool',
#   'still',
#   'teach',
#   'golden',
#   'rule',
#   'heaven',
#   'hurt',
#   'one',
#   'lying',
#   'crying',
#   'dying',
#   'young',
#   'ones',
#   'lonely',
#   'ones',
#   'scared',
#   'anyone',
#   'welcome',
#   'heaven',
#   'heaven',
#   'sing',
#   'like',
#   'elvis',
#   'play',
#   'guitar',
#   'like',
#   'b',
#   'b',
#   'king',
#   'slide',
#   'fastball',
#   'past',
#   'hank',
#   'aaron',
#   'batter',
#   'batter',
#   'batter',
#   'swing',
#   'anything',
#   'heaven',
#   'hurt',
#   'one',
#   'lying',
#   'crying',
#   'dying',
#   'young',
#   'ones',
#   'lonely',
#   'ones',
#   'scared',
#   'anyone',
#   'welcome',
#   'heaven',
#   'know',
#   'gods',
#   'decision',
#   'heavens',
#   'gonna',
#   'aint',
#   'telling',
#   'business',
#   'left',
#   'heaven',
#   'theres',
#   'football',
#   'referees',
#   'heaven',
#   'theres',
#   'never',
#   'injury',
#   'heaven',
#   'angels',
#   'yodel',
#   'sing',
#   'heaven',
#   'fishll',
#   'bite',
#   'anything',
#   'heaven',
#   'heaven',
#   'heaven'],
#  ('blakeshelton', 'ithoughttherewastime'): ['thought',
#   'time',
#   'knew',
#   'something',
#   'matter',
#   'really',
#   'needed',
#   'attention',
#   'planned',
#   'look',
#   'someday',
#   'busy',
#   'making',
#   'money',
#   'wanted',
#   'proud',
#   'wish',
#   'could',
#   'turn',
#   'clock',
#   'back',
#   'someway',
#   'thought',
#   'time',
#   'never',
#   'thought',
#   'would',
#   'leave',
#   'always',
#   'thought',
#   'could',
#   'find',
#   'somewhere',
#   'near',
#   'phone',
#   'answer',
#   'call',
#   'full',
#   'attention',
#   'youre',
#   'think',
#   'expected',
#   'thought',
#   'time',
#   'thought',
#   'time',
#   'even',
#   'planet',
#   'see',
#   'pretty',
#   'flowers',
#   'standing',
#   'talking',
#   'wind',
#   'wish',
#   'told',
#   'wish',
#   'shouted',
#   'love',
#   'love',
#   'love',
#   'love',
#   'back',
#   'thought',
#   'time',
#   'thought',
#   'time',
#   'thought',
#   'time',
#   'thought',
#   'time'],
#  ('blakeshelton', 'myneckofthewoods'): ['neck',
#   'woods',
#   'grandpas',
#   'two',
#   'lane',
#   'blazing',
#   'sun',
#   'pouring',
#   'rain',
#   'sells',
#   'tomatoes',
#   'back',
#   'pickup',
#   'truck',
#   'reads',
#   'bible',
#   'line',
#   'line',
#   'sipping',
#   'homeade',
#   'wine',
#   'thats',
#   'hes',
#   'like',
#   'us',
#   'dads',
#   'got',
#   'crippled',
#   'hand',
#   'casualty',
#   'vietnam',
#   'hes',
#   'still',
#   'sawmill',
#   'every',
#   'day',
#   'oh',
#   'first',
#   'thing',
#   'fore',
#   'break',
#   'dawn',
#   'mamas',
#   'got',
#   'eggs',
#   'coffee',
#   'whole',
#   'life',
#   'way',
#   'come',
#   'back',
#   'hollers',
#   'got',
#   'sweat',
#   'blue',
#   'collars',
#   'livings',
#   'hard',
#   'livings',
#   'good',
#   'see',
#   'god',
#   'sent',
#   'heavens',
#   'hung',
#   'em',
#   'round',
#   'neck',
#   'woods',
#   'sure',
#   'river',
#   'flows',
#   'take',
#   'care',
#   'step',
#   'right',
#   'someone',
#   'needs',
#   'friend',
#   'last',
#   'year',
#   'johnson',
#   'farm',
#   'fire',
#   'wiped',
#   'house',
#   'barn',
#   'whole',
#   'town',
#   'showed',
#   'build',
#   'em',
#   'back',
#   'right',
#   'come',
#   'back',
#   'hollers',
#   'got',
#   'sweat',
#   'blue',
#   'collars',
#   'livings',
#   'hard',
#   'livings',
#   'good',
#   'see',
#   'god',
#   'sent',
#   'heavens',
#   'hung',
#   'em',
#   'round',
#   'neck',
#   'woods',
#   'come',
#   'back',
#   'hollers',
#   'got',
#   'sweat',
#   'blue',
#   'collars',
#   'livings',
#   'hard',
#   'livings',
#   'good',
#   'see',
#   'god',
#   'sent',
#   'heavens',
#   'hung',
#   'em',
#   'round',
#   'neck',
#   'woods'],
#  ('blakeshelton', 'nobodybutme'): ['nobody',
#   'dont',
#   'waste',
#   'time',
#   'looking',
#   'shoulder',
#   'loves',
#   'past',
#   'aint',
#   'getting',
#   'closer',
#   'look',
#   'future',
#   'youre',
#   'see',
#   'dont',
#   'go',
#   'loving',
#   'nobody',
#   'chorus',
#   'nobody',
#   'gonna',
#   'love',
#   'like',
#   'ought',
#   'loved',
#   'nobody',
#   'gonna',
#   'cry',
#   'leave',
#   'want',
#   'im',
#   'asking',
#   'pretty',
#   'please',
#   'honey',
#   'dont',
#   'go',
#   'loving',
#   'nobody',
#   'took',
#   'time',
#   'tell',
#   'feel',
#   'took',
#   'long',
#   'dont',
#   'mean',
#   'isnt',
#   'real',
#   'aint',
#   'got',
#   'diamond',
#   'im',
#   'knees',
#   'dont',
#   'go',
#   'loving',
#   'nobody',
#   'chorus',
#   'nobody',
#   'gonna',
#   'love',
#   'like',
#   'ought',
#   'loved',
#   'nobody',
#   'gonna',
#   'cry',
#   'leave',
#   'want',
#   'im',
#   'asking',
#   'pretty',
#   'please',
#   'honey',
#   'dont',
#   'go',
#   'loving',
#   'nobody',
#   'chorus',
#   'nobody',
#   'gonna',
#   'love',
#   'like',
#   'ought',
#   'loved',
#   'nobody',
#   'gonna',
#   'cry',
#   'leave',
#   'want',
#   'im',
#   'asking',
#   'pretty',
#   'please',
#   'honey',
#   'dont',
#   'go',
#   'loving',
#   'nobody',
#   'dont',
#   'go',
#   'loving',
#   'nobody'],
#  ('blakeshelton', 'olred'): ['ol',
#   'red',
#   'well',
#   'caught',
#   'wife',
#   'another',
#   'man',
#   'cost',
#   'ninety',
#   'nine',
#   'prison',
#   'farm',
#   'georgia',
#   'close',
#   'florida',
#   'line',
#   'well',
#   'id',
#   'two',
#   'long',
#   'years',
#   'finally',
#   'made',
#   'warden',
#   'friend',
#   'sentenced',
#   'life',
#   'ease',
#   'taking',
#   'care',
#   'ol',
#   'red',
#   'ol',
#   'red',
#   'hes',
#   'damnedest',
#   'dog',
#   'ive',
#   'ever',
#   'seen',
#   'got',
#   'nose',
#   'smell',
#   'two',
#   'day',
#   'trail',
#   'hes',
#   'four',
#   'legged',
#   'tracking',
#   'machine',
#   'consider',
#   'mighty',
#   'lucky',
#   'get',
#   'past',
#   'gators',
#   'quicksand',
#   'beds',
#   'years',
#   'ive',
#   'aint',
#   'nobody',
#   'got',
#   'past',
#   'red',
#   'warden',
#   'sang',
#   'come',
#   'somebody',
#   'dont',
#   'run',
#   'ol',
#   'reds',
#   'itchin',
#   'little',
#   'fun',
#   'get',
#   'lantern',
#   'get',
#   'gun',
#   'redll',
#   'treed',
#   'mornin',
#   'comes',
#   'well',
#   'paid',
#   'guard',
#   'slipped',
#   'letter',
#   'cousin',
#   'tennessee',
#   'oh',
#   'brought',
#   'blue',
#   'tick',
#   'hound',
#   'pretty',
#   'could',
#   'well',
#   'penned',
#   'swampland',
#   'bout',
#   'mile',
#   'south',
#   'gate',
#   'id',
#   'take',
#   'ol',
#   'red',
#   'evening',
#   'run',
#   'id',
#   'drop',
#   'wait',
#   'warden',
#   'sang',
#   'come',
#   'somebody',
#   'dont',
#   'run',
#   'ol',
#   'reds',
#   'itchin',
#   'little',
#   'fun',
#   'get',
#   'lantern',
#   'get',
#   'gun',
#   'redll',
#   'treed',
#   'mornin',
#   'comes',
#   'ol',
#   'red',
#   'got',
#   'real',
#   'used',
#   'seeing',
#   'lady',
#   'every',
#   'night',
#   'kept',
#   'away',
#   'three',
#   'four',
#   'days',
#   'waited',
#   'till',
#   'time',
#   'got',
#   'right',
#   'well',
#   'made',
#   'run',
#   'evenin',
#   'sun',
#   'smiled',
#   'heard',
#   'em',
#   'turn',
#   'red',
#   'cause',
#   'headed',
#   'north',
#   'tennessee',
#   'ol',
#   'red',
#   'headed',
#   'south',
#   'warden',
#   'sang',
#   'come',
#   'somebody',
#   'dont',
#   'run',
#   'ol',
#   'reds',
#   'itchin',
#   'little',
#   'fun',
#   'get',
#   'lantern',
#   'get',
#   'gun',
#   'redll',
#   'treed',
#   'mornin',
#   'comes',
#   'theres',
#   'red',
#   'haired',
#   'blue',
#   'ticks',
#   'south',
#   'love',
#   'got',
#   'love',
#   'got'],
#  ('blakeshelton', 'playboysofthesouthwesternworld'): ['playboys',
#   'southwestern',
#   'world',
#   'song',
#   'best',
#   'friends',
#   'john',
#   'roy',
#   'boy',
#   'knew',
#   'since',
#   'three',
#   'two',
#   'grew',
#   'two',
#   'little',
#   'houses',
#   'two',
#   'bad',
#   'apples',
#   'family',
#   'tree',
#   'kind',
#   'ripened',
#   'rotted',
#   'puberty',
#   'two',
#   'kindred',
#   'spirits',
#   'bound',
#   'destiny',
#   'well',
#   'smart',
#   'lacked',
#   'ambition',
#   'johnny',
#   'wild',
#   'inhibition',
#   'like',
#   'mixin',
#   'fire',
#   'gasoline',
#   'hed',
#   'say',
#   'hey',
#   'romeo',
#   'lets',
#   'go',
#   'mexico',
#   'chase',
#   'senoritas',
#   'drink',
#   'silly',
#   'show',
#   'mexican',
#   'girls',
#   'couple',
#   'real',
#   'hillbillies',
#   'got',
#   'pocket',
#   'full',
#   'cash',
#   'old',
#   'ford',
#   'truck',
#   'fuzzy',
#   'cat',
#   'hangin',
#   'mirror',
#   'luck',
#   'said',
#   'dont',
#   'know',
#   'little',
#   'browneyed',
#   'girls',
#   'want',
#   'playboys',
#   'southwestern',
#   'world',
#   'long',
#   'around',
#   'eighteenth',
#   'year',
#   'found',
#   'two',
#   'plane',
#   'tickets',
#   'hell',
#   'got',
#   'scholarships',
#   'small',
#   'town',
#   'school',
#   'texas',
#   'learned',
#   'drink',
#   'sangria',
#   'til',
#   'dawns',
#   'early',
#   'light',
#   'eat',
#   'eggs',
#   'ranchero',
#   'throw',
#   'night',
#   'tell',
#   'daddys',
#   'girls',
#   'majoring',
#   'rodeo',
#   'ah',
#   'favorite',
#   'memory',
#   'school',
#   'fall',
#   'night',
#   'john',
#   'roy',
#   'came',
#   'runnin',
#   'hall',
#   'wearin',
#   'nothin',
#   'cowboy',
#   'boots',
#   'big',
#   'sombrero',
#   'yellin',
#   'hey',
#   'romeo',
#   'lets',
#   'go',
#   'mexico',
#   'chase',
#   'senoritas',
#   'drink',
#   'silly',
#   'show',
#   'mexican',
#   'girls',
#   'couple',
#   'real',
#   'hillbillies',
#   'got',
#   'pocket',
#   'full',
#   'cash',
#   'old',
#   'ford',
#   'truck',
#   'fuzzy',
#   'cat',
#   'hangin',
#   'mirror',
#   'luck',
#   'said',
#   'dont',
#   'know',
#   'little',
#   'browneyed',
#   'girls',
#   'want',
#   'playboys',
#   'southwestern',
#   'world',
#   'said',
#   'little',
#   'change',
#   'plans',
#   'like',
#   'paul',
#   'mccartney',
#   'got',
#   'busted',
#   'japan',
#   'said',
#   'got',
#   'waylaid',
#   'laid',
#   'foot',
#   'mexican',
#   'soil',
#   'see',
#   'boarder',
#   'guard',
#   'fu',
#   'manchu',
#   'mustache',
#   'kind',
#   'stumbled',
#   'johns',
#   'pocket',
#   'full',
#   'american',
#   'cash',
#   'said',
#   'doin',
#   'little',
#   'funny',
#   'business',
#   'mexico',
#   'amigo',
#   'could',
#   'think',
#   'savin',
#   'tail',
#   'mentioned',
#   'ten',
#   'years',
#   'mexican',
#   'jail',
#   'pointed',
#   'john',
#   'roy',
#   'said',
#   'please',
#   'let',
#   'go',
#   'well',
#   'idea',
#   'genius',
#   'layin',
#   'bed',
#   'said',
#   'hey',
#   'romeo',
#   'lets',
#   'go',
#   'mexico',
#   'chase',
#   'senoritas',
#   'drink',
#   'silly',
#   'show',
#   'mexican',
#   'girls',
#   'couple',
#   'real',
#   'hillbillies',
#   'got',
#   'pocket',
#   'full',
#   'cash',
#   'old',
#   'ford',
#   'truck',
#   'fuzzy',
#   'cat',
#   'hangin',
#   'mirror',
#   'luck',
#   'said',
#   'dont',
#   'know',
#   'little',
#   'browneyed',
#   'girls',
#   'want',
#   'playboys',
#   'southwestern',
#   'world',
#   'ah',
#   'still',
#   'best',
#   'friends',
#   'temporary',
#   'cell',
#   'mates'],
#  ('blakeshelton', 'problemsathome'): ['problems',
#   'home',
#   'fires',
#   'burning',
#   'forests',
#   'along',
#   'amazon',
#   'theres',
#   'children',
#   'starving',
#   'guatemala',
#   'theyre',
#   'barely',
#   'hanging',
#   'chorus',
#   'pray',
#   'theyll',
#   'find',
#   'answer',
#   'theres',
#   'way',
#   'right',
#   'wrong',
#   'lord',
#   'youre',
#   'listening',
#   'could',
#   'mention',
#   'troubles',
#   'got',
#   'problems',
#   'right',
#   'home',
#   'teenage',
#   'boy',
#   'mississippi',
#   'brings',
#   'daddys',
#   'gun',
#   'school',
#   'little',
#   'girl',
#   'new',
#   'york',
#   'city',
#   'buys',
#   'cocaine',
#   'mama',
#   'use',
#   'chorus',
#   'wife',
#   'crying',
#   'babys',
#   'fighting',
#   'battle',
#   'may',
#   'win',
#   'doctors',
#   'god',
#   'hands',
#   'pray',
#   'theyll',
#   'find',
#   'answer',
#   'theres',
#   'way',
#   'right',
#   'wrong',
#   'im',
#   'one',
#   'man',
#   'grain',
#   'sand',
#   'troubled',
#   'world',
#   'know',
#   'ive',
#   'got',
#   'problem',
#   'right',
#   'home',
#   'ive',
#   'got',
#   'problem',
#   'right',
#   'home'],
#  ('blakeshelton', 'sameoldsong'): ['old',
#   'song',
#   'love',
#   'country',
#   'music',
#   'guess',
#   'always',
#   'days',
#   'turn',
#   'radio',
#   'thrill',
#   'like',
#   'song',
#   'gives',
#   'chillbumps',
#   'theres',
#   'still',
#   'im',
#   'fed',
#   'old',
#   'vanilla',
#   'hey',
#   'im',
#   'tired',
#   'old',
#   'guy',
#   'old',
#   'song',
#   'old',
#   'love',
#   'goes',
#   'old',
#   'guitar',
#   'old',
#   'strum',
#   'may',
#   'country',
#   'im',
#   'dumb',
#   'hey',
#   'mr',
#   'songwriter',
#   'come',
#   'visit',
#   'home',
#   'tell',
#   'life',
#   'perfect',
#   'love',
#   'goes',
#   'ride',
#   'old',
#   'bronco',
#   'factory',
#   'eight',
#   'hours',
#   'let',
#   'introduce',
#   'supervisor',
#   'write',
#   'song',
#   'sunshine',
#   'flowers',
#   'old',
#   'guy',
#   'old',
#   'song',
#   'old',
#   'love',
#   'goes',
#   'old',
#   'guitar',
#   'old',
#   'strum',
#   'may',
#   'country',
#   'im',
#   'dumb',
#   'want',
#   'hear',
#   'song',
#   'passion',
#   'want',
#   'hear',
#   'song',
#   'sin',
#   'want',
#   'hear',
#   'song',
#   'redemption',
#   'yeah',
#   'sing',
#   'one',
#   'tell',
#   'cowboy',
#   'australia',
#   'tell',
#   'prisoner',
#   'china',
#   'tell',
#   'old',
#   'stock',
#   'car',
#   'driver',
#   'orangeburg',
#   'south',
#   'carolina',
#   'instead',
#   'old',
#   'guy',
#   'old',
#   'song',
#   'old',
#   'love',
#   'goes',
#   'old',
#   'guitar',
#   'old',
#   'strum',
#   'may',
#   'country',
#   'im',
#   'dumb',
#   'old',
#   'old',
#   'old'],
#  ('blakeshelton', 'shedoesntknowshesgotit'): ['doesnt',
#   'know',
#   'shes',
#   'got',
#   'friday',
#   'night',
#   'see',
#   'even',
#   'crowd',
#   'shes',
#   'hard',
#   'miss',
#   'aint',
#   'man',
#   'breathing',
#   'air',
#   'wouldnt',
#   'stop',
#   'stare',
#   'best',
#   'part',
#   'chorus',
#   'doesnt',
#   'know',
#   'shes',
#   'got',
#   'doesnt',
#   'know',
#   'bad',
#   'want',
#   'doesnt',
#   'know',
#   'shes',
#   'got',
#   'thats',
#   'whats',
#   'gettin',
#   'shell',
#   'close',
#   'eyes',
#   'music',
#   'plays',
#   'way',
#   'sways',
#   'really',
#   'rocks',
#   'room',
#   'doesnt',
#   'mean',
#   'get',
#   'things',
#   'stirred',
#   'thing',
#   'born',
#   'move',
#   'doesnt',
#   'know',
#   'shes',
#   'got',
#   'doesnt',
#   'know',
#   'bad',
#   'want',
#   'doesnt',
#   'know',
#   'shes',
#   'got',
#   'thats',
#   'whats',
#   'gettin',
#   'im',
#   'gonna',
#   'work',
#   'courage',
#   'tell',
#   'im',
#   'love',
#   'im',
#   'love',
#   'lot',
#   'heart',
#   'string',
#   'like',
#   'everything',
#   'girl',
#   'got',
#   'doesnt',
#   'know',
#   'shes',
#   'got',
#   'doesnt',
#   'know',
#   'bad',
#   'want',
#   'doesnt',
#   'know',
#   'shes',
#   'got',
#   'thats',
#   'whats',
#   'gettin',
#   'doesnt',
#   'know',
#   'shes',
#   'got',
#   'doesnt',
#   'know',
#   'bad',
#   'want',
#   'doesnt',
#   'know',
#   'shes',
#   'got',
#   'thats',
#   'whats',
#   'gettin'],
#  ('blakeshelton', 'somebeach'): ['beach',
#   'driving',
#   'interstate',
#   'running',
#   'thirty',
#   'minutes',
#   'late',
#   'singing',
#   'margaritaville',
#   'minding',
#   'foreign',
#   'car',
#   'driver',
#   'dude',
#   'road',
#   'rage',
#   'attitude',
#   'pulled',
#   'beside',
#   'talking',
#   'cell',
#   'phone',
#   'started',
#   'yelling',
#   'like',
#   'something',
#   'wrong',
#   'flipped',
#   'bird',
#   'gone',
#   'beach',
#   'somewhere',
#   'theres',
#   'big',
#   'umbrella',
#   'casting',
#   'shade',
#   'empty',
#   'chair',
#   'palm',
#   'trees',
#   'growing',
#   'warm',
#   'breezes',
#   'blowing',
#   'picture',
#   'right',
#   'beach',
#   'somewhere',
#   'circled',
#   'parking',
#   'lot',
#   'trying',
#   'find',
#   'spot',
#   'big',
#   'enough',
#   'could',
#   'park',
#   'old',
#   'truck',
#   'man',
#   'big',
#   'cigar',
#   'getting',
#   'car',
#   'stopped',
#   'waited',
#   'back',
#   'mercedes',
#   'benz',
#   'came',
#   'cruising',
#   'whipped',
#   'right',
#   'beach',
#   'somewhere',
#   'theres',
#   'go',
#   'got',
#   'day',
#   'get',
#   'theres',
#   'cold',
#   'margaritas',
#   'hot',
#   'senioritas',
#   'smiling',
#   'long',
#   'dark',
#   'hair',
#   'beach',
#   'somewhere',
#   'sat',
#   'waiting',
#   'room',
#   'seemed',
#   'like',
#   'afternoon',
#   'nurse',
#   'finally',
#   'said',
#   'docs',
#   'ready',
#   'youre',
#   'gonna',
#   'feel',
#   'thing',
#   'well',
#   'give',
#   'novocain',
#   'tooth',
#   'fine',
#   'minute',
#   'two',
#   'stuck',
#   'needle',
#   'deep',
#   'gum',
#   'started',
#   'drilling',
#   'numb',
#   'beach',
#   'somewhere',
#   'theres',
#   'beautiful',
#   'sunset',
#   'burning',
#   'atmosphere',
#   'theres',
#   'music',
#   'dancing',
#   'lovers',
#   'romancing',
#   'salty',
#   'evening',
#   'air',
#   'beach',
#   'somewhere',
#   'beach',
#   'somewhere'],
#  ('blakeshelton', 'someday'): ['someday',
#   'time',
#   'end',
#   'time',
#   'end',
#   'billion',
#   'years',
#   'trillion',
#   'years',
#   'infinity',
#   'cirlce',
#   'enternal',
#   'loop',
#   'drive',
#   'crazy',
#   'searching',
#   'truth',
#   'someday',
#   'know',
#   'reason',
#   'doubt',
#   'someday',
#   'babies',
#   'theres',
#   'nothing',
#   'recall',
#   'go',
#   'back',
#   'fade',
#   'black',
#   'thats',
#   'could',
#   'destined',
#   'time',
#   'place',
#   'lived',
#   'lives',
#   'memories',
#   'erased',
#   'someday',
#   'know',
#   'reason',
#   'doubt',
#   'someday',
#   'see',
#   'jesus',
#   'comin',
#   'sunshine',
#   'fills',
#   'night',
#   'die',
#   'fly',
#   'light',
#   'reunited',
#   'ones',
#   'whove',
#   'gone',
#   'away',
#   'love',
#   'way',
#   'today',
#   'believe',
#   'someday',
#   'well',
#   'know',
#   'reason',
#   'doubt',
#   'someday'],
#  ('blakeshelton', 'thatswhaticallhome'): ['thats',
#   'call',
#   'home',
#   'theres',
#   'house',
#   'thats',
#   'little',
#   'run',
#   'city',
#   'aint',
#   'never',
#   'found',
#   'miles',
#   'miles',
#   'paved',
#   'road',
#   'thats',
#   'grew',
#   'seven',
#   'children',
#   'raised',
#   'love',
#   'life',
#   'gets',
#   'hard',
#   'thats',
#   'go',
#   'chorus',
#   'daddy',
#   'dont',
#   'know',
#   'stranger',
#   'handshake',
#   'hes',
#   'friend',
#   'oh',
#   'mama',
#   'shes',
#   'angel',
#   'shell',
#   'hold',
#   'tight',
#   'till',
#   'heartache',
#   'ends',
#   'place',
#   'made',
#   'nails',
#   'wood',
#   'love',
#   'makes',
#   'feel',
#   'good',
#   'thats',
#   'call',
#   'thats',
#   'call',
#   'home',
#   'daddy',
#   'built',
#   'two',
#   'hands',
#   'overlooking',
#   'grandpas',
#   'land',
#   'years',
#   'lot',
#   'changed',
#   'driving',
#   'gravel',
#   'road',
#   'get',
#   'feeling',
#   'soul',
#   'thank',
#   'god',
#   'things',
#   'still',
#   'remain',
#   'repeat',
#   'chorus',
#   'get',
#   'old',
#   'screen',
#   'door',
#   'world',
#   'cant',
#   'touch',
#   'anymore',
#   'repeat',
#   'chorus',
#   'thats',
#   'call',
#   'home',
#   'thats',
#   'call',
#   'home'],
#  ('blakeshelton', 'thebaby'): ['baby',
#   'brother',
#   'said',
#   'rotten',
#   'core',
#   'youngest',
#   'child',
#   'got',
#   'guess',
#   'tired',
#   'time',
#   'came',
#   'along',
#   'shed',
#   'laugh',
#   'cried',
#   'could',
#   'wrong',
#   'would',
#   'always',
#   'save',
#   'baby',
#   'worked',
#   'factory',
#   'ohio',
#   'shrimp',
#   'boat',
#   'bayou',
#   'drove',
#   'truck',
#   'birmingham',
#   'turned',
#   '21',
#   'cincinnati',
#   'called',
#   'home',
#   'mom',
#   'daddy',
#   'said',
#   'boy',
#   'man',
#   'said',
#   'dont',
#   'care',
#   'youre',
#   '80',
#   'youll',
#   'always',
#   'baby',
#   'loved',
#   'photograph',
#   'whole',
#   'family',
#   'shed',
#   'always',
#   'point',
#   'us',
#   'friends',
#   'see',
#   'thats',
#   'greg',
#   'hes',
#   'great',
#   'really',
#   'loves',
#   'job',
#   'ronnie',
#   '2',
#   'kids',
#   'bout',
#   'wife',
#   'hes',
#   'got',
#   'ones',
#   'kinda',
#   'crazy',
#   'one',
#   'baby',
#   'got',
#   'call',
#   'alabama',
#   'said',
#   'come',
#   'home',
#   'louisianna',
#   'come',
#   'fast',
#   'fly',
#   'cause',
#   'momma',
#   'really',
#   'needs',
#   'says',
#   'shes',
#   'got',
#   'see',
#   'might',
#   'make',
#   'night',
#   'whole',
#   'way',
#   'drove',
#   '80',
#   'could',
#   'see',
#   'baby',
#   'looked',
#   'like',
#   'sleepin',
#   'family',
#   'weepin',
#   'time',
#   'got',
#   'side',
#   'knew',
#   'shed',
#   'taken',
#   'heart',
#   'breakin',
#   'never',
#   'got',
#   'say',
#   'goodbye',
#   'softly',
#   'kissed',
#   'lady',
#   'cried',
#   'like',
#   'baby'],
#  ('blakeshelton', 'thedreamer'): ['dreamer',
#   'funny',
#   'thing',
#   'dreamers',
#   'dream',
#   'sights',
#   'get',
#   'theyre',
#   'goin',
#   'leave',
#   'lot',
#   'good',
#   'things',
#   'behind',
#   'guess',
#   'could',
#   'call',
#   'dreamer',
#   'ive',
#   'seen',
#   'come',
#   'true',
#   'smile',
#   'need',
#   'look',
#   'happy',
#   'things',
#   'tell',
#   'yeah',
#   'im',
#   'big',
#   'selfmade',
#   'man',
#   'fool',
#   'cant',
#   'understand',
#   'thought',
#   'needed',
#   'fortune',
#   'thought',
#   'needed',
#   'fame',
#   'need',
#   'hear',
#   'whisper',
#   'name',
#   'could',
#   'make',
#   'future',
#   'extension',
#   'past',
#   'id',
#   'take',
#   'broken',
#   'memories',
#   'make',
#   'moments',
#   'last',
#   'ship',
#   'come',
#   'wonder',
#   'done',
#   'thought',
#   'needed',
#   'fortune',
#   'thought',
#   'needed',
#   'fame',
#   'need',
#   'hear',
#   'whisper',
#   'name',
#   'thought',
#   'needed',
#   'fortune',
#   'thought',
#   'needed',
#   'fame',
#   'need',
#   'hear',
#   'whisper',
#   'name',
#   'oh',
#   'yeah',
#   'whisper',
#   'baby'],
#  ('blakeshelton', 'underneaththesamemoon'): ['underneath',
#   'moon',
#   'shadows',
#   'night',
#   'moving',
#   'ground',
#   'like',
#   'silent',
#   'clouds',
#   'follow',
#   'around',
#   'wander',
#   'dark',
#   'midnight',
#   'mist',
#   'remembering',
#   'last',
#   'kiss',
#   'know',
#   'much',
#   'youre',
#   'missed',
#   'chorus',
#   'tonight',
#   'stand',
#   'lonely',
#   'place',
#   'search',
#   'heavens',
#   'saving',
#   'grace',
#   'cry',
#   'dying',
#   'without',
#   'know',
#   'youre',
#   'somewhere',
#   'looking',
#   'right',
#   'thats',
#   'two',
#   'distant',
#   'hearts',
#   'ohooh',
#   'least',
#   'underneath',
#   'underneath',
#   'moon',
#   'picturing',
#   'face',
#   'flowers',
#   'hair',
#   'like',
#   'always',
#   'wear',
#   'oh',
#   'see',
#   'longing',
#   'touched',
#   'youre',
#   'reach',
#   'oh',
#   'hold',
#   'please',
#   'wont',
#   'wait',
#   'repeat',
#   'chorus',
#   'la',
#   'la',
#   'la',
#   'la',
#   'la',
#   'la',
#   'la',
#   'la',
#   'la',
#   'ohooh',
#   'least',
#   'underneath',
#   'underneath',
#   'moon',
#   'shadows',
#   'night',
#   'moving',
#   'around',
#   'moving',
#   'ground',
#   'follow',
#   'around'],
#  ('taylorswift', 'aperfectlygoodheart'): ['perfectly',
#   'good',
#   'heart',
#   'would',
#   'wanna',
#   'break',
#   'perfectly',
#   'good',
#   'heart',
#   'would',
#   'wanna',
#   'take',
#   'love',
#   'tear',
#   'apart',
#   'would',
#   'wanna',
#   'make',
#   'first',
#   'scar',
#   'would',
#   'wanna',
#   'break',
#   'perfectly',
#   'good',
#   'heart',
#   'maybe',
#   'shouldve',
#   'seen',
#   'signs',
#   'shouldve',
#   'read',
#   'writing',
#   'wall',
#   'realized',
#   'distance',
#   'eyes',
#   'would',
#   'one',
#   'fall',
#   'matter',
#   'say',
#   'still',
#   'cant',
#   'believe',
#   'would',
#   'walk',
#   'away',
#   'dont',
#   'make',
#   'sense',
#   'would',
#   'wanna',
#   'break',
#   'perfectly',
#   'good',
#   'heart',
#   'would',
#   'wanna',
#   'take',
#   'love',
#   'tear',
#   'apart',
#   'would',
#   'wanna',
#   'make',
#   'first',
#   'scar',
#   'would',
#   'wanna',
#   'break',
#   'perfectly',
#   'good',
#   'heart',
#   'unbroken',
#   'anymore',
#   'get',
#   'back',
#   'way',
#   'would',
#   'wanna',
#   'break',
#   'perfectly',
#   'good',
#   'heart',
#   'would',
#   'wanna',
#   'take',
#   'love',
#   'tear',
#   'apart',
#   'would',
#   'wanna',
#   'make',
#   'first',
#   'scar',
#   'would',
#   'wanna',
#   'break',
#   'would',
#   'wanna',
#   'break',
#   'would',
#   'wanna',
#   'break',
#   'perfectly',
#   'good',
#   'heart',
#   'would',
#   'wanna',
#   'take',
#   'love',
#   'tear',
#   'apart',
#   'would',
#   'wanna',
#   'make',
#   'first',
#   'scar',
#   'would',
#   'wanna',
#   'break',
#   'perfectly',
#   'good',
#   'heart'],
#  ('taylorswift', 'aplaceinthisworld'): ['place',
#   'world',
#   'dont',
#   'know',
#   'want',
#   'dont',
#   'ask',
#   'cause',
#   'im',
#   'still',
#   'trying',
#   'figure',
#   'dont',
#   'know',
#   'whats',
#   'road',
#   'im',
#   'walking',
#   'trying',
#   'see',
#   'rain',
#   'coming',
#   'even',
#   'though',
#   'im',
#   'one',
#   'feels',
#   'way',
#   'im',
#   'alone',
#   'thats',
#   'know',
#   'ill',
#   'strong',
#   'ill',
#   'wrong',
#   'oh',
#   'life',
#   'goes',
#   'oh',
#   'im',
#   'girl',
#   'trying',
#   'find',
#   'place',
#   'world',
#   'got',
#   'radio',
#   'old',
#   'blue',
#   'jeans',
#   'im',
#   'wearing',
#   'heart',
#   'sleeve',
#   'feeling',
#   'lucky',
#   'today',
#   'got',
#   'sunshine',
#   'could',
#   'tell',
#   'need',
#   'tomorrows',
#   'mystery',
#   'oh',
#   'yeah',
#   'thats',
#   'ok',
#   'im',
#   'alone',
#   'thats',
#   'know',
#   'ill',
#   'strong',
#   'ill',
#   'wrong',
#   'oh',
#   'life',
#   'goes',
#   'oh',
#   'im',
#   'girl',
#   'trying',
#   'find',
#   'place',
#   'world',
#   'maybe',
#   'im',
#   'girl',
#   'mission',
#   'im',
#   'ready',
#   'fly',
#   'im',
#   'alone',
#   'thats',
#   'know',
#   'ill',
#   'strong',
#   'ill',
#   'wrong',
#   'oh',
#   'life',
#   'goes',
#   'oh',
#   'im',
#   'alone',
#   'thats',
#   'know',
#   'oh',
#   'im',
#   'girl',
#   'trying',
#   'find',
#   'place',
#   'world',
#   'oh',
#   'im',
#   'girl',
#   'oh',
#   'im',
#   'girl',
#   'oh',
#   'oh',
#   'oh',
#   'im',
#   'girl'],
#  ('taylorswift', 'christmaseswhenyouweremine'): ['christmases',
#   'mine',
#   'please',
#   'take',
#   'mistletoe',
#   'cause',
#   'dont',
#   'wanna',
#   'think',
#   'right',
#   'cause',
#   'everything',
#   'want',
#   'miles',
#   'away',
#   'snow',
#   'covered',
#   'little',
#   'town',
#   'mommas',
#   'kitchen',
#   'worrying',
#   'seasons',
#   'greetings',
#   'hope',
#   'youre',
#   'well',
#   'well',
#   'im',
#   'alright',
#   'wondering',
#   'lately',
#   'never',
#   'tell',
#   'know',
#   'shouldnt',
#   'lonely',
#   'time',
#   'christmases',
#   'mine',
#   'ive',
#   'fine',
#   'without',
#   'really',
#   'nights',
#   'got',
#   'cold',
#   'everybodys',
#   'except',
#   'baby',
#   'seems',
#   'like',
#   'everyones',
#   'got',
#   'someone',
#   'hold',
#   'lonely',
#   'time',
#   'cause',
#   'christmases',
#   'mine',
#   'merry',
#   'christmas',
#   'everybody',
#   'thatll',
#   'something',
#   'say',
#   'year',
#   'ill',
#   'bet',
#   'got',
#   'mom',
#   'another',
#   'sweater',
#   'cousins',
#   'late',
#   'putting',
#   'lights',
#   'year',
#   'notice',
#   'one',
#   'less',
#   'pair',
#   'hands',
#   'know',
#   'shouldnt',
#   'lonely',
#   'time',
#   'christmases',
#   'didnt',
#   'wonder',
#   'tonight',
#   'cause',
#   'christmases',
#   'mine',
#   'mine'],
#  ('taylorswift', 'christmasmustbesomethingmore'): ['christmas',
#   'must',
#   'something',
#   'ribbons',
#   'bows',
#   'didnt',
#   'mean',
#   'thing',
#   'would',
#   'song',
#   'still',
#   'survive',
#   'without',
#   'five',
#   'golden',
#   'rings',
#   'would',
#   'still',
#   'wanna',
#   'kiss',
#   'without',
#   'mistletoe',
#   'would',
#   'happen',
#   'god',
#   'never',
#   'let',
#   'snow',
#   'would',
#   'happen',
#   'christmas',
#   'carols',
#   'told',
#   'lie',
#   'tell',
#   'would',
#   'find',
#   'youd',
#   'see',
#   'today',
#   'holds',
#   'something',
#   'special',
#   'something',
#   'holy',
#   'superficial',
#   'heres',
#   'birthday',
#   'boy',
#   'saved',
#   'lives',
#   'something',
#   'try',
#   'ignore',
#   'put',
#   'wreath',
#   'door',
#   'heres',
#   'something',
#   'know',
#   'sure',
#   'christmas',
#   'must',
#   'something',
#   'angels',
#   'pay',
#   'attention',
#   'things',
#   'wished',
#   'would',
#   'always',
#   'happiness',
#   'came',
#   'cardboard',
#   'box',
#   'think',
#   'something',
#   'forgot',
#   'would',
#   'happen',
#   'presents',
#   'went',
#   'away',
#   'tell',
#   'would',
#   'find',
#   'youd',
#   'see',
#   'today',
#   'holds',
#   'something',
#   'special',
#   'something',
#   'holy',
#   'superficial',
#   'heres',
#   'birthday',
#   'boy',
#   'saved',
#   'lives',
#   'something',
#   'try',
#   'ignore',
#   'put',
#   'wreath',
#   'door',
#   'heres',
#   'something',
#   'know',
#   'sure',
#   'christmas',
#   'must',
#   'something',
#   'get',
#   'caught',
#   'business',
#   'relationships',
#   'hundredmileanhour',
#   'lives',
#   'time',
#   'year',
#   'everybodys',
#   'seems',
#   'last',
#   'thing',
#   'mind',
#   'day',
#   'holds',
#   'something',
#   'special',
#   'something',
#   'holy',
#   'superficial',
#   'heres',
#   'jesus',
#   'christ',
#   'saved',
#   'lives',
#   'something',
#   'try',
#   'ignore',
#   'put',
#   'wreath',
#   'door',
#   'heres',
#   'something',
#   'know',
#   'sure',
#   'christmas',
#   'must',
#   'something',
#   'christmas',
#   'must',
#   'something',
#   'christmas',
#   'must',
#   'something',
#   'theres',
#   'gotta',
#   'theres',
#   'gotta'],
#  ('taylorswift', 'coldasyou'): ['cold',
#   'way',
#   'coming',
#   'easily',
#   'take',
#   'take',
#   'best',
#   'start',
#   'fight',
#   'cause',
#   'need',
#   'feel',
#   'something',
#   'want',
#   'cause',
#   'im',
#   'wanted',
#   'oh',
#   'shame',
#   'rainy',
#   'ending',
#   'given',
#   'perfect',
#   'day',
#   'walk',
#   'away',
#   'aint',
#   'use',
#   'defending',
#   'words',
#   'never',
#   'say',
#   'im',
#   'sitting',
#   'thinking',
#   'ive',
#   'never',
#   'anywhere',
#   'cold',
#   'put',
#   'walls',
#   'paint',
#   'shade',
#   'gray',
#   'stood',
#   'loving',
#   'wished',
#   'away',
#   'come',
#   'away',
#   'great',
#   'little',
#   'story',
#   'mess',
#   'dreamer',
#   'nerve',
#   'adore',
#   'oh',
#   'shame',
#   'rainy',
#   'ending',
#   'given',
#   'perfect',
#   'day',
#   'walk',
#   'away',
#   'aint',
#   'use',
#   'defending',
#   'words',
#   'never',
#   'say',
#   'im',
#   'sitting',
#   'thinking',
#   'ive',
#   'never',
#   'anywhere',
#   'cold',
#   'never',
#   'give',
#   'damn',
#   'thing',
#   'honey',
#   'cried',
#   'cried',
#   'know',
#   'wouldnt',
#   'told',
#   'nobody',
#   'died',
#   'died',
#   'died',
#   'oh',
#   'shame',
#   'rainy',
#   'ending',
#   'given',
#   'perfect',
#   'day',
#   'every',
#   'smile',
#   'fake',
#   'condescending',
#   'counting',
#   'scars',
#   'made',
#   'im',
#   'sitting',
#   'thinking',
#   'ive',
#   'never',
#   'anywhere',
#   'cold'],
#  ('taylorswift', 'imonlymewhenimwithyou'): ['im',
#   'im',
#   'friday',
#   'night',
#   'beneath',
#   'stars',
#   'field',
#   'behind',
#   'yard',
#   'paintin',
#   'pictures',
#   'sky',
#   'sometimes',
#   'dont',
#   'say',
#   'thing',
#   'listen',
#   'crickets',
#   'sing',
#   'everything',
#   'need',
#   'right',
#   'side',
#   'know',
#   'everything',
#   'dont',
#   'wanna',
#   'live',
#   'without',
#   'im',
#   'youre',
#   'dont',
#   'wanna',
#   'fly',
#   'youre',
#   'still',
#   'ground',
#   'like',
#   'matter',
#   'well',
#   'drive',
#   'crazy',
#   'half',
#   'time',
#   'half',
#   'im',
#   'tryna',
#   'let',
#   'know',
#   'feel',
#   'true',
#   'im',
#   'im',
#   'small',
#   'town',
#   'boy',
#   'girl',
#   'livin',
#   'crazy',
#   'world',
#   'tryna',
#   'figure',
#   'isnt',
#   'true',
#   'dont',
#   'try',
#   'hide',
#   'tears',
#   'secrets',
#   'deepest',
#   'fears',
#   'nobody',
#   'gets',
#   'like',
#   'know',
#   'everything',
#   'say',
#   'cant',
#   'live',
#   'without',
#   'im',
#   'youre',
#   'dont',
#   'wanna',
#   'fly',
#   'youre',
#   'still',
#   'ground',
#   'like',
#   'matter',
#   'well',
#   'drive',
#   'crazy',
#   'half',
#   'time',
#   'half',
#   'im',
#   'tryna',
#   'let',
#   'know',
#   'feel',
#   'true',
#   'im',
#   'im',
#   'im',
#   'anybody',
#   'else',
#   'hard',
#   'tell',
#   'im',
#   'youre',
#   'dont',
#   'wanna',
#   'fly',
#   'youre',
#   'still',
#   'ground',
#   'like',
#   'matter',
#   'well',
#   'drive',
#   'crazy',
#   'half',
#   'time',
#   'half',
#   'im',
#   'tryna',
#   'let',
#   'know',
#   'feel',
#   'true',
#   'im',
#   'wanna',
#   'well',
#   'im',
#   'im'],
#  ('taylorswift', 'invisible'): ['invisible',
#   'cant',
#   'see',
#   'way',
#   'eyes',
#   'light',
#   'smile',
#   'shell',
#   'never',
#   'notice',
#   'stop',
#   'stare',
#   'whenever',
#   'walks',
#   'cant',
#   'see',
#   'wantin',
#   'way',
#   'want',
#   'everything',
#   'wanna',
#   'show',
#   'dont',
#   'even',
#   'know',
#   'shes',
#   'never',
#   'gonna',
#   'love',
#   'like',
#   'want',
#   'see',
#   'right',
#   'knew',
#   'could',
#   'beautiful',
#   'miracle',
#   'unbelievable',
#   'instead',
#   'invisible',
#   'theres',
#   'fire',
#   'inside',
#   'cant',
#   'help',
#   'shine',
#   'shes',
#   'never',
#   'gonna',
#   'see',
#   'light',
#   'matter',
#   'think',
#   'make',
#   'think',
#   'everything',
#   'could',
#   'wanna',
#   'show',
#   'dont',
#   'even',
#   'know',
#   'shes',
#   'never',
#   'gonna',
#   'love',
#   'like',
#   'want',
#   'see',
#   'right',
#   'knew',
#   'could',
#   'beautiful',
#   'miracle',
#   'unbelievable',
#   'instead',
#   'invisible',
#   'like',
#   'shadows',
#   'faded',
#   'light',
#   'oh',
#   'invisible',
#   'wanna',
#   'open',
#   'eyes',
#   'make',
#   'realize',
#   'wanna',
#   'show',
#   'dont',
#   'even',
#   'know',
#   'baby',
#   'let',
#   'love',
#   'let',
#   'want',
#   'see',
#   'right',
#   'knew',
#   'could',
#   'beautiful',
#   'miracle',
#   'unbelievable',
#   'instead',
#   'invisible',
#   'cant',
#   'see',
#   'way',
#   'eyes',
#   'light',
#   'smile'],
#  ('taylorswift', 'jumpthenfall'): ['jump',
#   'fall',
#   'like',
#   'way',
#   'sound',
#   'morning',
#   'phone',
#   'without',
#   'warning',
#   'realize',
#   'laugh',
#   'best',
#   'sound',
#   'ever',
#   'heard',
#   'like',
#   'way',
#   'cant',
#   'keep',
#   'focus',
#   'watch',
#   'talk',
#   'didnt',
#   'notice',
#   'hear',
#   'words',
#   'think',
#   'together',
#   'every',
#   'time',
#   'smile',
#   'smile',
#   'every',
#   'time',
#   'shine',
#   'ill',
#   'shine',
#   'whoa',
#   'oh',
#   'im',
#   'feeling',
#   'baby',
#   'dont',
#   'afraid',
#   'jump',
#   'fall',
#   'jump',
#   'fall',
#   'baby',
#   'im',
#   'never',
#   'gonna',
#   'leave',
#   'say',
#   'wanna',
#   'cause',
#   'imma',
#   'stay',
#   'jump',
#   'fall',
#   'well',
#   'like',
#   'way',
#   'hair',
#   'falls',
#   'face',
#   'got',
#   'keys',
#   'love',
#   'freckle',
#   'face',
#   'oh',
#   'ive',
#   'never',
#   'wrapped',
#   'honey',
#   'like',
#   'way',
#   'youre',
#   'everything',
#   'ever',
#   'wanted',
#   'time',
#   'think',
#   'say',
#   'come',
#   'closer',
#   'take',
#   'deep',
#   'breath',
#   'jump',
#   'fall',
#   'cause',
#   'every',
#   'time',
#   'smile',
#   'smile',
#   'every',
#   'time',
#   'shine',
#   'ill',
#   'shine',
#   'whoa',
#   'oh',
#   'im',
#   'feeling',
#   'baby',
#   'dont',
#   'afraid',
#   'jump',
#   'fall',
#   'jump',
#   'fall',
#   'baby',
#   'im',
#   'never',
#   'gonna',
#   'leave',
#   'say',
#   'wanna',
#   'cause',
#   'imma',
#   'stay',
#   'jump',
#   'fall',
#   'bottoms',
#   'gonna',
#   'drop',
#   'feet',
#   'ill',
#   'catch',
#   'ill',
#   'catch',
#   'people',
#   'say',
#   'things',
#   'bring',
#   'knees',
#   'ill',
#   'catch',
#   'time',
#   'gonna',
#   'come',
#   'youre',
#   'mad',
#   'could',
#   'cry',
#   'ill',
#   'hold',
#   'night',
#   'smile',
#   'whoa',
#   'oh',
#   'need',
#   'baby',
#   'dont',
#   'afraid',
#   'please',
#   'jump',
#   'fall',
#   'jump',
#   'fall',
#   'baby',
#   'im',
#   'never',
#   'gonna',
#   'leave',
#   'say',
#   'wanna',
#   'cause',
#   'imma',
#   'stay',
#   'jump',
#   'fall',
#   'jump',
#   'fall',
#   'baby',
#   'jump',
#   'fall',
#   'every',
#   'time',
#   'smile',
#   'smile',
#   'every',
#   'time',
#   'shine',
#   'ill',
#   'shine',
#   'every',
#   'time',
#   'youre',
#   'baby',
#   'ill',
#   'show',
#   'ill',
#   'show',
#   'jump',
#   'fall',
#   'jump',
#   'fall',
#   'jump',
#   'fall',
#   'yeah'],
#  ('taylorswift', 'lastchristmas'): ['last',
#   'christmas',
#   'last',
#   'christmas',
#   'gave',
#   'heart',
#   'next',
#   'day',
#   'gave',
#   'away',
#   'year',
#   'save',
#   'tears',
#   'ill',
#   'give',
#   'someone',
#   'special',
#   'bitten',
#   'twice',
#   'shy',
#   'keep',
#   'distance',
#   'still',
#   'catch',
#   'eye',
#   'tell',
#   'baby',
#   'recognize',
#   'well',
#   'year',
#   'doesnt',
#   'surprise',
#   'merry',
#   'christmas',
#   'wrapped',
#   'sent',
#   'note',
#   'saying',
#   'love',
#   'meant',
#   'know',
#   'fool',
#   'ive',
#   'kissed',
#   'know',
#   'youd',
#   'fool',
#   'last',
#   'christmas',
#   'gave',
#   'heart',
#   'next',
#   'day',
#   'gave',
#   'away',
#   'year',
#   'save',
#   'tears',
#   'ill',
#   'give',
#   'someone',
#   'special',
#   'last',
#   'christmas',
#   'gave',
#   'heart',
#   'next',
#   'day',
#   'gave',
#   'away',
#   'year',
#   'save',
#   'tears',
#   'ill',
#   'give',
#   'someone',
#   'special',
#   'crowded',
#   'room',
#   'friends',
#   'tired',
#   'eyes',
#   'im',
#   'hiding',
#   'soul',
#   'ice',
#   'god',
#   'thought',
#   'someone',
#   'rely',
#   'guess',
#   'shoulder',
#   'cry',
#   'face',
#   'lover',
#   'fire',
#   'heart',
#   'girl',
#   'cover',
#   'tore',
#   'apart',
#   'maybe',
#   'year',
#   'maybe',
#   'year',
#   'ill',
#   'give',
#   'someone',
#   'special',
#   'cause',
#   'last',
#   'christmas',
#   'gave',
#   'heart',
#   'next',
#   'day',
#   'gave',
#   'away',
#   'year',
#   'save',
#   'tears',
#   'ill',
#   'give',
#   'someone',
#   'special',
#   'last',
#   'christmas',
#   'gave',
#   'heart',
#   'next',
#   'day',
#   'gave',
#   'away',
#   'year',
#   'save',
#   'tears',
#   'ill',
#   'give',
#   'someone',
#   'special',
#   'last',
#   'christmas',
#   'year',
#   'wont',
#   'anything',
#   'like',
#   'anything',
#   'like',
#   'last',
#   'christmas',
#   'gave',
#   'heart',
#   'next',
#   'day',
#   'gave',
#   'away',
#   'year',
#   'save',
#   'tears',
#   'ill',
#   'give',
#   'someone',
#   'special'],
#  ('taylorswift', 'maryssongohmymymy'): ['marys',
#   'song',
#   'oh',
#   'said',
#   'seven',
#   'nine',
#   'looked',
#   'like',
#   'stars',
#   'shined',
#   'sky',
#   'pretty',
#   'lights',
#   'daddies',
#   'used',
#   'joke',
#   'two',
#   'us',
#   'growing',
#   'falling',
#   'love',
#   'mamas',
#   'smiled',
#   'rolled',
#   'eyes',
#   'said',
#   'oh',
#   'take',
#   'back',
#   'house',
#   'backyard',
#   'tree',
#   'said',
#   'youd',
#   'beat',
#   'bigger',
#   'never',
#   'never',
#   'take',
#   'back',
#   'world',
#   'one',
#   'block',
#   'wide',
#   'dared',
#   'kiss',
#   'ran',
#   'tried',
#   'two',
#   'kids',
#   'oh',
#   'well',
#   'sixteen',
#   'suddenly',
#   'wasnt',
#   'little',
#   'girl',
#   'used',
#   'see',
#   'eyes',
#   'still',
#   'shined',
#   'like',
#   'pretty',
#   'lights',
#   'daddies',
#   'used',
#   'joke',
#   'two',
#   'us',
#   'never',
#   'believed',
#   'wed',
#   'really',
#   'fall',
#   'love',
#   'mamas',
#   'smiled',
#   'rolled',
#   'eyes',
#   'said',
#   'oh',
#   'take',
#   'back',
#   'creek',
#   'beds',
#   'turned',
#   'two',
#   'riding',
#   'truck',
#   'need',
#   'next',
#   'take',
#   'back',
#   'time',
#   'first',
#   'fight',
#   'slamming',
#   'doors',
#   'instead',
#   'kissing',
#   'goodnight',
#   'stayed',
#   'outside',
#   'til',
#   'morning',
#   'light',
#   'oh',
#   'years',
#   'gone',
#   'come',
#   'around',
#   'sitting',
#   'favorite',
#   'spot',
#   'town',
#   'looked',
#   'got',
#   'one',
#   'knee',
#   'take',
#   'back',
#   'time',
#   'walked',
#   'aisle',
#   'whole',
#   'town',
#   'came',
#   'mamas',
#   'cried',
#   'said',
#   'take',
#   'home',
#   'met',
#   'many',
#   'years',
#   'well',
#   'rock',
#   'babies',
#   'front',
#   'porch',
#   'time',
#   'ill',
#   'eightyseven',
#   'youll',
#   'eightynine',
#   'ill',
#   'still',
#   'look',
#   'like',
#   'stars',
#   'shine',
#   'sky',
#   'oh'],
#  ('taylorswift', 'oursong'): ['song',
#   'riding',
#   'shotgun',
#   'hair',
#   'undone',
#   'front',
#   'seat',
#   'car',
#   'hes',
#   'got',
#   'onehand',
#   'feel',
#   'steering',
#   'wheel',
#   'heart',
#   'look',
#   'around',
#   'turn',
#   'radio',
#   'says',
#   'baby',
#   'something',
#   'wrong',
#   'say',
#   'nothing',
#   'thinking',
#   'dont',
#   'song',
#   'says',
#   'song',
#   'slamming',
#   'screen',
#   'door',
#   'sneakin',
#   'late',
#   'tapping',
#   'window',
#   'phone',
#   'talk',
#   'real',
#   'slow',
#   'cause',
#   'late',
#   'mama',
#   'dont',
#   'know',
#   'song',
#   'way',
#   'laugh',
#   'first',
#   'date',
#   'man',
#   'didnt',
#   'kiss',
#   'got',
#   'home',
#   'fore',
#   'said',
#   'amen',
#   'asking',
#   'god',
#   'could',
#   'play',
#   'walking',
#   'front',
#   'porch',
#   'steps',
#   'everything',
#   'day',
#   'gone',
#   'wrong',
#   'trampled',
#   'lost',
#   'thrown',
#   'away',
#   'got',
#   'hallway',
#   'well',
#   'way',
#   'lovin',
#   'bed',
#   'almost',
#   'didnt',
#   'notice',
#   'roses',
#   'note',
#   'said',
#   'song',
#   'slamming',
#   'screen',
#   'door',
#   'sneakin',
#   'late',
#   'tapping',
#   'window',
#   'phone',
#   'talk',
#   'real',
#   'slow',
#   'cause',
#   'late',
#   'mama',
#   'dont',
#   'know',
#   'song',
#   'way',
#   'laugh',
#   'first',
#   'date',
#   'man',
#   'didnt',
#   'kiss',
#   'got',
#   'home',
#   'fore',
#   'said',
#   'amen',
#   'asking',
#   'god',
#   'could',
#   'play',
#   'ive',
#   'heard',
#   'every',
#   'album',
#   'listened',
#   'radio',
#   'waited',
#   'something',
#   'come',
#   'along',
#   'good',
#   'song',
#   'cause',
#   'song',
#   'slamming',
#   'screen',
#   'door',
#   'sneakin',
#   'late',
#   'tapping',
#   'window',
#   'phone',
#   'talks',
#   'real',
#   'slow',
#   'cause',
#   'late',
#   'mama',
#   'dont',
#   'know',
#   'song',
#   'way',
#   'laughs',
#   'first',
#   'date',
#   'man',
#   'didnt',
#   'kiss',
#   'got',
#   'home',
#   'fore',
#   'said',
#   'amen',
#   'asking',
#   'god',
#   'could',
#   'play',
#   'play',
#   'oh',
#   'yeah',
#   'ohoh',
#   'yeah',
#   'riding',
#   'shotgun',
#   'hair',
#   'undone',
#   'front',
#   'seat',
#   'car',
#   'grabbed',
#   'pen',
#   'old',
#   'napkin',
#   'wrote',
#   'song'],
#  ('taylorswift', 'picturetoburn'): ['picture',
#   'burn',
#   'state',
#   'obvious',
#   'didnt',
#   'get',
#   'perfect',
#   'fantasy',
#   'realize',
#   'love',
#   'could',
#   'ever',
#   'love',
#   'go',
#   'tell',
#   'friends',
#   'im',
#   'obsessive',
#   'crazy',
#   'thats',
#   'fine',
#   'ill',
#   'tell',
#   'mine',
#   'youre',
#   'gay',
#   'way',
#   'hate',
#   'stupid',
#   'old',
#   'pickup',
#   'truck',
#   'never',
#   'let',
#   'drive',
#   'youre',
#   'redneck',
#   'heartbreak',
#   'whos',
#   'really',
#   'bad',
#   'lying',
#   'watch',
#   'strike',
#   'match',
#   'wasted',
#   'time',
#   'far',
#   'im',
#   'concerned',
#   'youre',
#   'another',
#   'picture',
#   'burn',
#   'theres',
#   'time',
#   'tears',
#   'im',
#   'sitting',
#   'planning',
#   'revenge',
#   'theres',
#   'nothing',
#   'stopping',
#   'going',
#   'best',
#   'friends',
#   'come',
#   'around',
#   'saying',
#   'sorry',
#   'daddys',
#   'gonna',
#   'show',
#   'sorry',
#   'youll',
#   'cause',
#   'hate',
#   'stupid',
#   'old',
#   'pickup',
#   'truck',
#   'never',
#   'let',
#   'drive',
#   'youre',
#   'redneck',
#   'heartbreak',
#   'whos',
#   'really',
#   'bad',
#   'lying',
#   'watch',
#   'strike',
#   'match',
#   'wasted',
#   'time',
#   'far',
#   'im',
#   'concerned',
#   'youre',
#   'another',
#   'picture',
#   'burn',
#   'youre',
#   'missing',
#   'youd',
#   'better',
#   'keep',
#   'cause',
#   'coming',
#   'back',
#   'around',
#   'would',
#   'bad',
#   'health',
#   'cause',
#   'hate',
#   'stupid',
#   'old',
#   'pickup',
#   'truck',
#   'never',
#   'let',
#   'drive',
#   'youre',
#   'redneck',
#   'heartbreak',
#   'whos',
#   'really',
#   'bad',
#   'lying',
#   'watch',
#   'strike',
#   'match',
#   'wasted',
#   'time',
#   'case',
#   'havent',
#   'heard',
#   'really',
#   'really',
#   'hate',
#   'stupid',
#   'old',
#   'pickup',
#   'truck',
#   'never',
#   'let',
#   'drive',
#   'youre',
#   'redneck',
#   'heartbreak',
#   'whos',
#   'really',
#   'bad',
#   'lying',
#   'watch',
#   'strike',
#   'match',
#   'wasted',
#   'time',
#   'far',
#   'im',
#   'concerned',
#   'youre',
#   'another',
#   'picture',
#   'burn',
#   'burn',
#   'burn',
#   'burn',
#   'baby',
#   'burn',
#   'youre',
#   'another',
#   'picture',
#   'burn',
#   'baby',
#   'burn'],
#  ('taylorswift', 'santababy'): ['santa',
#   'baby',
#   'santa',
#   'baby',
#   'slip',
#   'sable',
#   'tree',
#   'ive',
#   'awful',
#   'good',
#   'girl',
#   'santa',
#   'baby',
#   'hurry',
#   'chimney',
#   'tonight',
#   'santa',
#   'baby',
#   '54',
#   'convertible',
#   'light',
#   'blue',
#   'well',
#   'ill',
#   'wait',
#   'dear',
#   'santa',
#   'baby',
#   'hurry',
#   'chimney',
#   'tonight',
#   'yeah',
#   'think',
#   'fun',
#   'ive',
#   'missed',
#   'think',
#   'boys',
#   'havent',
#   'kissed',
#   'next',
#   'year',
#   'could',
#   'good',
#   'check',
#   'christmas',
#   'list',
#   'santa',
#   'baby',
#   'want',
#   'yacht',
#   'really',
#   'thats',
#   'lot',
#   'ive',
#   'angel',
#   'year',
#   'santa',
#   'baby',
#   'hurry',
#   'chimney',
#   'tonight',
#   'santa',
#   'honey',
#   'theres',
#   'one',
#   'thing',
#   'really',
#   'need',
#   'deed',
#   'platinum',
#   'mine',
#   'santa',
#   'honey',
#   'hurry',
#   'chimney',
#   'tonight',
#   'come',
#   'trim',
#   'christmas',
#   'tree',
#   'decorations',
#   'bought',
#   'tiffanys',
#   'really',
#   'believe',
#   'lets',
#   'see',
#   'believe',
#   'santa',
#   'baby',
#   'forgot',
#   'mention',
#   'one',
#   'little',
#   'thing',
#   'ring',
#   'dont',
#   'mean',
#   'phone',
#   'santa',
#   'baby',
#   'hurry',
#   'chimney',
#   'tonight'],
#  ('taylorswift', 'shouldvesaidno'): ['shouldve',
#   'said',
#   'strange',
#   'think',
#   'songs',
#   'used',
#   'sing',
#   'smiles',
#   'flowers',
#   'everything',
#   'gone',
#   'yesterday',
#   'found',
#   'even',
#   'looking',
#   'feels',
#   'wrong',
#   'say',
#   'youd',
#   'take',
#   'back',
#   'given',
#   'one',
#   'chance',
#   'moment',
#   'weakness',
#   'said',
#   'yes',
#   'shouldve',
#   'said',
#   'shouldve',
#   'gone',
#   'home',
#   'shouldve',
#   'thought',
#   'twice',
#   'fore',
#   'let',
#   'go',
#   'shouldve',
#   'known',
#   'word',
#   'bout',
#   'herd',
#   'get',
#   'back',
#   'get',
#   'back',
#   'shouldve',
#   'back',
#   'mind',
#   'shouldnt',
#   'asking',
#   'shouldnt',
#   'begging',
#   'forgiveness',
#   'feet',
#   'shouldve',
#   'said',
#   'baby',
#   'might',
#   'still',
#   'see',
#   'ive',
#   'crying',
#   'baby',
#   'know',
#   'right',
#   'things',
#   'say',
#   'honestly',
#   'expect',
#   'believe',
#   'could',
#   'ever',
#   'say',
#   'past',
#   'past',
#   'need',
#   'one',
#   'chance',
#   'moment',
#   'weakness',
#   'said',
#   'yes',
#   'shouldve',
#   'said',
#   'shouldve',
#   'gone',
#   'home',
#   'shouldve',
#   'thought',
#   'twice',
#   'fore',
#   'let',
#   'go',
#   'shouldve',
#   'known',
#   'word',
#   'bout',
#   'herd',
#   'get',
#   'back',
#   'get',
#   'back',
#   'shouldve',
#   'back',
#   'mind',
#   'shouldnt',
#   'asking',
#   'shouldnt',
#   'begging',
#   'forgiveness',
#   'feet',
#   'shouldve',
#   'said',
#   'baby',
#   'might',
#   'still',
#   'cant',
#   'resist',
#   'go',
#   'tell',
#   'worth',
#   'worth',
#   'shouldve',
#   'said',
#   'shouldve',
#   'gone',
#   'home',
#   'shouldve',
#   'thought',
#   'twice',
#   'fore',
#   'let',
#   'go',
#   'shouldve',
#   'known',
#   'word',
#   'bout',
#   'herd',
#   'get',
#   'back',
#   'get',
#   'back',
#   'shouldve',
#   'back',
#   'mind',
#   'shouldnt',
#   'asking',
#   'shouldnt',
#   'begging',
#   'forgiveness',
#   'feet',
#   'shouldve',
#   'said',
#   'baby',
#   'might',
#   'still'],
#  ('taylorswift', 'silentnight'): ['silent',
#   'night',
#   'silent',
#   'night',
#   'holy',
#   'night',
#   'calm',
#   'bright',
#   'round',
#   'yon',
#   'virgin',
#   'mother',
#   'child',
#   'holy',
#   'infant',
#   'tender',
#   'mild',
#   'sleep',
#   'heavenly',
#   'peace',
#   'sleep',
#   'heavenly',
#   'peace',
#   'silent',
#   'night',
#   'holy',
#   'night',
#   'shepherds',
#   'quake',
#   'sight',
#   'glories',
#   'stream',
#   'heaven',
#   'afar',
#   'heavenly',
#   'hosts',
#   'sing',
#   'hallelujah',
#   'christ',
#   'saviour',
#   'born',
#   'christ',
#   'saviour',
#   'born',
#   'silent',
#   'night',
#   'holy',
#   'night',
#   'son',
#   'god',
#   'loves',
#   'pure',
#   'light',
#   'radiant',
#   'beams',
#   'thy',
#   'holy',
#   'face',
#   'dawn',
#   'redeeming',
#   'grace',
#   'jesus',
#   'lord',
#   'thy',
#   'birth',
#   'jesus',
#   'lord',
#   'thy',
#   'birth',
#   'hallelujah',
#   'hallelujah',
#   'hallelujah',
#   'christ',
#   'saviour',
#   'born'],
#  ('taylorswift', 'staybeautiful'): ['stay',
#   'beautiful',
#   'corys',
#   'eyes',
#   'like',
#   'jungle',
#   'smiles',
#   'like',
#   'radio',
#   'whispers',
#   'songs',
#   'window',
#   'words',
#   'nobody',
#   'knows',
#   'theres',
#   'pretty',
#   'girls',
#   'every',
#   'corner',
#   'watch',
#   'hes',
#   'walking',
#   'home',
#   'saying',
#   'know',
#   'ever',
#   'know',
#   'youre',
#   'beautiful',
#   'every',
#   'little',
#   'piece',
#   'love',
#   'dont',
#   'know',
#   'youre',
#   'really',
#   'gonna',
#   'someone',
#   'ask',
#   'anyone',
#   'find',
#   'everything',
#   'looked',
#   'hope',
#   'life',
#   'leads',
#   'back',
#   'door',
#   'oh',
#   'dont',
#   'stay',
#   'beautiful',
#   'cory',
#   'finds',
#   'another',
#   'way',
#   'highlight',
#   'day',
#   'im',
#   'taking',
#   'pictures',
#   'mind',
#   'save',
#   'rainy',
#   'day',
#   'hard',
#   'make',
#   'conversation',
#   'hes',
#   'taking',
#   'breath',
#   'away',
#   'say',
#   'hey',
#   'way',
#   'youre',
#   'beautiful',
#   'every',
#   'little',
#   'piece',
#   'love',
#   'dont',
#   'know',
#   'youre',
#   'really',
#   'gonna',
#   'someone',
#   'ask',
#   'anyone',
#   'find',
#   'everything',
#   'looked',
#   'hope',
#   'life',
#   'leads',
#   'back',
#   'door',
#   'oh',
#   'dont',
#   'stay',
#   'beautiful',
#   'story',
#   'never',
#   'gets',
#   'told',
#   'daydream',
#   'ill',
#   'never',
#   'get',
#   'hold',
#   'least',
#   'youll',
#   'know',
#   'youre',
#   'beautiful',
#   'every',
#   'little',
#   'piece',
#   'love',
#   'dont',
#   'know',
#   'youre',
#   'really',
#   'gonna',
#   'someone',
#   'ask',
#   'anyone',
#   'find',
#   'everything',
#   'looked',
#   'hope',
#   'life',
#   'leads',
#   'back',
#   'front',
#   'door',
#   'oh',
#   'dont',
#   'stay',
#   'beautiful',
#   'beautiful',
#   'beautiful',
#   'beautiful',
#   'beautiful',
#   'beautiful',
#   'la',
#   'la',
#   'la',
#   'oh',
#   'oh',
#   'oh',
#   'oh',
#   'oh',
#   'dont',
#   'stay',
#   'beautiful',
#   'stay',
#   'beautiful',
#   'na',
#   'na',
#   'na',
#   'na',
#   'na'],
#  ('taylorswift', 'teardropsonmyguitar'): ['teardrops',
#   'guitar',
#   'drew',
#   'looks',
#   'fake',
#   'smile',
#   'wont',
#   'see',
#   'want',
#   'im',
#   'needing',
#   'everything',
#   'ill',
#   'bet',
#   'shes',
#   'beautiful',
#   'girl',
#   'talks',
#   'shes',
#   'got',
#   'everything',
#   'live',
#   'without',
#   'drew',
#   'talks',
#   'laugh',
#   'cause',
#   'funny',
#   'cant',
#   'even',
#   'see',
#   'anyone',
#   'hes',
#   'says',
#   'hes',
#   'love',
#   'hes',
#   'finally',
#   'got',
#   'right',
#   'wonder',
#   'knows',
#   'hes',
#   'think',
#   'night',
#   'hes',
#   'reason',
#   'teardrops',
#   'guitar',
#   'thing',
#   'keeps',
#   'wishing',
#   'wishing',
#   'star',
#   'hes',
#   'song',
#   'car',
#   'keep',
#   'singing',
#   'dont',
#   'know',
#   'drew',
#   'walks',
#   'tell',
#   'cant',
#   'breathe',
#   'goes',
#   'perfectly',
#   'kind',
#   'flawless',
#   'wish',
#   'could',
#   'shed',
#   'better',
#   'hold',
#   'tight',
#   'give',
#   'love',
#   'look',
#   'beautiful',
#   'eyes',
#   'know',
#   'shes',
#   'lucky',
#   'cause',
#   'hes',
#   'reason',
#   'teardrops',
#   'guitar',
#   'thing',
#   'keeps',
#   'wishing',
#   'wishing',
#   'star',
#   'hes',
#   'song',
#   'car',
#   'keep',
#   'singing',
#   'dont',
#   'know',
#   'drive',
#   'home',
#   'alone',
#   'turn',
#   'light',
#   'ill',
#   'put',
#   'picture',
#   'maybe',
#   'get',
#   'sleep',
#   'tonight',
#   'cause',
#   'hes',
#   'reason',
#   'teardrops',
#   'guitar',
#   'one',
#   'whos',
#   'got',
#   'enough',
#   'break',
#   'heart',
#   'hes',
#   'song',
#   'car',
#   'keep',
#   'singing',
#   'dont',
#   'know',
#   'hes',
#   'time',
#   'taken',
#   'theres',
#   'never',
#   'enough',
#   'hes',
#   'need',
#   'fall',
#   'drew',
#   'looks',
#   'fake',
#   'smile',
#   'wont',
#   'see'],
#  ('taylorswift', 'theoutside'): ['outside',
#   'didnt',
#   'know',
#   'would',
#   'find',
#   'went',
#   'looking',
#   'reason',
#   'know',
#   'didnt',
#   'read',
#   'lines',
#   'baby',
#   'ive',
#   'got',
#   'nowhere',
#   'go',
#   'tried',
#   'take',
#   'road',
#   'less',
#   'traveled',
#   'nothing',
#   'seems',
#   'work',
#   'first',
#   'times',
#   'right',
#   'ever',
#   'try',
#   'better',
#   'nobody',
#   'ever',
#   'lets',
#   'still',
#   'see',
#   'aint',
#   'best',
#   'view',
#   'outside',
#   'looking',
#   'ive',
#   'lot',
#   'lonely',
#   'places',
#   'ive',
#   'never',
#   'outside',
#   'saw',
#   'never',
#   'knew',
#   'would',
#   'give',
#   'part',
#   'part',
#   'late',
#   'see',
#   'couldve',
#   'helped',
#   'wanted',
#   'one',
#   'notices',
#   'late',
#   'anything',
#   'ever',
#   'try',
#   'better',
#   'nobody',
#   'ever',
#   'lets',
#   'still',
#   'see',
#   'aint',
#   'best',
#   'view',
#   'outside',
#   'looking',
#   'ive',
#   'lot',
#   'lonely',
#   'places',
#   'ive',
#   'never',
#   'outside',
#   'oh',
#   'yeah',
#   'ever',
#   'try',
#   'better',
#   'nobody',
#   'ever',
#   'lets',
#   'still',
#   'see',
#   'aint',
#   'best',
#   'view',
#   'outside',
#   'looking',
#   'ive',
#   'lot',
#   'lonely',
#   'places',
#   'ive',
#   'never',
#   'outside'],
#  ('taylorswift', 'tiedtogetherwithasmile'): ['tied',
#   'together',
#   'smile',
#   'seems',
#   'one',
#   'doesnt',
#   'see',
#   'beauty',
#   'face',
#   'mirror',
#   'looking',
#   'back',
#   'walk',
#   'around',
#   'thinking',
#   'youre',
#   'pretty',
#   'thats',
#   'true',
#   'cause',
#   'know',
#   'hold',
#   'baby',
#   'youre',
#   'losing',
#   'waters',
#   'high',
#   'youre',
#   'jumping',
#   'letting',
#   'go',
#   'one',
#   'knows',
#   'cry',
#   'dont',
#   'tell',
#   'anyone',
#   'might',
#   'golden',
#   'one',
#   'youre',
#   'tied',
#   'together',
#   'smile',
#   'youre',
#   'coming',
#   'undone',
#   'guess',
#   'true',
#   'love',
#   'wanted',
#   'cause',
#   'youre',
#   'giving',
#   'away',
#   'like',
#   'extra',
#   'change',
#   'hoping',
#   'end',
#   'pocket',
#   'leaves',
#   'like',
#   'penny',
#   'rain',
#   'oh',
#   'cause',
#   'price',
#   'pay',
#   'price',
#   'pay',
#   'hold',
#   'baby',
#   'youre',
#   'losing',
#   'waters',
#   'high',
#   'youre',
#   'jumping',
#   'letting',
#   'go',
#   'one',
#   'knows',
#   'cry',
#   'dont',
#   'tell',
#   'anyone',
#   'might',
#   'golden',
#   'one',
#   'youre',
#   'tied',
#   'together',
#   'smile',
#   'youre',
#   'coming',
#   'undone',
#   'hold',
#   'baby',
#   'youre',
#   'losing',
#   'waters',
#   'high',
#   'youre',
#   'jumping',
#   'letting',
#   'go',
#   'one',
#   'knows',
#   'cry',
#   'dont',
#   'tell',
#   'anyone',
#   'might',
#   'golden',
#   'one',
#   'youre',
#   'tied',
#   'together',
#   'smile',
#   'youre',
#   'coming',
#   'undone',
#   'youre',
#   'tied',
#   'together',
#   'smile',
#   'youre',
#   'coming',
#   'undone',
#   'goodbye',
#   'baby',
#   'smile',
#   'baby',
#   'baby'],
#  ('taylorswift', 'timmcgraw'): ['tim',
#   'mcgraw',
#   'said',
#   'way',
#   'blue',
#   'eyes',
#   'shined',
#   'put',
#   'georgia',
#   'stars',
#   'shame',
#   'night',
#   'said',
#   'thats',
#   'lie',
#   'boy',
#   'chevy',
#   'truck',
#   'tendency',
#   'gettin',
#   'stuck',
#   'back',
#   'roads',
#   'night',
#   'right',
#   'beside',
#   'summer',
#   'long',
#   'time',
#   'woke',
#   'find',
#   'summer',
#   'gone',
#   'think',
#   'tim',
#   'mcgraw',
#   'hope',
#   'think',
#   'favorite',
#   'song',
#   'one',
#   'danced',
#   'night',
#   'long',
#   'moon',
#   'like',
#   'spotlight',
#   'lake',
#   'think',
#   'happiness',
#   'hope',
#   'think',
#   'little',
#   'black',
#   'dress',
#   'think',
#   'head',
#   'chest',
#   'old',
#   'faded',
#   'blue',
#   'jeans',
#   'think',
#   'tim',
#   'mcgraw',
#   'hope',
#   'think',
#   'september',
#   'saw',
#   'month',
#   'tears',
#   'thankin',
#   'god',
#   'werent',
#   'see',
#   'like',
#   'box',
#   'beneath',
#   'bed',
#   'letter',
#   'never',
#   'read',
#   'three',
#   'summers',
#   'back',
#   'hard',
#   'find',
#   'little',
#   'bittersweet',
#   'lookin',
#   'back',
#   'nice',
#   'believe',
#   'think',
#   'tim',
#   'mcgraw',
#   'hope',
#   'think',
#   'favorite',
#   'song',
#   'one',
#   'danced',
#   'night',
#   'long',
#   'moon',
#   'like',
#   'spotlight',
#   'lake',
#   'think',
#   'happiness',
#   'hope',
#   'think',
#   'little',
#   'black',
#   'dress',
#   'think',
#   'head',
#   'chest',
#   'old',
#   'faded',
#   'blue',
#   'jeans',
#   'think',
#   'tim',
#   'mcgraw',
#   'hope',
#   'think',
#   'im',
#   'back',
#   'first',
#   'time',
#   'since',
#   'im',
#   'standin',
#   'street',
#   'theres',
#   'letter',
#   'left',
#   'doorstep',
#   'first',
#   'thing',
#   'youll',
#   'read',
#   'think',
#   'tim',
#   'mcgraw',
#   'hope',
#   'think',
#   'favorite',
#   'song',
#   'someday',
#   'youll',
#   'turn',
#   'radio',
#   'hope',
#   'takes',
#   'back',
#   'place',
#   'think',
#   'happiness',
#   'hope',
#   'think',
#   'little',
#   'black',
#   'dress',
#   'think',
#   'head',
#   'chest',
#   'old',
#   'faded',
#   'blue',
#   'jeans',
#   'think',
#   'tim',
#   'mcgraw',
#   'hope',
#   'think',
#   'oh',
#   'think',
#   'mmmm',
#   'said',
#   'way',
#   'blue',
#   'eyes',
#   'shined',
#   'put',
#   'georgia',
#   'stars',
#   'shame',
#   'night',
#   'said',
#   'thats',
#   'lie'],
#  ('taylorswift', 'untouchable'): ['untouchable',
#   'untouchable',
#   'like',
#   'distant',
#   'diamond',
#   'sky',
#   'im',
#   'reaching',
#   'cant',
#   'tell',
#   'im',
#   'caught',
#   'im',
#   'caught',
#   'untouchable',
#   'burning',
#   'brighter',
#   'sun',
#   'youre',
#   'close',
#   'feel',
#   'like',
#   'coming',
#   'undone',
#   'middle',
#   'night',
#   'im',
#   'dream',
#   'like',
#   'million',
#   'little',
#   'stars',
#   'spelling',
#   'name',
#   'gotta',
#   'come',
#   'come',
#   'say',
#   'well',
#   'together',
#   'come',
#   'come',
#   'little',
#   'taste',
#   'heaven',
#   'half',
#   'full',
#   'wont',
#   'wait',
#   'day',
#   'know',
#   'youre',
#   'saying',
#   'youd',
#   'anyway',
#   'youre',
#   'untouchable',
#   'burning',
#   'brighter',
#   'sun',
#   'youre',
#   'close',
#   'feel',
#   'like',
#   'coming',
#   'undone',
#   'middle',
#   'night',
#   'im',
#   'dream',
#   'like',
#   'million',
#   'little',
#   'stars',
#   'spelling',
#   'name',
#   'gotta',
#   'come',
#   'come',
#   'say',
#   'well',
#   'together',
#   'come',
#   'come',
#   'oh',
#   'middle',
#   'night',
#   'waking',
#   'dream',
#   'wanna',
#   'feel',
#   'side',
#   'standing',
#   'next',
#   'gotta',
#   'come',
#   'come',
#   'say',
#   'well',
#   'together',
#   'come',
#   'come',
#   'little',
#   'taste',
#   'heaven',
#   'im',
#   'caught',
#   'oh',
#   'oh',
#   'youre',
#   'untouchable',
#   'burning',
#   'brighter',
#   'sun',
#   'youre',
#   'close',
#   'feel',
#   'like',
#   'coming',
#   'undone',
#   'middle',
#   'night',
#   'im',
#   'dream',
#   'like',
#   'million',
#   'little',
#   'stars',
#   'spelling',
#   'name',
#   'gotta',
#   'come',
#   'come',
#   'say',
#   'well',
#   'together',
#   'come',
#   'come',
#   'oh',
#   'oh',
#   'middle',
#   'night',
#   'im',
#   'dream',
#   'like',
#   'million',
#   'little',
#   'stars',
#   'spelling',
#   'name',
#   'gotta',
#   'come',
#   'come',
#   'say',
#   'well',
#   'together',
#   'come',
#   'come',
#   'come',
#   'middle',
#   'night',
#   'waking',
#   'dream',
#   'wanna',
#   'feel',
#   'side',
#   'standing',
#   'next',
#   'gotta',
#   'come',
#   'come',
#   'say',
#   'well',
#   'together',
#   'come',
#   'come',
#   'little',
#   'taste',
#   'heaven',
#   'middle',
#   'night',
#   'im',
#   'dream',
#   'like',
#   'million',
#   'little',
#   'stars',
#   'spelling',
#   'name',
#   'gotta',
#   'come',
#   'come',
#   'come',
#   'come',
#   'come',
#   'come',
#   'oh',
#   'oh',
#   'oh',
#   'like',
#   'million',
#   'little',
#   'stars',
#   'spelling',
#   'name',
#   'theyre',
#   'spelling',
#   'name',
#   'oh'],
#  ('taylorswift', 'whitechristmas'): ['white',
#   'christmas',
#   'im',
#   'dreaming',
#   'white',
#   'christmas',
#   'like',
#   'ones',
#   'used',
#   'know',
#   'tree',
#   'tops',
#   'glisten',
#   'children',
#   'listen',
#   'hear',
#   'sleigh',
#   'bells',
#   'snow',
#   'im',
#   'dreaming',
#   'white',
#   'christmas',
#   'every',
#   'christmas',
#   'card',
#   'write',
#   'may',
#   'days',
#   'merry',
#   'bright',
#   'may',
#   'christmases',
#   'white',
#   'im',
#   'dreaming',
#   'white',
#   'christmas',
#   'like',
#   'ones',
#   'used',
#   'know',
#   'may',
#   'days',
#   'merry',
#   'bright',
#   'may',
#   'christmases',
#   'white',
#   'may',
#   'days',
#   'merry',
#   'bright',
#   'may',
#   'christmases',
#   'white']}

# %% [markdown]
# ## Basic Descriptive Statistics
#
# Call your `descriptive_stats` function on both your lyrics data and your twitter data and for both artists (four total calls).

# %%
songDFS_3 = {}

for key, val in songDFS_2.items():
    if key[0] in songDFS_3:
        songDFS_3[key[0]] += val
    else:
        songDFS_3[key[0]] = []

# %%
songDFS_3.keys()
# Out:
# dict_keys(['blakeshelton', 'taylorswift'])

# %%
# calls to descriptive_stats here
for key, val in songDFS_3.items():
    print(f'Lyric for {key}')
    descriptive_stats(val)
    print()

for key, val in twitterDFS_2.items():
    print(f'Twitter for {key}')
    descriptive_stats(val)
    print()
# Out:
# Lyric for blakeshelton
#
# Lyric for taylorswift
#
# Twitter for taylorswift13
#
# Twitter for blakeshelton

# %% [markdown]
# Q: How do you think the "top 5 words" would be different if we left stopwords in the data?
#
# A:
# I think the top 5 words would be different if a combination of the stopwords are used often.
#
# ---
#
# Q: What were your prior beliefs about the lexical diversity between the artists? Does the difference (or lack thereof) in lexical diversity between the artists conform to your prior beliefs?
#
# A:

# %% [markdown]
# ## Specialty Statistics
#
# The descriptive statistics we have calculated are quite generic. You will now calculate a handful of statistics tailored to these data.
#
# 1. Ten most common emojis by artist in the twitter descriptions.
# 1. Ten most common hashtags by artist in the twitter descriptions.
# 1. Five most common words in song titles by artist.
# 1. For each artist, a histogram of song lengths (in terms of number of tokens)
#
# We can use the `emoji` library to help us identify emojis and you have been given a function to help you.

# %%
def is_emoji(s):
    return(s in emoji.UNICODE_EMOJI['en'])

assert(is_emoji("❤️"))
assert(not is_emoji(":-)"))

# %%
len(emoji.UNICODE_EMOJI['en'])
# Out:
# 4702

# %% [markdown]
# ### Emojis 😁
#
# What are the ten most common emojis by artist in the twitter descriptions?

# %%
# Your code here
for key, val in twitterDFS_2.items():
    d = Counter([x for x in val if is_emoji(x)])
    print(f'Top 10 most common emojis for {key}:')
    print(d.most_common(10))
    print()
# Out:
# Top 10 most common emojis for taylorswift13:
# [('\U0001fae1', 51), ('🥧', 51), ('👋🏼', 51), ('😎', 51), ('🦦', 50), ('🤍', 48), ('🇺🇸', 39), ('🚴\u200d♀️', 29), ('🌷', 28), ('💌', 23)]
#
# Top 10 most common emojis for blakeshelton:
# [('🇺🇲', 95), ('👰\u200d♀️', 50), ('💒', 44), ('🔴', 44), ('📍', 44), ('🏰', 44), ('🎵', 44), ('🥋', 44), ('💿', 44), ('💛', 33)]

# %% [markdown]
# ### Hashtags
#
# What are the ten most common hashtags by artist in the twitter descriptions?

# %%
# Your code here
for key, val in twitterDFS_2.items():
    d = Counter([x for x in val if "#" in x])
    print(f'Top 10 most common emojis for {key}:')
    print(d.most_common(10))
    print()
# Out:
# Top 10 most common emojis for taylorswift13:
# [('#ethereum', 51), ('#lula2022', 14), ('#michael:', 4)]
#
# Top 10 most common emojis for blakeshelton:
# [('#trump2024,', 51), ('#maga', 51), ('#kaga', 51), ('#teamlucabethforever', 51), ('#deadhead', 47), ('#1,', 22), ('#golf,#maga,', 7)]

# %%
emoji_df = {}
for key, val in twitterDFS_2.items():
    d = Counter([x for x in val if "#" in x])
    print(f'Top 10 most common emojis for {key}:')
    print(d.most_common(10))
    print()
# Out:
# Top 10 most common emojis for taylorswift13:
# [('#ethereum', 51), ('#lula2022', 14), ('#michael:', 4)]
#
# Top 10 most common emojis for blakeshelton:
# [('#trump2024,', 51), ('#maga', 51), ('#kaga', 51), ('#teamlucabethforever', 51), ('#deadhead', 47), ('#1,', 22), ('#golf,#maga,', 7)]

# %% [markdown]
# ### Song Titles
#
# What are the five most common words in song titles by artist? The song titles should be on the first line of the lyrics pages, so if you have kept the raw file contents around, you will not need to re-read the data.

# %%
# Your code here
#titles = {k[1]:0 for k songDFS.keys()}
titles={}
for artist in os.listdir("lyrics"):
    artist_path=os.path.join('lyrics',artist)
    for lyric_file in os.listdir(artist_path):
        artist_path=os.path.join('lyrics',artist,lyric_file)
        f=open(artist_path,'r')
        title_line=f.readline()
        title_line=title_line.lower().strip()
        s= [w for w in title_line.split(' ') if w not in sw]
        for word in s:
            if word in titles: 
                titles[word]+=1
            else:
                titles[word]=1
    print(artist)
    print(sorted(titles.items(),key=lambda x: x[1],reverse=True))
    titles={}
# Out:
# blakeshelton
# [('time', 2), ('home', 2), ('asphalt', 1), ('cowboy', 1), ('austin', 1), ('every', 1), ('look', 1), ('georgia', 1), ('jug', 1), ('heavy', 1), ("liftin'", 1), ('man', 1), ('heaven', 1), ('thought', 1), ('neck', 1), ('woods', 1), ('nobody', 1), ("ol'", 1), ('red', 1), ('playboys', 1), ('southwestern', 1), ('world', 1), ('problems', 1), ('old', 1), ('song', 1), ('know', 1), ('got', 1), ('beach', 1), ('someday', 1), ("that's", 1), ('call', 1), ('baby', 1), ('dreamer', 1), ('underneath', 1), ('moon', 1)]
# taylorswift
# [('christmas', 3), ("i'm", 2), ('song', 2), ('perfectly', 1), ('good', 1), ('heart', 1), ('place', 1), ('world', 1), ('christmases', 1), ('mine', 1), ('must', 1), ('something', 1), ('cold', 1), ('invisible', 1), ('jump', 1), ('fall', 1), ('last', 1), ("mary's", 1), ('(oh', 1), ('my)', 1), ('picture', 1), ('burn', 1), ('santa', 1), ('baby', 1), ('said', 1), ('silent', 1), ('night', 1), ('stay', 1), ('beautiful', 1), ('teardrops', 1), ('guitar', 1), ('outside', 1), ('tied', 1), ('together', 1), ('smile', 1), ('tim', 1), ('mcgraw', 1), ('untouchable', 1), ('white', 1)]

# %% [markdown]
# ### Song Lengths
#
# For each artist, a histogram of song lengths (in terms of number of tokens). If you put the song lengths in a data frame with an artist column, matplotlib will make the plotting quite easy. An example is given to help you out.

# %%
import pandas as pd
import numpy as np
import matplotlib as py

# %%
import matplotlib as py 
num_songs = 22
artist_list=[]
token_length_list=[]
for k,v in songDFS_2.items():
    artist_list.append(k[0])
    token_length_list.append(len(v))

df = pd.DataFrame({
    "artist":artist_list, 
    "length": token_length_list
})

df.groupby('artist')['length'].plot(kind="hist",density=True,alpha=0.5,legend=True)
# Out:
# artist
# blakeshelton    AxesSubplot(0.125,0.125;0.775x0.755)
# taylorswift     AxesSubplot(0.125,0.125;0.775x0.755)
# Name: length, dtype: object

# %% [markdown]
# Since the lyrics may be stored with carriage returns or tabs, it may be useful to have a function that can collapse whitespace, using regular expressions, and be used for splitting.
#
# Q: What does the regular expression `'\s+'` match on?
#
# A: \s+ will match one or more whitespace characters

# %%
collapse_whitespace = re.compile(r'\s+')

def tokenize_lyrics(lyric) : 
    """strip and split on whitespace"""
    return([item.lower() for item in collapse_whitespace.split(lyric)])

# %%
# Your lyric length comparison chart here. 

songDFS_3={}
for k, v in songDFS.items():
    s= "".join(ch for ch in v if ch not in punctuation)
    s=s.lower()
    words=tokenize_lyrics(s)
    s= [w for w in words if w not in sw]
    songDFS_3[k]=s

songDFS_3
# Out:
# {('blakeshelton', 'alloverme'): ['time',
#   'really',
#   'used',
#   'care',
#   'others',
#   'thought',
#   'way',
#   'talk',
#   'crowd',
#   'used',
#   'pull',
#   'away',
#   'would',
#   'kiss',
#   'face',
#   'touch',
#   'hair',
#   'didnt',
#   'care',
#   'saw',
#   'chorus',
#   'used',
#   'let',
#   'get',
#   'prove',
#   'love',
#   'id',
#   'crawl',
#   'knees',
#   'whole',
#   'world',
#   'see',
#   'shes',
#   'sky',
#   'blue',
#   'stand',
#   'middle',
#   'heartache',
#   'sure',
#   'looks',
#   'gray',
#   'alone',
#   'wouldnt',
#   'give',
#   'could',
#   'feel',
#   'familiar',
#   'touch',
#   'love',
#   'holding',
#   'repeat',
#   'chorus',
#   'two',
#   'times',
#   ''],
#  ('blakeshelton', 'asphaltcowboy'): ['asphalt',
#   'cowboy',
#   'sun',
#   'opened',
#   'eyes',
#   'dont',
#   'wanna',
#   'leave',
#   'side',
#   'lonesome',
#   'road',
#   'go',
#   'climbing',
#   'back',
#   'behind',
#   'wheel',
#   'fifty',
#   'feet',
#   'chrome',
#   'steel',
#   'load',
#   'need',
#   'chicago',
#   'middle',
#   'night',
#   'unknown',
#   'im',
#   'ride',
#   'wont',
#   'let',
#   'go',
#   'im',
#   'asphalt',
#   'cowboy',
#   'born',
#   'run',
#   'underneath',
#   'stars',
#   'pay',
#   'mind',
#   'lonely',
#   'heart',
#   'ride',
#   'ride',
#   'til',
#   'im',
#   'back',
#   'arms',
#   'ill',
#   'wind',
#   'sometimes',
#   'late',
#   'night',
#   'see',
#   'picture',
#   'dashboard',
#   'light',
#   'takes',
#   'id',
#   'like',
#   'wrapped',
#   'blanket',
#   'pulling',
#   'ribbons',
#   'hair',
#   'kiss',
#   'girl',
#   'thats',
#   'miss',
#   'still',
#   'drive',
#   'horses',
#   'rain',
#   'snow',
#   'highspeed',
#   'rodeo',
#   'know',
#   'im',
#   'asphalt',
#   'cowboy',
#   'born',
#   'run',
#   'underneath',
#   'stars',
#   'pay',
#   'mind',
#   'lonely',
#   'heart',
#   'ride',
#   'ride',
#   'til',
#   'im',
#   'back',
#   'arms',
#   'ill',
#   'wind',
#   'ill',
#   'ride',
#   'im',
#   'back',
#   'arms',
#   'ill',
#   'wind',
#   'ill',
#   'ride',
#   'middle',
#   'night',
#   'unknown',
#   'ride',
#   'wont',
#   'let',
#   'go',
#   ''],
#  ('blakeshelton', 'austin'): ['austin',
#   'left',
#   'without',
#   'leavin',
#   'number',
#   'said',
#   'needed',
#   'clear',
#   'mind',
#   'figured',
#   'shed',
#   'gone',
#   'back',
#   'austin',
#   'cause',
#   'talked',
#   'time',
#   'almost',
#   'year',
#   'called',
#   'three',
#   'rings',
#   'answering',
#   'machine',
#   'got',
#   'youre',
#   'callin',
#   'bout',
#   'car',
#   'sold',
#   'tuesday',
#   'night',
#   'im',
#   'bowling',
#   'youve',
#   'got',
#   'somethin',
#   'sell',
#   'youre',
#   'wastin',
#   'time',
#   'im',
#   'buyin',
#   'anybody',
#   'else',
#   'wait',
#   'tone',
#   'know',
#   'ps',
#   'austin',
#   'still',
#   'love',
#   'telephone',
#   'fell',
#   'counter',
#   'heard',
#   'couldnt',
#   'believe',
#   'kind',
#   'man',
#   'would',
#   'hang',
#   'long',
#   'kind',
#   'love',
#   'must',
#   'waited',
#   'three',
#   'days',
#   'tried',
#   'didnt',
#   'know',
#   'shed',
#   'say',
#   'heard',
#   'three',
#   'rings',
#   'friday',
#   'night',
#   'im',
#   'ballgame',
#   'first',
#   'thing',
#   'saturday',
#   'dont',
#   'rain',
#   'im',
#   'headed',
#   'lake',
#   'ill',
#   'gone',
#   'weekend',
#   'long',
#   'ill',
#   'call',
#   'back',
#   'get',
#   'home',
#   'sunday',
#   'afternoon',
#   'ps',
#   'austin',
#   'still',
#   'love',
#   'well',
#   'time',
#   'left',
#   'number',
#   'another',
#   'word',
#   'waited',
#   'phone',
#   'sunday',
#   'evenin',
#   'heard',
#   'youre',
#   'callin',
#   'bout',
#   'heart',
#   'still',
#   'shouldve',
#   'listened',
#   'little',
#   'wouldnt',
#   'taken',
#   'long',
#   'know',
#   'belong',
#   'way',
#   'boy',
#   'machine',
#   'youre',
#   'talkin',
#   'cant',
#   'tell',
#   'austin',
#   'still',
#   'love',
#   'still',
#   'love',
#   ''],
#  ('blakeshelton', 'everytimeilookatyou'): ['every',
#   'time',
#   'look',
#   'brings',
#   'back',
#   'old',
#   'feeling',
#   'running',
#   'like',
#   'im',
#   'really',
#   'afraid',
#   'hurting',
#   'cant',
#   'stand',
#   'awkwardness',
#   'laugh',
#   'cry',
#   'dare',
#   'look',
#   'eyes',
#   'oh',
#   'goes',
#   'hands',
#   'start',
#   'shake',
#   'hearts',
#   'gonna',
#   'show',
#   'like',
#   'day',
#   'met',
#   'night',
#   'said',
#   'everytime',
#   'look',
#   'seem',
#   'bit',
#   'distracted',
#   'wish',
#   'could',
#   'feel',
#   'never',
#   'good',
#   'acting',
#   'baby',
#   'things',
#   'never',
#   'change',
#   'cant',
#   'keep',
#   'letting',
#   'go',
#   'something',
#   'cant',
#   'control',
#   'oh',
#   'goes',
#   'hands',
#   'start',
#   'shake',
#   'hearts',
#   'gonna',
#   'show',
#   'like',
#   'day',
#   'met',
#   'night',
#   'said',
#   'everytime',
#   'look',
#   'stand',
#   'looking',
#   'sweet',
#   'innocent',
#   'cruel',
#   'confident',
#   'expense',
#   'oh',
#   'goes',
#   'hands',
#   'start',
#   'shake',
#   'hearts',
#   'gonna',
#   'show',
#   'like',
#   'day',
#   'met',
#   'night',
#   'said',
#   'everytime',
#   'look',
#   'oh',
#   'goes',
#   'hands',
#   'start',
#   'shake',
#   'hearts',
#   'gonna',
#   'blow',
#   'like',
#   'day',
#   'met',
#   'night',
#   'said',
#   'everytime',
#   'look',
#   'oh',
#   'yeah',
#   'everytime',
#   'look',
#   ''],
#  ('blakeshelton', 'georgiainajug'): ['georgia',
#   'jug',
#   'mason',
#   'jars',
#   'dresser',
#   'filled',
#   'quarters',
#   'dollars',
#   'savin',
#   'em',
#   'trip',
#   'around',
#   'world',
#   'youve',
#   'changed',
#   'tune',
#   'therell',
#   'honeymoon',
#   'im',
#   'going',
#   'without',
#   'girl',
#   'im',
#   'going',
#   'mexico',
#   'glass',
#   'tequila',
#   'going',
#   'purto',
#   'rico',
#   'bottle',
#   'rum',
#   'going',
#   'honolulu',
#   'mai',
#   'tai',
#   'mug',
#   'im',
#   'coming',
#   'back',
#   'home',
#   'georgia',
#   'jug',
#   'well',
#   'never',
#   'ride',
#   'bus',
#   'mexico',
#   'city',
#   'pity',
#   'well',
#   'never',
#   'sail',
#   'ship',
#   'waikiki',
#   'well',
#   'never',
#   'share',
#   'brick',
#   'suburban',
#   'home',
#   'today',
#   'im',
#   'taking',
#   'money',
#   'jar',
#   'tonight',
#   'ill',
#   'buy',
#   'ticket',
#   'corner',
#   'bar',
#   'im',
#   'going',
#   'mexico',
#   'glass',
#   'tequila',
#   'going',
#   'purto',
#   'rico',
#   'bottle',
#   'rum',
#   'going',
#   'honolulu',
#   'mai',
#   'tai',
#   'mug',
#   'im',
#   'coming',
#   'back',
#   'home',
#   'georgia',
#   'jug',
#   ''],
#  ('blakeshelton', 'heavyliftin'): ['heavy',
#   'liftin',
#   'yeah',
#   'hit',
#   'ground',
#   'runnin',
#   'mornin',
#   'sun',
#   'job',
#   'needs',
#   'doin',
#   'get',
#   'done',
#   'show',
#   'early',
#   'go',
#   'home',
#   'late',
#   'everybody',
#   'knows',
#   'pull',
#   'weight',
#   'cause',
#   'dont',
#   'mind',
#   'doin',
#   'little',
#   'heavy',
#   'liftin',
#   'im',
#   'always',
#   'givin',
#   'everything',
#   'even',
#   'im',
#   'hurtin',
#   'keep',
#   'workin',
#   'long',
#   'im',
#   'still',
#   'alive',
#   'kickin',
#   'ill',
#   'stickin',
#   'heavy',
#   'liftin',
#   'well',
#   'baby',
#   'hurt',
#   'done',
#   'wrong',
#   'goin',
#   'got',
#   'tough',
#   'got',
#   'gone',
#   'well',
#   'aint',
#   'aint',
#   'even',
#   'walls',
#   'come',
#   'fallin',
#   'know',
#   'dont',
#   'mind',
#   'doin',
#   'little',
#   'heavy',
#   'liftin',
#   'im',
#   'always',
#   'givin',
#   'everything',
#   'even',
#   'im',
#   'hurtin',
#   'keep',
#   'workin',
#   'long',
#   'im',
#   'still',
#   'alive',
#   'kickin',
#   'ill',
#   'stickin',
#   'heavy',
#   'liftin',
#   'yeah',
#   'baby',
#   'heart',
#   'achin',
#   'lean',
#   'back',
#   'aint',
#   'breakin',
#   'im',
#   'sayin',
#   'dont',
#   'mind',
#   'doin',
#   'little',
#   'heavy',
#   'liftin',
#   'im',
#   'always',
#   'givin',
#   'everything',
#   'even',
#   'im',
#   'hurtin',
#   'keep',
#   'workin',
#   'long',
#   'im',
#   'still',
#   'alive',
#   'kickin',
#   'ill',
#   'stickin',
#   'heavy',
#   'liftin',
#   'honey',
#   'aint',
#   'quittin',
#   'im',
#   'always',
#   'givin',
#   'everything',
#   'yeah',
#   'long',
#   'im',
#   'still',
#   'alive',
#   'kickin',
#   'ill',
#   'stickin',
#   'heavy',
#   'liftin',
#   'yeah',
#   ''],
#  ('blakeshelton', 'ifiwasyourman'): ['man',
#   'cloud',
#   'id',
#   'make',
#   'baby',
#   'raindrops',
#   'theyd',
#   'feed',
#   'treetops',
#   'cloud',
#   'sun',
#   'id',
#   'shine',
#   'flowers',
#   'pass',
#   'power',
#   'sun',
#   'moon',
#   'id',
#   'caress',
#   'every',
#   'ocean',
#   'celestial',
#   'motion',
#   'moon',
#   'star',
#   'charmed',
#   'enchanted',
#   'wishes',
#   'would',
#   'granted',
#   'star',
#   'man',
#   'kisses',
#   'would',
#   'linger',
#   'id',
#   'melt',
#   'fingers',
#   'man',
#   'man',
#   'wed',
#   'share',
#   'every',
#   'shower',
#   'wash',
#   'away',
#   'hours',
#   'baby',
#   'man',
#   'song',
#   'id',
#   'reach',
#   'people',
#   'barrooms',
#   'steeples',
#   'song',
#   'dream',
#   'id',
#   'sweeter',
#   'honey',
#   'id',
#   'bigger',
#   'money',
#   'dream',
#   'man',
#   'wed',
#   'dance',
#   'daisies',
#   'theyd',
#   'say',
#   'crazy',
#   'girl',
#   'man',
#   'man',
#   'id',
#   'pump',
#   'passion',
#   'youd',
#   'get',
#   'fashion',
#   'baby',
#   'iiiii',
#   'man',
#   'would',
#   'hurry',
#   'id',
#   'rub',
#   'away',
#   'worries',
#   'girl',
#   'man',
#   'man',
#   'wed',
#   'together',
#   'forever',
#   'baby',
#   'man',
#   'love',
#   'wed',
#   'heal',
#   'every',
#   'nation',
#   'wed',
#   'everybodys',
#   'station',
#   'love',
#   'man',
#   'sweet',
#   'lovin',
#   'man',
#   'man',
#   'man',
#   ''],
#  ('blakeshelton', 'inmyheaven'): ['heaven',
#   'heaven',
#   'aint',
#   'lawyers',
#   'dont',
#   'need',
#   'names',
#   'dotted',
#   'lines',
#   'folks',
#   'business',
#   'like',
#   'oughtta',
#   'good',
#   'firm',
#   'handshake',
#   'works',
#   'fine',
#   'feed',
#   'lawyers',
#   'lions',
#   'heaven',
#   'aint',
#   'children',
#   'totin',
#   'loaded',
#   'guns',
#   'school',
#   'aint',
#   'thing',
#   'peer',
#   'pressure',
#   'cool',
#   'still',
#   'teach',
#   'golden',
#   'rule',
#   'heaven',
#   'hurt',
#   'one',
#   'lying',
#   'crying',
#   'dying',
#   'young',
#   'ones',
#   'lonely',
#   'ones',
#   'scared',
#   'anyone',
#   'welcome',
#   'heaven',
#   'heaven',
#   'sing',
#   'like',
#   'elvis',
#   'play',
#   'guitar',
#   'like',
#   'b',
#   'b',
#   'king',
#   'slide',
#   'fastball',
#   'past',
#   'hank',
#   'aaron',
#   'batter',
#   'batter',
#   'batter',
#   'swing',
#   'anything',
#   'heaven',
#   'hurt',
#   'one',
#   'lying',
#   'crying',
#   'dying',
#   'young',
#   'ones',
#   'lonely',
#   'ones',
#   'scared',
#   'anyone',
#   'welcome',
#   'heaven',
#   'know',
#   'gods',
#   'decision',
#   'heavens',
#   'gonna',
#   'aint',
#   'telling',
#   'business',
#   'left',
#   'heaven',
#   'theres',
#   'football',
#   'referees',
#   'heaven',
#   'theres',
#   'never',
#   'injury',
#   'heaven',
#   'angels',
#   'yodel',
#   'sing',
#   'heaven',
#   'fishll',
#   'bite',
#   'anything',
#   'heaven',
#   'heaven',
#   'heaven',
#   ''],
#  ('blakeshelton', 'ithoughttherewastime'): ['thought',
#   'time',
#   'knew',
#   'something',
#   'matter',
#   'really',
#   'needed',
#   'attention',
#   'planned',
#   'look',
#   'someday',
#   'busy',
#   'making',
#   'money',
#   'wanted',
#   'proud',
#   'wish',
#   'could',
#   'turn',
#   'clock',
#   'back',
#   'someway',
#   'thought',
#   'time',
#   'never',
#   'thought',
#   'would',
#   'leave',
#   'always',
#   'thought',
#   'could',
#   'find',
#   'somewhere',
#   'near',
#   'phone',
#   'answer',
#   'call',
#   'full',
#   'attention',
#   'youre',
#   'think',
#   'expected',
#   'thought',
#   'time',
#   'thought',
#   'time',
#   'even',
#   'planet',
#   'see',
#   'pretty',
#   'flowers',
#   'standing',
#   'talking',
#   'wind',
#   'wish',
#   'told',
#   'wish',
#   'shouted',
#   'love',
#   'love',
#   'love',
#   'love',
#   'back',
#   'thought',
#   'time',
#   'thought',
#   'time',
#   'thought',
#   'time',
#   'thought',
#   'time',
#   ''],
#  ('blakeshelton', 'myneckofthewoods'): ['neck',
#   'woods',
#   'grandpas',
#   'two',
#   'lane',
#   'blazing',
#   'sun',
#   'pouring',
#   'rain',
#   'sells',
#   'tomatoes',
#   'back',
#   'pickup',
#   'truck',
#   'reads',
#   'bible',
#   'line',
#   'line',
#   'sipping',
#   'homeade',
#   'wine',
#   'thats',
#   'hes',
#   'like',
#   'us',
#   'dads',
#   'got',
#   'crippled',
#   'hand',
#   'casualty',
#   'vietnam',
#   'hes',
#   'still',
#   'sawmill',
#   'every',
#   'day',
#   'oh',
#   'first',
#   'thing',
#   'fore',
#   'break',
#   'dawn',
#   'mamas',
#   'got',
#   'eggs',
#   'coffee',
#   'whole',
#   'life',
#   'way',
#   'come',
#   'back',
#   'hollers',
#   'got',
#   'sweat',
#   'blue',
#   'collars',
#   'livings',
#   'hard',
#   'livings',
#   'good',
#   'see',
#   'god',
#   'sent',
#   'heavens',
#   'hung',
#   'em',
#   'round',
#   'neck',
#   'woods',
#   'sure',
#   'river',
#   'flows',
#   'take',
#   'care',
#   'step',
#   'right',
#   'someone',
#   'needs',
#   'friend',
#   'last',
#   'year',
#   'johnson',
#   'farm',
#   'fire',
#   'wiped',
#   'house',
#   'barn',
#   'whole',
#   'town',
#   'showed',
#   'build',
#   'em',
#   'back',
#   'right',
#   'come',
#   'back',
#   'hollers',
#   'got',
#   'sweat',
#   'blue',
#   'collars',
#   'livings',
#   'hard',
#   'livings',
#   'good',
#   'see',
#   'god',
#   'sent',
#   'heavens',
#   'hung',
#   'em',
#   'round',
#   'neck',
#   'woods',
#   'come',
#   'back',
#   'hollers',
#   'got',
#   'sweat',
#   'blue',
#   'collars',
#   'livings',
#   'hard',
#   'livings',
#   'good',
#   'see',
#   'god',
#   'sent',
#   'heavens',
#   'hung',
#   'em',
#   'round',
#   'neck',
#   'woods',
#   ''],
#  ('blakeshelton', 'nobodybutme'): ['nobody',
#   'dont',
#   'waste',
#   'time',
#   'looking',
#   'shoulder',
#   'loves',
#   'past',
#   'aint',
#   'getting',
#   'closer',
#   'look',
#   'future',
#   'youre',
#   'see',
#   'dont',
#   'go',
#   'loving',
#   'nobody',
#   'chorus',
#   'nobody',
#   'gonna',
#   'love',
#   'like',
#   'ought',
#   'loved',
#   'nobody',
#   'gonna',
#   'cry',
#   'leave',
#   'want',
#   'im',
#   'asking',
#   'pretty',
#   'please',
#   'honey',
#   'dont',
#   'go',
#   'loving',
#   'nobody',
#   'took',
#   'time',
#   'tell',
#   'feel',
#   'took',
#   'long',
#   'dont',
#   'mean',
#   'isnt',
#   'real',
#   'aint',
#   'got',
#   'diamond',
#   'im',
#   'knees',
#   'dont',
#   'go',
#   'loving',
#   'nobody',
#   'chorus',
#   'nobody',
#   'gonna',
#   'love',
#   'like',
#   'ought',
#   'loved',
#   'nobody',
#   'gonna',
#   'cry',
#   'leave',
#   'want',
#   'im',
#   'asking',
#   'pretty',
#   'please',
#   'honey',
#   'dont',
#   'go',
#   'loving',
#   'nobody',
#   'chorus',
#   'nobody',
#   'gonna',
#   'love',
#   'like',
#   'ought',
#   'loved',
#   'nobody',
#   'gonna',
#   'cry',
#   'leave',
#   'want',
#   'im',
#   'asking',
#   'pretty',
#   'please',
#   'honey',
#   'dont',
#   'go',
#   'loving',
#   'nobody',
#   'dont',
#   'go',
#   'loving',
#   'nobody',
#   ''],
#  ('blakeshelton', 'olred'): ['ol',
#   'red',
#   'well',
#   'caught',
#   'wife',
#   'another',
#   'man',
#   'cost',
#   'ninety',
#   'nine',
#   'prison',
#   'farm',
#   'georgia',
#   'close',
#   'florida',
#   'line',
#   'well',
#   'id',
#   'two',
#   'long',
#   'years',
#   'finally',
#   'made',
#   'warden',
#   'friend',
#   'sentenced',
#   'life',
#   'ease',
#   'taking',
#   'care',
#   'ol',
#   'red',
#   'ol',
#   'red',
#   'hes',
#   'damnedest',
#   'dog',
#   'ive',
#   'ever',
#   'seen',
#   'got',
#   'nose',
#   'smell',
#   'two',
#   'day',
#   'trail',
#   'hes',
#   'four',
#   'legged',
#   'tracking',
#   'machine',
#   'consider',
#   'mighty',
#   'lucky',
#   'get',
#   'past',
#   'gators',
#   'quicksand',
#   'beds',
#   'years',
#   'ive',
#   'aint',
#   'nobody',
#   'got',
#   'past',
#   'red',
#   'warden',
#   'sang',
#   'come',
#   'somebody',
#   'dont',
#   'run',
#   'ol',
#   'reds',
#   'itchin',
#   'little',
#   'fun',
#   'get',
#   'lantern',
#   'get',
#   'gun',
#   'redll',
#   'treed',
#   'mornin',
#   'comes',
#   'well',
#   'paid',
#   'guard',
#   'slipped',
#   'letter',
#   'cousin',
#   'tennessee',
#   'oh',
#   'brought',
#   'blue',
#   'tick',
#   'hound',
#   'pretty',
#   'could',
#   'well',
#   'penned',
#   'swampland',
#   'bout',
#   'mile',
#   'south',
#   'gate',
#   'id',
#   'take',
#   'ol',
#   'red',
#   'evening',
#   'run',
#   'id',
#   'drop',
#   'wait',
#   'warden',
#   'sang',
#   'come',
#   'somebody',
#   'dont',
#   'run',
#   'ol',
#   'reds',
#   'itchin',
#   'little',
#   'fun',
#   'get',
#   'lantern',
#   'get',
#   'gun',
#   'redll',
#   'treed',
#   'mornin',
#   'comes',
#   'ol',
#   'red',
#   'got',
#   'real',
#   'used',
#   'seeing',
#   'lady',
#   'every',
#   'night',
#   'kept',
#   'away',
#   'three',
#   'four',
#   'days',
#   'waited',
#   'till',
#   'time',
#   'got',
#   'right',
#   'well',
#   'made',
#   'run',
#   'evenin',
#   'sun',
#   'smiled',
#   'heard',
#   'em',
#   'turn',
#   'red',
#   'cause',
#   'headed',
#   'north',
#   'tennessee',
#   'ol',
#   'red',
#   'headed',
#   'south',
#   'warden',
#   'sang',
#   'come',
#   'somebody',
#   'dont',
#   'run',
#   'ol',
#   'reds',
#   'itchin',
#   'little',
#   'fun',
#   'get',
#   'lantern',
#   'get',
#   'gun',
#   'redll',
#   'treed',
#   'mornin',
#   'comes',
#   'theres',
#   'red',
#   'haired',
#   'blue',
#   'ticks',
#   'south',
#   'love',
#   'got',
#   'love',
#   'got',
#   ''],
#  ('blakeshelton', 'playboysofthesouthwesternworld'): ['playboys',
#   'southwestern',
#   'world',
#   'song',
#   'best',
#   'friends',
#   'john',
#   'roy',
#   'boy',
#   'knew',
#   'since',
#   'three',
#   'two',
#   'grew',
#   'two',
#   'little',
#   'houses',
#   'two',
#   'bad',
#   'apples',
#   'family',
#   'tree',
#   'kind',
#   'ripened',
#   'rotted',
#   'puberty',
#   'two',
#   'kindred',
#   'spirits',
#   'bound',
#   'destiny',
#   'well',
#   'smart',
#   'lacked',
#   'ambition',
#   'johnny',
#   'wild',
#   'inhibition',
#   'like',
#   'mixin',
#   'fire',
#   'gasoline',
#   'hed',
#   'say',
#   'hey',
#   'romeo',
#   'lets',
#   'go',
#   'mexico',
#   'chase',
#   'senoritas',
#   'drink',
#   'silly',
#   'show',
#   'mexican',
#   'girls',
#   'couple',
#   'real',
#   'hillbillies',
#   'got',
#   'pocket',
#   'full',
#   'cash',
#   'old',
#   'ford',
#   'truck',
#   'fuzzy',
#   'cat',
#   'hangin',
#   'mirror',
#   'luck',
#   'said',
#   'dont',
#   'know',
#   'little',
#   'browneyed',
#   'girls',
#   'want',
#   'playboys',
#   'southwestern',
#   'world',
#   'long',
#   'around',
#   'eighteenth',
#   'year',
#   'found',
#   'two',
#   'plane',
#   'tickets',
#   'hell',
#   'got',
#   'scholarships',
#   'small',
#   'town',
#   'school',
#   'texas',
#   'learned',
#   'drink',
#   'sangria',
#   'til',
#   'dawns',
#   'early',
#   'light',
#   'eat',
#   'eggs',
#   'ranchero',
#   'throw',
#   'night',
#   'tell',
#   'daddys',
#   'girls',
#   'majoring',
#   'rodeo',
#   'ah',
#   'favorite',
#   'memory',
#   'school',
#   'fall',
#   'night',
#   'john',
#   'roy',
#   'came',
#   'runnin',
#   'hall',
#   'wearin',
#   'nothin',
#   'cowboy',
#   'boots',
#   'big',
#   'sombrero',
#   'yellin',
#   'hey',
#   'romeo',
#   'lets',
#   'go',
#   'mexico',
#   'chase',
#   'senoritas',
#   'drink',
#   'silly',
#   'show',
#   'mexican',
#   'girls',
#   'couple',
#   'real',
#   'hillbillies',
#   'got',
#   'pocket',
#   'full',
#   'cash',
#   'old',
#   'ford',
#   'truck',
#   'fuzzy',
#   'cat',
#   'hangin',
#   'mirror',
#   'luck',
#   'said',
#   'dont',
#   'know',
#   'little',
#   'browneyed',
#   'girls',
#   'want',
#   'playboys',
#   'southwestern',
#   'world',
#   'said',
#   'little',
#   'change',
#   'plans',
#   'like',
#   'paul',
#   'mccartney',
#   'got',
#   'busted',
#   'japan',
#   'said',
#   'got',
#   'waylaid',
#   'laid',
#   'foot',
#   'mexican',
#   'soil',
#   'see',
#   'boarder',
#   'guard',
#   'fu',
#   'manchu',
#   'mustache',
#   'kind',
#   'stumbled',
#   'johns',
#   'pocket',
#   'full',
#   'american',
#   'cash',
#   'said',
#   'doin',
#   'little',
#   'funny',
#   'business',
#   'mexico',
#   'amigo',
#   'could',
#   'think',
#   'savin',
#   'tail',
#   'mentioned',
#   'ten',
#   'years',
#   'mexican',
#   'jail',
#   'pointed',
#   'john',
#   'roy',
#   'said',
#   'please',
#   'let',
#   'go',
#   'well',
#   'idea',
#   'genius',
#   'layin',
#   'bed',
#   'said',
#   'hey',
#   'romeo',
#   'lets',
#   'go',
#   'mexico',
#   'chase',
#   'senoritas',
#   'drink',
#   'silly',
#   'show',
#   'mexican',
#   'girls',
#   'couple',
#   'real',
#   'hillbillies',
#   'got',
#   'pocket',
#   'full',
#   'cash',
#   'old',
#   'ford',
#   'truck',
#   'fuzzy',
#   'cat',
#   'hangin',
#   'mirror',
#   'luck',
#   'said',
#   'dont',
#   'know',
#   'little',
#   'browneyed',
#   'girls',
#   'want',
#   'playboys',
#   'southwestern',
#   'world',
#   'ah',
#   'still',
#   'best',
#   'friends',
#   'temporary',
#   'cell',
#   'mates',
#   ''],
#  ('blakeshelton', 'problemsathome'): ['problems',
#   'home',
#   'fires',
#   'burning',
#   'forests',
#   'along',
#   'amazon',
#   'theres',
#   'children',
#   'starving',
#   'guatemala',
#   'theyre',
#   'barely',
#   'hanging',
#   'chorus',
#   'pray',
#   'theyll',
#   'find',
#   'answer',
#   'theres',
#   'way',
#   'right',
#   'wrong',
#   'lord',
#   'youre',
#   'listening',
#   'could',
#   'mention',
#   'troubles',
#   'got',
#   'problems',
#   'right',
#   'home',
#   'teenage',
#   'boy',
#   'mississippi',
#   'brings',
#   'daddys',
#   'gun',
#   'school',
#   'little',
#   'girl',
#   'new',
#   'york',
#   'city',
#   'buys',
#   'cocaine',
#   'mama',
#   'use',
#   'chorus',
#   'wife',
#   'crying',
#   'babys',
#   'fighting',
#   'battle',
#   'may',
#   'win',
#   'doctors',
#   'god',
#   'hands',
#   'pray',
#   'theyll',
#   'find',
#   'answer',
#   'theres',
#   'way',
#   'right',
#   'wrong',
#   'im',
#   'one',
#   'man',
#   'grain',
#   'sand',
#   'troubled',
#   'world',
#   'know',
#   'ive',
#   'got',
#   'problem',
#   'right',
#   'home',
#   'ive',
#   'got',
#   'problem',
#   'right',
#   'home',
#   ''],
#  ('blakeshelton', 'sameoldsong'): ['old',
#   'song',
#   'love',
#   'country',
#   'music',
#   'guess',
#   'always',
#   'days',
#   'turn',
#   'radio',
#   'thrill',
#   'like',
#   'song',
#   'gives',
#   'chillbumps',
#   'theres',
#   'still',
#   'im',
#   'fed',
#   'old',
#   'vanilla',
#   'hey',
#   'im',
#   'tired',
#   'old',
#   'guy',
#   'old',
#   'song',
#   'old',
#   'love',
#   'goes',
#   'old',
#   'guitar',
#   'old',
#   'strum',
#   'may',
#   'country',
#   'im',
#   'dumb',
#   'hey',
#   'mr',
#   'songwriter',
#   'come',
#   'visit',
#   'home',
#   'tell',
#   'life',
#   'perfect',
#   'love',
#   'goes',
#   'ride',
#   'old',
#   'bronco',
#   'factory',
#   'eight',
#   'hours',
#   'let',
#   'introduce',
#   'supervisor',
#   'write',
#   'song',
#   'sunshine',
#   'flowers',
#   'old',
#   'guy',
#   'old',
#   'song',
#   'old',
#   'love',
#   'goes',
#   'old',
#   'guitar',
#   'old',
#   'strum',
#   'may',
#   'country',
#   'im',
#   'dumb',
#   'want',
#   'hear',
#   'song',
#   'passion',
#   'want',
#   'hear',
#   'song',
#   'sin',
#   'want',
#   'hear',
#   'song',
#   'redemption',
#   'yeah',
#   'sing',
#   'one',
#   'tell',
#   'cowboy',
#   'australia',
#   'tell',
#   'prisoner',
#   'china',
#   'tell',
#   'old',
#   'stock',
#   'car',
#   'driver',
#   'orangeburg',
#   'south',
#   'carolina',
#   'instead',
#   'old',
#   'guy',
#   'old',
#   'song',
#   'old',
#   'love',
#   'goes',
#   'old',
#   'guitar',
#   'old',
#   'strum',
#   'may',
#   'country',
#   'im',
#   'dumb',
#   'old',
#   'old',
#   'old',
#   ''],
#  ('blakeshelton', 'shedoesntknowshesgotit'): ['doesnt',
#   'know',
#   'shes',
#   'got',
#   'friday',
#   'night',
#   'see',
#   'even',
#   'crowd',
#   'shes',
#   'hard',
#   'miss',
#   'aint',
#   'man',
#   'breathing',
#   'air',
#   'wouldnt',
#   'stop',
#   'stare',
#   'best',
#   'part',
#   'chorus',
#   'doesnt',
#   'know',
#   'shes',
#   'got',
#   'doesnt',
#   'know',
#   'bad',
#   'want',
#   'doesnt',
#   'know',
#   'shes',
#   'got',
#   'thats',
#   'whats',
#   'gettin',
#   'shell',
#   'close',
#   'eyes',
#   'music',
#   'plays',
#   'way',
#   'sways',
#   'really',
#   'rocks',
#   'room',
#   'doesnt',
#   'mean',
#   'get',
#   'things',
#   'stirred',
#   'thing',
#   'born',
#   'move',
#   'doesnt',
#   'know',
#   'shes',
#   'got',
#   'doesnt',
#   'know',
#   'bad',
#   'want',
#   'doesnt',
#   'know',
#   'shes',
#   'got',
#   'thats',
#   'whats',
#   'gettin',
#   'im',
#   'gonna',
#   'work',
#   'courage',
#   'tell',
#   'im',
#   'love',
#   'im',
#   'love',
#   'lot',
#   'heart',
#   'string',
#   'like',
#   'everything',
#   'girl',
#   'got',
#   'doesnt',
#   'know',
#   'shes',
#   'got',
#   'doesnt',
#   'know',
#   'bad',
#   'want',
#   'doesnt',
#   'know',
#   'shes',
#   'got',
#   'thats',
#   'whats',
#   'gettin',
#   'doesnt',
#   'know',
#   'shes',
#   'got',
#   'doesnt',
#   'know',
#   'bad',
#   'want',
#   'doesnt',
#   'know',
#   'shes',
#   'got',
#   'thats',
#   'whats',
#   'gettin',
#   ''],
#  ('blakeshelton', 'somebeach'): ['beach',
#   'driving',
#   'interstate',
#   'running',
#   'thirty',
#   'minutes',
#   'late',
#   'singing',
#   'margaritaville',
#   'minding',
#   'foreign',
#   'car',
#   'driver',
#   'dude',
#   'road',
#   'rage',
#   'attitude',
#   'pulled',
#   'beside',
#   'talking',
#   'cell',
#   'phone',
#   'started',
#   'yelling',
#   'like',
#   'something',
#   'wrong',
#   'flipped',
#   'bird',
#   'gone',
#   'beach',
#   'somewhere',
#   'theres',
#   'big',
#   'umbrella',
#   'casting',
#   'shade',
#   'empty',
#   'chair',
#   'palm',
#   'trees',
#   'growing',
#   'warm',
#   'breezes',
#   'blowing',
#   'picture',
#   'right',
#   'beach',
#   'somewhere',
#   'circled',
#   'parking',
#   'lot',
#   'trying',
#   'find',
#   'spot',
#   'big',
#   'enough',
#   'could',
#   'park',
#   'old',
#   'truck',
#   'man',
#   'big',
#   'cigar',
#   'getting',
#   'car',
#   'stopped',
#   'waited',
#   'back',
#   'mercedes',
#   'benz',
#   'came',
#   'cruising',
#   'whipped',
#   'right',
#   'beach',
#   'somewhere',
#   'theres',
#   'go',
#   'got',
#   'day',
#   'get',
#   'theres',
#   'cold',
#   'margaritas',
#   'hot',
#   'senioritas',
#   'smiling',
#   'long',
#   'dark',
#   'hair',
#   'beach',
#   'somewhere',
#   'sat',
#   'waiting',
#   'room',
#   'seemed',
#   'like',
#   'afternoon',
#   'nurse',
#   'finally',
#   'said',
#   'docs',
#   'ready',
#   'youre',
#   'gonna',
#   'feel',
#   'thing',
#   'well',
#   'give',
#   'novocain',
#   'tooth',
#   'fine',
#   'minute',
#   'two',
#   'stuck',
#   'needle',
#   'deep',
#   'gum',
#   'started',
#   'drilling',
#   'numb',
#   'beach',
#   'somewhere',
#   'theres',
#   'beautiful',
#   'sunset',
#   'burning',
#   'atmosphere',
#   'theres',
#   'music',
#   'dancing',
#   'lovers',
#   'romancing',
#   'salty',
#   'evening',
#   'air',
#   'beach',
#   'somewhere',
#   'beach',
#   'somewhere',
#   ''],
#  ('blakeshelton', 'someday'): ['someday',
#   'time',
#   'end',
#   'time',
#   'end',
#   'billion',
#   'years',
#   'trillion',
#   'years',
#   'infinity',
#   'cirlce',
#   'enternal',
#   'loop',
#   'drive',
#   'crazy',
#   'searching',
#   'truth',
#   'someday',
#   'know',
#   'reason',
#   'doubt',
#   'someday',
#   'babies',
#   'theres',
#   'nothing',
#   'recall',
#   'go',
#   'back',
#   'fade',
#   'black',
#   'thats',
#   'could',
#   'destined',
#   'time',
#   'place',
#   'lived',
#   'lives',
#   'memories',
#   'erased',
#   'someday',
#   'know',
#   'reason',
#   'doubt',
#   'someday',
#   'see',
#   'jesus',
#   'comin',
#   'sunshine',
#   'fills',
#   'night',
#   'die',
#   'fly',
#   'light',
#   'reunited',
#   'ones',
#   'whove',
#   'gone',
#   'away',
#   'love',
#   'way',
#   'today',
#   'believe',
#   'someday',
#   'well',
#   'know',
#   'reason',
#   'doubt',
#   'someday',
#   ''],
#  ('blakeshelton', 'thatswhaticallhome'): ['thats',
#   'call',
#   'home',
#   'theres',
#   'house',
#   'thats',
#   'little',
#   'run',
#   'city',
#   'aint',
#   'never',
#   'found',
#   'miles',
#   'miles',
#   'paved',
#   'road',
#   'thats',
#   'grew',
#   'seven',
#   'children',
#   'raised',
#   'love',
#   'life',
#   'gets',
#   'hard',
#   'thats',
#   'go',
#   'chorus',
#   'daddy',
#   'dont',
#   'know',
#   'stranger',
#   'handshake',
#   'hes',
#   'friend',
#   'oh',
#   'mama',
#   'shes',
#   'angel',
#   'shell',
#   'hold',
#   'tight',
#   'till',
#   'heartache',
#   'ends',
#   'place',
#   'made',
#   'nails',
#   'wood',
#   'love',
#   'makes',
#   'feel',
#   'good',
#   'thats',
#   'call',
#   'thats',
#   'call',
#   'home',
#   'daddy',
#   'built',
#   'two',
#   'hands',
#   'overlooking',
#   'grandpas',
#   'land',
#   'years',
#   'lot',
#   'changed',
#   'driving',
#   'gravel',
#   'road',
#   'get',
#   'feeling',
#   'soul',
#   'thank',
#   'god',
#   'things',
#   'still',
#   'remain',
#   'repeat',
#   'chorus',
#   'get',
#   'old',
#   'screen',
#   'door',
#   'world',
#   'cant',
#   'touch',
#   'anymore',
#   'repeat',
#   'chorus',
#   'thats',
#   'call',
#   'home',
#   'thats',
#   'call',
#   'home',
#   ''],
#  ('blakeshelton', 'thebaby'): ['baby',
#   'brother',
#   'said',
#   'rotten',
#   'core',
#   'youngest',
#   'child',
#   'got',
#   'guess',
#   'tired',
#   'time',
#   'came',
#   'along',
#   'shed',
#   'laugh',
#   'cried',
#   'could',
#   'wrong',
#   'would',
#   'always',
#   'save',
#   'baby',
#   'worked',
#   'factory',
#   'ohio',
#   'shrimp',
#   'boat',
#   'bayou',
#   'drove',
#   'truck',
#   'birmingham',
#   'turned',
#   '21',
#   'cincinnati',
#   'called',
#   'home',
#   'mom',
#   'daddy',
#   'said',
#   'boy',
#   'man',
#   'said',
#   'dont',
#   'care',
#   'youre',
#   '80',
#   'youll',
#   'always',
#   'baby',
#   'loved',
#   'photograph',
#   'whole',
#   'family',
#   'shed',
#   'always',
#   'point',
#   'us',
#   'friends',
#   'see',
#   'thats',
#   'greg',
#   'hes',
#   'great',
#   'really',
#   'loves',
#   'job',
#   'ronnie',
#   '2',
#   'kids',
#   'bout',
#   'wife',
#   'hes',
#   'got',
#   'ones',
#   'kinda',
#   'crazy',
#   'one',
#   'baby',
#   'got',
#   'call',
#   'alabama',
#   'said',
#   'come',
#   'home',
#   'louisianna',
#   'come',
#   'fast',
#   'fly',
#   'cause',
#   'momma',
#   'really',
#   'needs',
#   'says',
#   'shes',
#   'got',
#   'see',
#   'might',
#   'make',
#   'night',
#   'whole',
#   'way',
#   'drove',
#   '80',
#   'could',
#   'see',
#   'baby',
#   'looked',
#   'like',
#   'sleepin',
#   'family',
#   'weepin',
#   'time',
#   'got',
#   'side',
#   'knew',
#   'shed',
#   'taken',
#   'heart',
#   'breakin',
#   'never',
#   'got',
#   'say',
#   'goodbye',
#   'softly',
#   'kissed',
#   'lady',
#   'cried',
#   'like',
#   'baby',
#   ''],
#  ('blakeshelton', 'thedreamer'): ['dreamer',
#   'funny',
#   'thing',
#   'dreamers',
#   'dream',
#   'sights',
#   'get',
#   'theyre',
#   'goin',
#   'leave',
#   'lot',
#   'good',
#   'things',
#   'behind',
#   'guess',
#   'could',
#   'call',
#   'dreamer',
#   'ive',
#   'seen',
#   'come',
#   'true',
#   'smile',
#   'need',
#   'look',
#   'happy',
#   'things',
#   'tell',
#   'yeah',
#   'im',
#   'big',
#   'selfmade',
#   'man',
#   'fool',
#   'cant',
#   'understand',
#   'thought',
#   'needed',
#   'fortune',
#   'thought',
#   'needed',
#   'fame',
#   'need',
#   'hear',
#   'whisper',
#   'name',
#   'could',
#   'make',
#   'future',
#   'extension',
#   'past',
#   'id',
#   'take',
#   'broken',
#   'memories',
#   'make',
#   'moments',
#   'last',
#   'ship',
#   'come',
#   'wonder',
#   'done',
#   'thought',
#   'needed',
#   'fortune',
#   'thought',
#   'needed',
#   'fame',
#   'need',
#   'hear',
#   'whisper',
#   'name',
#   'thought',
#   'needed',
#   'fortune',
#   'thought',
#   'needed',
#   'fame',
#   'need',
#   'hear',
#   'whisper',
#   'name',
#   'oh',
#   'yeah',
#   'whisper',
#   'baby',
#   ''],
#  ('blakeshelton', 'underneaththesamemoon'): ['underneath',
#   'moon',
#   'shadows',
#   'night',
#   'moving',
#   'ground',
#   'like',
#   'silent',
#   'clouds',
#   'follow',
#   'around',
#   'wander',
#   'dark',
#   'midnight',
#   'mist',
#   'remembering',
#   'last',
#   'kiss',
#   'know',
#   'much',
#   'youre',
#   'missed',
#   'chorus',
#   'tonight',
#   'stand',
#   'lonely',
#   'place',
#   'search',
#   'heavens',
#   'saving',
#   'grace',
#   'cry',
#   'dying',
#   'without',
#   'know',
#   'youre',
#   'somewhere',
#   'looking',
#   'right',
#   'thats',
#   'two',
#   'distant',
#   'hearts',
#   'ohooh',
#   'least',
#   'underneath',
#   'underneath',
#   'moon',
#   'picturing',
#   'face',
#   'flowers',
#   'hair',
#   'like',
#   'always',
#   'wear',
#   'oh',
#   'see',
#   'longing',
#   'touched',
#   'youre',
#   'reach',
#   'oh',
#   'hold',
#   'please',
#   'wont',
#   'wait',
#   'repeat',
#   'chorus',
#   'la',
#   'la',
#   'la',
#   'la',
#   'la',
#   'la',
#   'la',
#   'la',
#   'la',
#   'ohooh',
#   'least',
#   'underneath',
#   'underneath',
#   'moon',
#   'shadows',
#   'night',
#   'moving',
#   'around',
#   'moving',
#   'ground',
#   'follow',
#   'around',
#   ''],
#  ('taylorswift', 'aperfectlygoodheart'): ['perfectly',
#   'good',
#   'heart',
#   'would',
#   'wanna',
#   'break',
#   'perfectly',
#   'good',
#   'heart',
#   'would',
#   'wanna',
#   'take',
#   'love',
#   'tear',
#   'apart',
#   'would',
#   'wanna',
#   'make',
#   'first',
#   'scar',
#   'would',
#   'wanna',
#   'break',
#   'perfectly',
#   'good',
#   'heart',
#   'maybe',
#   'shouldve',
#   'seen',
#   'signs',
#   'shouldve',
#   'read',
#   'writing',
#   'wall',
#   'realized',
#   'distance',
#   'eyes',
#   'would',
#   'one',
#   'fall',
#   'matter',
#   'say',
#   'still',
#   'cant',
#   'believe',
#   'would',
#   'walk',
#   'away',
#   'dont',
#   'make',
#   'sense',
#   'would',
#   'wanna',
#   'break',
#   'perfectly',
#   'good',
#   'heart',
#   'would',
#   'wanna',
#   'take',
#   'love',
#   'tear',
#   'apart',
#   'would',
#   'wanna',
#   'make',
#   'first',
#   'scar',
#   'would',
#   'wanna',
#   'break',
#   'perfectly',
#   'good',
#   'heart',
#   'unbroken',
#   'anymore',
#   'get',
#   'back',
#   'way',
#   'would',
#   'wanna',
#   'break',
#   'perfectly',
#   'good',
#   'heart',
#   'would',
#   'wanna',
#   'take',
#   'love',
#   'tear',
#   'apart',
#   'would',
#   'wanna',
#   'make',
#   'first',
#   'scar',
#   'would',
#   'wanna',
#   'break',
#   'would',
#   'wanna',
#   'break',
#   'would',
#   'wanna',
#   'break',
#   'perfectly',
#   'good',
#   'heart',
#   'would',
#   'wanna',
#   'take',
#   'love',
#   'tear',
#   'apart',
#   'would',
#   'wanna',
#   'make',
#   'first',
#   'scar',
#   'would',
#   'wanna',
#   'break',
#   'perfectly',
#   'good',
#   'heart',
#   ''],
#  ('taylorswift', 'aplaceinthisworld'): ['place',
#   'world',
#   'dont',
#   'know',
#   'want',
#   'dont',
#   'ask',
#   'cause',
#   'im',
#   'still',
#   'trying',
#   'figure',
#   'dont',
#   'know',
#   'whats',
#   'road',
#   'im',
#   'walking',
#   'trying',
#   'see',
#   'rain',
#   'coming',
#   'even',
#   'though',
#   'im',
#   'one',
#   'feels',
#   'way',
#   'im',
#   'alone',
#   'thats',
#   'know',
#   'ill',
#   'strong',
#   'ill',
#   'wrong',
#   'oh',
#   'life',
#   'goes',
#   'oh',
#   'im',
#   'girl',
#   'trying',
#   'find',
#   'place',
#   'world',
#   'got',
#   'radio',
#   'old',
#   'blue',
#   'jeans',
#   'im',
#   'wearing',
#   'heart',
#   'sleeve',
#   'feeling',
#   'lucky',
#   'today',
#   'got',
#   'sunshine',
#   'could',
#   'tell',
#   'need',
#   'tomorrows',
#   'mystery',
#   'oh',
#   'yeah',
#   'thats',
#   'ok',
#   'im',
#   'alone',
#   'thats',
#   'know',
#   'ill',
#   'strong',
#   'ill',
#   'wrong',
#   'oh',
#   'life',
#   'goes',
#   'oh',
#   'im',
#   'girl',
#   'trying',
#   'find',
#   'place',
#   'world',
#   'maybe',
#   'im',
#   'girl',
#   'mission',
#   'im',
#   'ready',
#   'fly',
#   'im',
#   'alone',
#   'thats',
#   'know',
#   'ill',
#   'strong',
#   'ill',
#   'wrong',
#   'oh',
#   'life',
#   'goes',
#   'oh',
#   'im',
#   'alone',
#   'thats',
#   'know',
#   'oh',
#   'im',
#   'girl',
#   'trying',
#   'find',
#   'place',
#   'world',
#   'oh',
#   'im',
#   'girl',
#   'oh',
#   'im',
#   'girl',
#   'oh',
#   'oh',
#   'oh',
#   'im',
#   'girl',
#   ''],
#  ('taylorswift', 'christmaseswhenyouweremine'): ['christmases',
#   'mine',
#   'please',
#   'take',
#   'mistletoe',
#   'cause',
#   'dont',
#   'wanna',
#   'think',
#   'right',
#   'cause',
#   'everything',
#   'want',
#   'miles',
#   'away',
#   'snow',
#   'covered',
#   'little',
#   'town',
#   'mommas',
#   'kitchen',
#   'worrying',
#   'seasons',
#   'greetings',
#   'hope',
#   'youre',
#   'well',
#   'well',
#   'im',
#   'alright',
#   'wondering',
#   'lately',
#   'never',
#   'tell',
#   'know',
#   'shouldnt',
#   'lonely',
#   'time',
#   'christmases',
#   'mine',
#   'ive',
#   'fine',
#   'without',
#   'really',
#   'nights',
#   'got',
#   'cold',
#   'everybodys',
#   'except',
#   'baby',
#   'seems',
#   'like',
#   'everyones',
#   'got',
#   'someone',
#   'hold',
#   'lonely',
#   'time',
#   'cause',
#   'christmases',
#   'mine',
#   'merry',
#   'christmas',
#   'everybody',
#   'thatll',
#   'something',
#   'say',
#   'year',
#   'ill',
#   'bet',
#   'got',
#   'mom',
#   'another',
#   'sweater',
#   'cousins',
#   'late',
#   'putting',
#   'lights',
#   'year',
#   'notice',
#   'one',
#   'less',
#   'pair',
#   'hands',
#   'know',
#   'shouldnt',
#   'lonely',
#   'time',
#   'christmases',
#   'didnt',
#   'wonder',
#   'tonight',
#   'cause',
#   'christmases',
#   'mine',
#   'mine',
#   ''],
#  ('taylorswift', 'christmasmustbesomethingmore'): ['christmas',
#   'must',
#   'something',
#   'ribbons',
#   'bows',
#   'didnt',
#   'mean',
#   'thing',
#   'would',
#   'song',
#   'still',
#   'survive',
#   'without',
#   'five',
#   'golden',
#   'rings',
#   'would',
#   'still',
#   'wanna',
#   'kiss',
#   'without',
#   'mistletoe',
#   'would',
#   'happen',
#   'god',
#   'never',
#   'let',
#   'snow',
#   'would',
#   'happen',
#   'christmas',
#   'carols',
#   'told',
#   'lie',
#   'tell',
#   'would',
#   'find',
#   'youd',
#   'see',
#   'today',
#   'holds',
#   'something',
#   'special',
#   'something',
#   'holy',
#   'superficial',
#   'heres',
#   'birthday',
#   'boy',
#   'saved',
#   'lives',
#   'something',
#   'try',
#   'ignore',
#   'put',
#   'wreath',
#   'door',
#   'heres',
#   'something',
#   'know',
#   'sure',
#   'christmas',
#   'must',
#   'something',
#   'angels',
#   'pay',
#   'attention',
#   'things',
#   'wished',
#   'would',
#   'always',
#   'happiness',
#   'came',
#   'cardboard',
#   'box',
#   'think',
#   'something',
#   'forgot',
#   'would',
#   'happen',
#   'presents',
#   'went',
#   'away',
#   'tell',
#   'would',
#   'find',
#   'youd',
#   'see',
#   'today',
#   'holds',
#   'something',
#   'special',
#   'something',
#   'holy',
#   'superficial',
#   'heres',
#   'birthday',
#   'boy',
#   'saved',
#   'lives',
#   'something',
#   'try',
#   'ignore',
#   'put',
#   'wreath',
#   'door',
#   'heres',
#   'something',
#   'know',
#   'sure',
#   'christmas',
#   'must',
#   'something',
#   'get',
#   'caught',
#   'business',
#   'relationships',
#   'hundredmileanhour',
#   'lives',
#   'time',
#   'year',
#   'everybodys',
#   'seems',
#   'last',
#   'thing',
#   'mind',
#   'day',
#   'holds',
#   'something',
#   'special',
#   'something',
#   'holy',
#   'superficial',
#   'heres',
#   'jesus',
#   'christ',
#   'saved',
#   'lives',
#   'something',
#   'try',
#   'ignore',
#   'put',
#   'wreath',
#   'door',
#   'heres',
#   'something',
#   'know',
#   'sure',
#   'christmas',
#   'must',
#   'something',
#   'christmas',
#   'must',
#   'something',
#   'christmas',
#   'must',
#   'something',
#   'theres',
#   'gotta',
#   'theres',
#   'gotta',
#   ''],
#  ('taylorswift', 'coldasyou'): ['cold',
#   'way',
#   'coming',
#   'easily',
#   'take',
#   'take',
#   'best',
#   'start',
#   'fight',
#   'cause',
#   'need',
#   'feel',
#   'something',
#   'want',
#   'cause',
#   'im',
#   'wanted',
#   'oh',
#   'shame',
#   'rainy',
#   'ending',
#   'given',
#   'perfect',
#   'day',
#   'walk',
#   'away',
#   'aint',
#   'use',
#   'defending',
#   'words',
#   'never',
#   'say',
#   'im',
#   'sitting',
#   'thinking',
#   'ive',
#   'never',
#   'anywhere',
#   'cold',
#   'put',
#   'walls',
#   'paint',
#   'shade',
#   'gray',
#   'stood',
#   'loving',
#   'wished',
#   'away',
#   'come',
#   'away',
#   'great',
#   'little',
#   'story',
#   'mess',
#   'dreamer',
#   'nerve',
#   'adore',
#   'oh',
#   'shame',
#   'rainy',
#   'ending',
#   'given',
#   'perfect',
#   'day',
#   'walk',
#   'away',
#   'aint',
#   'use',
#   'defending',
#   'words',
#   'never',
#   'say',
#   'im',
#   'sitting',
#   'thinking',
#   'ive',
#   'never',
#   'anywhere',
#   'cold',
#   'never',
#   'give',
#   'damn',
#   'thing',
#   'honey',
#   'cried',
#   'cried',
#   'know',
#   'wouldnt',
#   'told',
#   'nobody',
#   'died',
#   'died',
#   'died',
#   'oh',
#   'shame',
#   'rainy',
#   'ending',
#   'given',
#   'perfect',
#   'day',
#   'every',
#   'smile',
#   'fake',
#   'condescending',
#   'counting',
#   'scars',
#   'made',
#   'im',
#   'sitting',
#   'thinking',
#   'ive',
#   'never',
#   'anywhere',
#   'cold',
#   ''],
#  ('taylorswift', 'imonlymewhenimwithyou'): ['im',
#   'im',
#   'friday',
#   'night',
#   'beneath',
#   'stars',
#   'field',
#   'behind',
#   'yard',
#   'paintin',
#   'pictures',
#   'sky',
#   'sometimes',
#   'dont',
#   'say',
#   'thing',
#   'listen',
#   'crickets',
#   'sing',
#   'everything',
#   'need',
#   'right',
#   'side',
#   'know',
#   'everything',
#   'dont',
#   'wanna',
#   'live',
#   'without',
#   'im',
#   'youre',
#   'dont',
#   'wanna',
#   'fly',
#   'youre',
#   'still',
#   'ground',
#   'like',
#   'matter',
#   'well',
#   'drive',
#   'crazy',
#   'half',
#   'time',
#   'half',
#   'im',
#   'tryna',
#   'let',
#   'know',
#   'feel',
#   'true',
#   'im',
#   'im',
#   'small',
#   'town',
#   'boy',
#   'girl',
#   'livin',
#   'crazy',
#   'world',
#   'tryna',
#   'figure',
#   'isnt',
#   'true',
#   'dont',
#   'try',
#   'hide',
#   'tears',
#   'secrets',
#   'deepest',
#   'fears',
#   'nobody',
#   'gets',
#   'like',
#   'know',
#   'everything',
#   'say',
#   'cant',
#   'live',
#   'without',
#   'im',
#   'youre',
#   'dont',
#   'wanna',
#   'fly',
#   'youre',
#   'still',
#   'ground',
#   'like',
#   'matter',
#   'well',
#   'drive',
#   'crazy',
#   'half',
#   'time',
#   'half',
#   'im',
#   'tryna',
#   'let',
#   'know',
#   'feel',
#   'true',
#   'im',
#   'im',
#   'im',
#   'anybody',
#   'else',
#   'hard',
#   'tell',
#   'im',
#   'youre',
#   'dont',
#   'wanna',
#   'fly',
#   'youre',
#   'still',
#   'ground',
#   'like',
#   'matter',
#   'well',
#   'drive',
#   'crazy',
#   'half',
#   'time',
#   'half',
#   'im',
#   'tryna',
#   'let',
#   'know',
#   'feel',
#   'true',
#   'im',
#   'wanna',
#   'well',
#   'im',
#   'im',
#   ''],
#  ('taylorswift', 'invisible'): ['invisible',
#   'cant',
#   'see',
#   'way',
#   'eyes',
#   'light',
#   'smile',
#   'shell',
#   'never',
#   'notice',
#   'stop',
#   'stare',
#   'whenever',
#   'walks',
#   'cant',
#   'see',
#   'wantin',
#   'way',
#   'want',
#   'everything',
#   'wanna',
#   'show',
#   'dont',
#   'even',
#   'know',
#   'shes',
#   'never',
#   'gonna',
#   'love',
#   'like',
#   'want',
#   'see',
#   'right',
#   'knew',
#   'could',
#   'beautiful',
#   'miracle',
#   'unbelievable',
#   'instead',
#   'invisible',
#   'theres',
#   'fire',
#   'inside',
#   'cant',
#   'help',
#   'shine',
#   'shes',
#   'never',
#   'gonna',
#   'see',
#   'light',
#   'matter',
#   'think',
#   'make',
#   'think',
#   'everything',
#   'could',
#   'wanna',
#   'show',
#   'dont',
#   'even',
#   'know',
#   'shes',
#   'never',
#   'gonna',
#   'love',
#   'like',
#   'want',
#   'see',
#   'right',
#   'knew',
#   'could',
#   'beautiful',
#   'miracle',
#   'unbelievable',
#   'instead',
#   'invisible',
#   'like',
#   'shadows',
#   'faded',
#   'light',
#   'oh',
#   'invisible',
#   'wanna',
#   'open',
#   'eyes',
#   'make',
#   'realize',
#   'wanna',
#   'show',
#   'dont',
#   'even',
#   'know',
#   'baby',
#   'let',
#   'love',
#   'let',
#   'want',
#   'see',
#   'right',
#   'knew',
#   'could',
#   'beautiful',
#   'miracle',
#   'unbelievable',
#   'instead',
#   'invisible',
#   'cant',
#   'see',
#   'way',
#   'eyes',
#   'light',
#   'smile',
#   ''],
#  ('taylorswift', 'jumpthenfall'): ['jump',
#   'fall',
#   'like',
#   'way',
#   'sound',
#   'morning',
#   'phone',
#   'without',
#   'warning',
#   'realize',
#   'laugh',
#   'best',
#   'sound',
#   'ever',
#   'heard',
#   'like',
#   'way',
#   'cant',
#   'keep',
#   'focus',
#   'watch',
#   'talk',
#   'didnt',
#   'notice',
#   'hear',
#   'words',
#   'think',
#   'together',
#   'every',
#   'time',
#   'smile',
#   'smile',
#   'every',
#   'time',
#   'shine',
#   'ill',
#   'shine',
#   'whoa',
#   'oh',
#   'im',
#   'feeling',
#   'baby',
#   'dont',
#   'afraid',
#   'jump',
#   'fall',
#   'jump',
#   'fall',
#   'baby',
#   'im',
#   'never',
#   'gonna',
#   'leave',
#   'say',
#   'wanna',
#   'cause',
#   'imma',
#   'stay',
#   'jump',
#   'fall',
#   'well',
#   'like',
#   'way',
#   'hair',
#   'falls',
#   'face',
#   'got',
#   'keys',
#   'love',
#   'freckle',
#   'face',
#   'oh',
#   'ive',
#   'never',
#   'wrapped',
#   'honey',
#   'like',
#   'way',
#   'youre',
#   'everything',
#   'ever',
#   'wanted',
#   'time',
#   'think',
#   'say',
#   'come',
#   'closer',
#   'take',
#   'deep',
#   'breath',
#   'jump',
#   'fall',
#   'cause',
#   'every',
#   'time',
#   'smile',
#   'smile',
#   'every',
#   'time',
#   'shine',
#   'ill',
#   'shine',
#   'whoa',
#   'oh',
#   'im',
#   'feeling',
#   'baby',
#   'dont',
#   'afraid',
#   'jump',
#   'fall',
#   'jump',
#   'fall',
#   'baby',
#   'im',
#   'never',
#   'gonna',
#   'leave',
#   'say',
#   'wanna',
#   'cause',
#   'imma',
#   'stay',
#   'jump',
#   'fall',
#   'bottoms',
#   'gonna',
#   'drop',
#   'feet',
#   'ill',
#   'catch',
#   'ill',
#   'catch',
#   'people',
#   'say',
#   'things',
#   'bring',
#   'knees',
#   'ill',
#   'catch',
#   'time',
#   'gonna',
#   'come',
#   'youre',
#   'mad',
#   'could',
#   'cry',
#   'ill',
#   'hold',
#   'night',
#   'smile',
#   'whoa',
#   'oh',
#   'need',
#   'baby',
#   'dont',
#   'afraid',
#   'please',
#   'jump',
#   'fall',
#   'jump',
#   'fall',
#   'baby',
#   'im',
#   'never',
#   'gonna',
#   'leave',
#   'say',
#   'wanna',
#   'cause',
#   'imma',
#   'stay',
#   'jump',
#   'fall',
#   'jump',
#   'fall',
#   'baby',
#   'jump',
#   'fall',
#   'every',
#   'time',
#   'smile',
#   'smile',
#   'every',
#   'time',
#   'shine',
#   'ill',
#   'shine',
#   'every',
#   'time',
#   'youre',
#   'baby',
#   'ill',
#   'show',
#   'ill',
#   'show',
#   'jump',
#   'fall',
#   'jump',
#   'fall',
#   'jump',
#   'fall',
#   'yeah',
#   ''],
#  ('taylorswift', 'lastchristmas'): ['last',
#   'christmas',
#   'last',
#   'christmas',
#   'gave',
#   'heart',
#   'next',
#   'day',
#   'gave',
#   'away',
#   'year',
#   'save',
#   'tears',
#   'ill',
#   'give',
#   'someone',
#   'special',
#   'bitten',
#   'twice',
#   'shy',
#   'keep',
#   'distance',
#   'still',
#   'catch',
#   'eye',
#   'tell',
#   'baby',
#   'recognize',
#   'well',
#   'year',
#   'doesnt',
#   'surprise',
#   'merry',
#   'christmas',
#   'wrapped',
#   'sent',
#   'note',
#   'saying',
#   'love',
#   'meant',
#   'know',
#   'fool',
#   'ive',
#   'kissed',
#   'know',
#   'youd',
#   'fool',
#   'last',
#   'christmas',
#   'gave',
#   'heart',
#   'next',
#   'day',
#   'gave',
#   'away',
#   'year',
#   'save',
#   'tears',
#   'ill',
#   'give',
#   'someone',
#   'special',
#   'last',
#   'christmas',
#   'gave',
#   'heart',
#   'next',
#   'day',
#   'gave',
#   'away',
#   'year',
#   'save',
#   'tears',
#   'ill',
#   'give',
#   'someone',
#   'special',
#   'crowded',
#   'room',
#   'friends',
#   'tired',
#   'eyes',
#   'im',
#   'hiding',
#   'soul',
#   'ice',
#   'god',
#   'thought',
#   'someone',
#   'rely',
#   'guess',
#   'shoulder',
#   'cry',
#   'face',
#   'lover',
#   'fire',
#   'heart',
#   'girl',
#   'cover',
#   'tore',
#   'apart',
#   'maybe',
#   'year',
#   'maybe',
#   'year',
#   'ill',
#   'give',
#   'someone',
#   'special',
#   'cause',
#   'last',
#   'christmas',
#   'gave',
#   'heart',
#   'next',
#   'day',
#   'gave',
#   'away',
#   'year',
#   'save',
#   'tears',
#   'ill',
#   'give',
#   'someone',
#   'special',
#   'last',
#   'christmas',
#   'gave',
#   'heart',
#   'next',
#   'day',
#   'gave',
#   'away',
#   'year',
#   'save',
#   'tears',
#   'ill',
#   'give',
#   'someone',
#   'special',
#   'last',
#   'christmas',
#   'year',
#   'wont',
#   'anything',
#   'like',
#   'anything',
#   'like',
#   'last',
#   'christmas',
#   'gave',
#   'heart',
#   'next',
#   'day',
#   'gave',
#   'away',
#   'year',
#   'save',
#   'tears',
#   'ill',
#   'give',
#   'someone',
#   'special',
#   ''],
#  ('taylorswift', 'maryssongohmymymy'): ['marys',
#   'song',
#   'oh',
#   'said',
#   'seven',
#   'nine',
#   'looked',
#   'like',
#   'stars',
#   'shined',
#   'sky',
#   'pretty',
#   'lights',
#   'daddies',
#   'used',
#   'joke',
#   'two',
#   'us',
#   'growing',
#   'falling',
#   'love',
#   'mamas',
#   'smiled',
#   'rolled',
#   'eyes',
#   'said',
#   'oh',
#   'take',
#   'back',
#   'house',
#   'backyard',
#   'tree',
#   'said',
#   'youd',
#   'beat',
#   'bigger',
#   'never',
#   'never',
#   'take',
#   'back',
#   'world',
#   'one',
#   'block',
#   'wide',
#   'dared',
#   'kiss',
#   'ran',
#   'tried',
#   'two',
#   'kids',
#   'oh',
#   'well',
#   'sixteen',
#   'suddenly',
#   'wasnt',
#   'little',
#   'girl',
#   'used',
#   'see',
#   'eyes',
#   'still',
#   'shined',
#   'like',
#   'pretty',
#   'lights',
#   'daddies',
#   'used',
#   'joke',
#   'two',
#   'us',
#   'never',
#   'believed',
#   'wed',
#   'really',
#   'fall',
#   'love',
#   'mamas',
#   'smiled',
#   'rolled',
#   'eyes',
#   'said',
#   'oh',
#   'take',
#   'back',
#   'creek',
#   'beds',
#   'turned',
#   'two',
#   'riding',
#   'truck',
#   'need',
#   'next',
#   'take',
#   'back',
#   'time',
#   'first',
#   'fight',
#   'slamming',
#   'doors',
#   'instead',
#   'kissing',
#   'goodnight',
#   'stayed',
#   'outside',
#   'til',
#   'morning',
#   'light',
#   'oh',
#   'years',
#   'gone',
#   'come',
#   'around',
#   'sitting',
#   'favorite',
#   'spot',
#   'town',
#   'looked',
#   'got',
#   'one',
#   'knee',
#   'take',
#   'back',
#   'time',
#   'walked',
#   'aisle',
#   'whole',
#   'town',
#   'came',
#   'mamas',
#   'cried',
#   'said',
#   'take',
#   'home',
#   'met',
#   'many',
#   'years',
#   'well',
#   'rock',
#   'babies',
#   'front',
#   'porch',
#   'time',
#   'ill',
#   'eightyseven',
#   'youll',
#   'eightynine',
#   'ill',
#   'still',
#   'look',
#   'like',
#   'stars',
#   'shine',
#   'sky',
#   'oh',
#   ''],
#  ('taylorswift', 'oursong'): ['song',
#   'riding',
#   'shotgun',
#   'hair',
#   'undone',
#   'front',
#   'seat',
#   'car',
#   'hes',
#   'got',
#   'onehand',
#   'feel',
#   'steering',
#   'wheel',
#   'heart',
#   'look',
#   'around',
#   'turn',
#   'radio',
#   'says',
#   'baby',
#   'something',
#   'wrong',
#   'say',
#   'nothing',
#   'thinking',
#   'dont',
#   'song',
#   'says',
#   'song',
#   'slamming',
#   'screen',
#   'door',
#   'sneakin',
#   'late',
#   'tapping',
#   'window',
#   'phone',
#   'talk',
#   'real',
#   'slow',
#   'cause',
#   'late',
#   'mama',
#   'dont',
#   'know',
#   'song',
#   'way',
#   'laugh',
#   'first',
#   'date',
#   'man',
#   'didnt',
#   'kiss',
#   'got',
#   'home',
#   'fore',
#   'said',
#   'amen',
#   'asking',
#   'god',
#   'could',
#   'play',
#   'walking',
#   'front',
#   'porch',
#   'steps',
#   'everything',
#   'day',
#   'gone',
#   'wrong',
#   'trampled',
#   'lost',
#   'thrown',
#   'away',
#   'got',
#   'hallway',
#   'well',
#   'way',
#   'lovin',
#   'bed',
#   'almost',
#   'didnt',
#   'notice',
#   'roses',
#   'note',
#   'said',
#   'song',
#   'slamming',
#   'screen',
#   'door',
#   'sneakin',
#   'late',
#   'tapping',
#   'window',
#   'phone',
#   'talk',
#   'real',
#   'slow',
#   'cause',
#   'late',
#   'mama',
#   'dont',
#   'know',
#   'song',
#   'way',
#   'laugh',
#   'first',
#   'date',
#   'man',
#   'didnt',
#   'kiss',
#   'got',
#   'home',
#   'fore',
#   'said',
#   'amen',
#   'asking',
#   'god',
#   'could',
#   'play',
#   'ive',
#   'heard',
#   'every',
#   'album',
#   'listened',
#   'radio',
#   'waited',
#   'something',
#   'come',
#   'along',
#   'good',
#   'song',
#   'cause',
#   'song',
#   'slamming',
#   'screen',
#   'door',
#   'sneakin',
#   'late',
#   'tapping',
#   'window',
#   'phone',
#   'talks',
#   'real',
#   'slow',
#   'cause',
#   'late',
#   'mama',
#   'dont',
#   'know',
#   'song',
#   'way',
#   'laughs',
#   'first',
#   'date',
#   'man',
#   'didnt',
#   'kiss',
#   'got',
#   'home',
#   'fore',
#   'said',
#   'amen',
#   'asking',
#   'god',
#   'could',
#   'play',
#   'play',
#   'oh',
#   'yeah',
#   'ohoh',
#   'yeah',
#   'riding',
#   'shotgun',
#   'hair',
#   'undone',
#   'front',
#   'seat',
#   'car',
#   'grabbed',
#   'pen',
#   'old',
#   'napkin',
#   'wrote',
#   'song',
#   ''],
#  ('taylorswift', 'picturetoburn'): ['picture',
#   'burn',
#   'state',
#   'obvious',
#   'didnt',
#   'get',
#   'perfect',
#   'fantasy',
#   'realize',
#   'love',
#   'could',
#   'ever',
#   'love',
#   'go',
#   'tell',
#   'friends',
#   'im',
#   'obsessive',
#   'crazy',
#   'thats',
#   'fine',
#   'ill',
#   'tell',
#   'mine',
#   'youre',
#   'gay',
#   'way',
#   'hate',
#   'stupid',
#   'old',
#   'pickup',
#   'truck',
#   'never',
#   'let',
#   'drive',
#   'youre',
#   'redneck',
#   'heartbreak',
#   'whos',
#   'really',
#   'bad',
#   'lying',
#   'watch',
#   'strike',
#   'match',
#   'wasted',
#   'time',
#   'far',
#   'im',
#   'concerned',
#   'youre',
#   'another',
#   'picture',
#   'burn',
#   'theres',
#   'time',
#   'tears',
#   'im',
#   'sitting',
#   'planning',
#   'revenge',
#   'theres',
#   'nothing',
#   'stopping',
#   'going',
#   'best',
#   'friends',
#   'come',
#   'around',
#   'saying',
#   'sorry',
#   'daddys',
#   'gonna',
#   'show',
#   'sorry',
#   'youll',
#   'cause',
#   'hate',
#   'stupid',
#   'old',
#   'pickup',
#   'truck',
#   'never',
#   'let',
#   'drive',
#   'youre',
#   'redneck',
#   'heartbreak',
#   'whos',
#   'really',
# ...
#   'would',
#   'bad',
#   'health',
#   'cause',
#   'hate',
#   'stupid',
#   'old',
#   'pickup',
#   'truck',
#   'never',
#   'let',
#   'drive',
#   'youre',
#   'redneck',
#   'heartbreak',
#   'whos',
#   'really',
#   'bad',
#   'lying',
#   'watch',
#   'strike',
#   'match',
#   'wasted',
#   'time',
#   'case',
#   'havent',
#   'heard',
#   'really',
#   'really',
#   'hate',
#   'stupid',
#   'old',
#   'pickup',
#   'truck',
#   'never',
#   'let',
#   'drive',
#   'youre',
#   'redneck',
#   'heartbreak',
#   'whos',
#   'really',
#   'bad',
#   'lying',
#   'watch',
#   'strike',
#   'match',
#   'wasted',
#   'time',
#   'far',
#   'im',
#   'concerned',
#   'youre',
#   'another',
#   'picture',
#   'burn',
#   'burn',
#   'burn',
#   'burn',
#   'baby',
#   'burn',
#   'youre',
#   'another',
#   'picture',
#   'burn',
#   'baby',
#   'burn',
#   ''],
#  ('taylorswift', 'santababy'): ['santa',
#   'baby',
#   'santa',
#   'baby',
#   'slip',
#   'sable',
#   'tree',
#   'ive',
#   'awful',
#   'good',
#   'girl',
#   'santa',
#   'baby',
#   'hurry',
#   'chimney',
#   'tonight',
#   'santa',
#   'baby',
#   '54',
#   'convertible',
#   'light',
#   'blue',
#   'well',
#   'ill',
#   'wait',
#   'dear',
#   'santa',
#   'baby',
#   'hurry',
#   'chimney',
#   'tonight',
#   'yeah',
#   'think',
#   'fun',
#   'ive',
#   'missed',
#   'think',
#   'boys',
#   'havent',
#   'kissed',
#   'next',
#   'year',
#   'could',
#   'good',
#   'check',
#   'christmas',
#   'list',
#   'santa',
#   'baby',
#   'want',
#   'yacht',
#   'really',
#   'thats',
#   'lot',
#   'ive',
#   'angel',
#   'year',
#   'santa',
#   'baby',
#   'hurry',
#   'chimney',
#   'tonight',
#   'santa',
#   'honey',
#   'theres',
#   'one',
#   'thing',
#   'really',
#   'need',
#   'deed',
#   'platinum',
#   'mine',
#   'santa',
#   'honey',
#   'hurry',
#   'chimney',
#   'tonight',
#   'come',
#   'trim',
#   'christmas',
#   'tree',
#   'decorations',
#   'bought',
#   'tiffanys',
#   'really',
#   'believe',
#   'lets',
#   'see',
#   'believe',
#   'santa',
#   'baby',
#   'forgot',
#   'mention',
#   'one',
#   'little',
#   'thing',
#   'ring',
#   'dont',
#   'mean',
#   'phone',
#   'santa',
#   'baby',
#   'hurry',
#   'chimney',
#   'tonight',
#   ''],
#  ('taylorswift', 'shouldvesaidno'): ['shouldve',
#   'said',
#   'strange',
#   'think',
#   'songs',
#   'used',
#   'sing',
#   'smiles',
#   'flowers',
#   'everything',
#   'gone',
#   'yesterday',
#   'found',
#   'even',
#   'looking',
#   'feels',
#   'wrong',
#   'say',
#   'youd',
#   'take',
#   'back',
#   'given',
#   'one',
#   'chance',
#   'moment',
#   'weakness',
#   'said',
#   'yes',
#   'shouldve',
#   'said',
#   'shouldve',
#   'gone',
#   'home',
#   'shouldve',
#   'thought',
#   'twice',
#   'fore',
#   'let',
#   'go',
#   'shouldve',
#   'known',
#   'word',
#   'bout',
#   'herd',
#   'get',
#   'back',
#   'get',
#   'back',
#   'shouldve',
#   'back',
#   'mind',
#   'shouldnt',
#   'asking',
#   'shouldnt',
#   'begging',
#   'forgiveness',
#   'feet',
#   'shouldve',
#   'said',
#   'baby',
#   'might',
#   'still',
#   'see',
#   'ive',
#   'crying',
#   'baby',
#   'know',
#   'right',
#   'things',
#   'say',
#   'honestly',
#   'expect',
#   'believe',
#   'could',
#   'ever',
#   'say',
#   'past',
#   'past',
#   'need',
#   'one',
#   'chance',
#   'moment',
#   'weakness',
#   'said',
#   'yes',
#   'shouldve',
#   'said',
#   'shouldve',
#   'gone',
#   'home',
#   'shouldve',
#   'thought',
#   'twice',
#   'fore',
#   'let',
#   'go',
#   'shouldve',
#   'known',
#   'word',
#   'bout',
#   'herd',
#   'get',
#   'back',
#   'get',
#   'back',
#   'shouldve',
#   'back',
#   'mind',
#   'shouldnt',
#   'asking',
#   'shouldnt',
#   'begging',
#   'forgiveness',
#   'feet',
#   'shouldve',
#   'said',
#   'baby',
#   'might',
#   'still',
#   'cant',
#   'resist',
#   'go',
#   'tell',
#   'worth',
#   'worth',
#   'shouldve',
#   'said',
#   'shouldve',
#   'gone',
#   'home',
#   'shouldve',
#   'thought',
#   'twice',
#   'fore',
#   'let',
#   'go',
#   'shouldve',
#   'known',
#   'word',
#   'bout',
#   'herd',
#   'get',
#   'back',
#   'get',
#   'back',
#   'shouldve',
#   'back',
#   'mind',
#   'shouldnt',
#   'asking',
#   'shouldnt',
#   'begging',
#   'forgiveness',
#   'feet',
#   'shouldve',
#   'said',
#   'baby',
#   'might',
#   'still',
#   ''],
#  ('taylorswift', 'silentnight'): ['silent',
#   'night',
#   'silent',
#   'night',
#   'holy',
#   'night',
#   'calm',
#   'bright',
#   'round',
#   'yon',
#   'virgin',
#   'mother',
#   'child',
#   'holy',
#   'infant',
#   'tender',
#   'mild',
#   'sleep',
#   'heavenly',
#   'peace',
#   'sleep',
#   'heavenly',
#   'peace',
#   'silent',
#   'night',
#   'holy',
#   'night',
#   'shepherds',
#   'quake',
#   'sight',
#   'glories',
#   'stream',
#   'heaven',
#   'afar',
#   'heavenly',
#   'hosts',
#   'sing',
#   'hallelujah',
#   'christ',
#   'saviour',
#   'born',
#   'christ',
#   'saviour',
#   'born',
#   'silent',
#   'night',
#   'holy',
#   'night',
#   'son',
#   'god',
#   'loves',
#   'pure',
#   'light',
#   'radiant',
#   'beams',
#   'thy',
#   'holy',
#   'face',
#   'dawn',
#   'redeeming',
#   'grace',
#   'jesus',
#   'lord',
#   'thy',
#   'birth',
#   'jesus',
#   'lord',
#   'thy',
#   'birth',
#   'hallelujah',
#   'hallelujah',
#   'hallelujah',
#   'christ',
#   'saviour',
#   'born',
#   ''],
#  ('taylorswift', 'staybeautiful'): ['stay',
#   'beautiful',
#   'corys',
#   'eyes',
#   'like',
#   'jungle',
#   'smiles',
#   'like',
#   'radio',
#   'whispers',
#   'songs',
#   'window',
#   'words',
#   'nobody',
#   'knows',
#   'theres',
#   'pretty',
#   'girls',
#   'every',
#   'corner',
#   'watch',
#   'hes',
#   'walking',
#   'home',
#   'saying',
#   'know',
#   'ever',
#   'know',
#   'youre',
#   'beautiful',
#   'every',
#   'little',
#   'piece',
#   'love',
#   'dont',
#   'know',
#   'youre',
#   'really',
#   'gonna',
#   'someone',
#   'ask',
#   'anyone',
#   'find',
#   'everything',
#   'looked',
#   'hope',
#   'life',
#   'leads',
#   'back',
#   'door',
#   'oh',
#   'dont',
#   'stay',
#   'beautiful',
#   'cory',
#   'finds',
#   'another',
#   'way',
#   'highlight',
#   'day',
#   'im',
#   'taking',
#   'pictures',
#   'mind',
#   'save',
#   'rainy',
#   'day',
#   'hard',
#   'make',
#   'conversation',
#   'hes',
#   'taking',
#   'breath',
#   'away',
#   'say',
#   'hey',
#   'way',
#   'youre',
#   'beautiful',
#   'every',
#   'little',
#   'piece',
#   'love',
#   'dont',
#   'know',
#   'youre',
#   'really',
#   'gonna',
#   'someone',
#   'ask',
#   'anyone',
#   'find',
#   'everything',
#   'looked',
#   'hope',
#   'life',
#   'leads',
#   'back',
#   'door',
#   'oh',
#   'dont',
#   'stay',
#   'beautiful',
#   'story',
#   'never',
#   'gets',
#   'told',
#   'daydream',
#   'ill',
#   'never',
#   'get',
#   'hold',
#   'least',
#   'youll',
#   'know',
#   'youre',
#   'beautiful',
#   'every',
#   'little',
#   'piece',
#   'love',
#   'dont',
#   'know',
#   'youre',
#   'really',
#   'gonna',
#   'someone',
#   'ask',
#   'anyone',
#   'find',
#   'everything',
#   'looked',
#   'hope',
#   'life',
#   'leads',
#   'back',
#   'front',
#   'door',
#   'oh',
#   'dont',
#   'stay',
#   'beautiful',
#   'beautiful',
#   'beautiful',
#   'beautiful',
#   'beautiful',
#   'beautiful',
#   'la',
#   'la',
#   'la',
#   'oh',
#   'oh',
#   'oh',
#   'oh',
#   'oh',
#   'dont',
#   'stay',
#   'beautiful',
#   'stay',
#   'beautiful',
#   'na',
#   'na',
#   'na',
#   'na',
#   'na',
#   ''],
#  ('taylorswift', 'teardropsonmyguitar'): ['teardrops',
#   'guitar',
#   'drew',
#   'looks',
#   'fake',
#   'smile',
#   'wont',
#   'see',
#   'want',
#   'im',
#   'needing',
#   'everything',
#   'ill',
#   'bet',
#   'shes',
#   'beautiful',
#   'girl',
#   'talks',
#   'shes',
#   'got',
#   'everything',
#   'live',
#   'without',
#   'drew',
#   'talks',
#   'laugh',
#   'cause',
#   'funny',
#   'cant',
#   'even',
#   'see',
#   'anyone',
#   'hes',
#   'says',
#   'hes',
#   'love',
#   'hes',
#   'finally',
#   'got',
#   'right',
#   'wonder',
#   'knows',
#   'hes',
#   'think',
#   'night',
#   'hes',
#   'reason',
#   'teardrops',
#   'guitar',
#   'thing',
#   'keeps',
#   'wishing',
#   'wishing',
#   'star',
#   'hes',
#   'song',
#   'car',
#   'keep',
#   'singing',
#   'dont',
#   'know',
#   'drew',
#   'walks',
#   'tell',
#   'cant',
#   'breathe',
#   'goes',
#   'perfectly',
#   'kind',
#   'flawless',
#   'wish',
#   'could',
#   'shed',
#   'better',
#   'hold',
#   'tight',
#   'give',
#   'love',
#   'look',
#   'beautiful',
#   'eyes',
#   'know',
#   'shes',
#   'lucky',
#   'cause',
#   'hes',
#   'reason',
#   'teardrops',
#   'guitar',
#   'thing',
#   'keeps',
#   'wishing',
#   'wishing',
#   'star',
#   'hes',
#   'song',
#   'car',
#   'keep',
#   'singing',
#   'dont',
#   'know',
#   'drive',
#   'home',
#   'alone',
#   'turn',
#   'light',
#   'ill',
#   'put',
#   'picture',
#   'maybe',
#   'get',
#   'sleep',
#   'tonight',
#   'cause',
#   'hes',
#   'reason',
#   'teardrops',
#   'guitar',
#   'one',
#   'whos',
#   'got',
#   'enough',
#   'break',
#   'heart',
#   'hes',
#   'song',
#   'car',
#   'keep',
#   'singing',
#   'dont',
#   'know',
#   'hes',
#   'time',
#   'taken',
#   'theres',
#   'never',
#   'enough',
#   'hes',
#   'need',
#   'fall',
#   'drew',
#   'looks',
#   'fake',
#   'smile',
#   'wont',
#   'see',
#   ''],
#  ('taylorswift', 'theoutside'): ['outside',
#   'didnt',
#   'know',
#   'would',
#   'find',
#   'went',
#   'looking',
#   'reason',
#   'know',
#   'didnt',
#   'read',
#   'lines',
#   'baby',
#   'ive',
#   'got',
#   'nowhere',
#   'go',
#   'tried',
#   'take',
#   'road',
#   'less',
#   'traveled',
#   'nothing',
#   'seems',
#   'work',
#   'first',
#   'times',
#   'right',
#   'ever',
#   'try',
#   'better',
#   'nobody',
#   'ever',
#   'lets',
#   'still',
#   'see',
#   'aint',
#   'best',
#   'view',
#   'outside',
#   'looking',
#   'ive',
#   'lot',
#   'lonely',
#   'places',
#   'ive',
#   'never',
#   'outside',
#   'saw',
#   'never',
#   'knew',
#   'would',
#   'give',
#   'part',
#   'part',
#   'late',
#   'see',
#   'couldve',
#   'helped',
#   'wanted',
#   'one',
#   'notices',
#   'late',
#   'anything',
#   'ever',
#   'try',
#   'better',
#   'nobody',
#   'ever',
#   'lets',
#   'still',
#   'see',
#   'aint',
#   'best',
#   'view',
#   'outside',
#   'looking',
#   'ive',
#   'lot',
#   'lonely',
#   'places',
#   'ive',
#   'never',
#   'outside',
#   'oh',
#   'yeah',
#   'ever',
#   'try',
#   'better',
#   'nobody',
#   'ever',
#   'lets',
#   'still',
#   'see',
#   'aint',
#   'best',
#   'view',
#   'outside',
#   'looking',
#   'ive',
#   'lot',
#   'lonely',
#   'places',
#   'ive',
#   'never',
#   'outside',
#   ''],
#  ('taylorswift', 'tiedtogetherwithasmile'): ['tied',
#   'together',
#   'smile',
#   'seems',
#   'one',
#   'doesnt',
#   'see',
#   'beauty',
#   'face',
#   'mirror',
#   'looking',
#   'back',
#   'walk',
#   'around',
#   'thinking',
#   'youre',
#   'pretty',
#   'thats',
#   'true',
#   'cause',
#   'know',
#   'hold',
#   'baby',
#   'youre',
#   'losing',
#   'waters',
#   'high',
#   'youre',
#   'jumping',
#   'letting',
#   'go',
#   'one',
#   'knows',
#   'cry',
#   'dont',
#   'tell',
#   'anyone',
#   'might',
#   'golden',
#   'one',
#   'youre',
#   'tied',
#   'together',
#   'smile',
#   'youre',
#   'coming',
#   'undone',
#   'guess',
#   'true',
#   'love',
#   'wanted',
#   'cause',
#   'youre',
#   'giving',
#   'away',
#   'like',
#   'extra',
#   'change',
#   'hoping',
#   'end',
#   'pocket',
#   'leaves',
#   'like',
#   'penny',
#   'rain',
#   'oh',
#   'cause',
#   'price',
#   'pay',
#   'price',
#   'pay',
#   'hold',
#   'baby',
#   'youre',
#   'losing',
#   'waters',
#   'high',
#   'youre',
#   'jumping',
#   'letting',
#   'go',
#   'one',
#   'knows',
#   'cry',
#   'dont',
#   'tell',
#   'anyone',
#   'might',
#   'golden',
#   'one',
#   'youre',
#   'tied',
#   'together',
#   'smile',
#   'youre',
#   'coming',
#   'undone',
#   'hold',
#   'baby',
#   'youre',
#   'losing',
#   'waters',
#   'high',
#   'youre',
#   'jumping',
#   'letting',
#   'go',
#   'one',
#   'knows',
#   'cry',
#   'dont',
#   'tell',
#   'anyone',
#   'might',
#   'golden',
#   'one',
#   'youre',
#   'tied',
#   'together',
#   'smile',
#   'youre',
#   'coming',
#   'undone',
#   'youre',
#   'tied',
#   'together',
#   'smile',
#   'youre',
#   'coming',
#   'undone',
#   'goodbye',
#   'baby',
#   'smile',
#   'baby',
#   'baby',
#   ''],
#  ('taylorswift', 'timmcgraw'): ['tim',
#   'mcgraw',
#   'said',
#   'way',
#   'blue',
#   'eyes',
#   'shined',
#   'put',
#   'georgia',
#   'stars',
#   'shame',
#   'night',
#   'said',
#   'thats',
#   'lie',
#   'boy',
#   'chevy',
#   'truck',
#   'tendency',
#   'gettin',
#   'stuck',
#   'back',
#   'roads',
#   'night',
#   'right',
#   'beside',
#   'summer',
#   'long',
#   'time',
#   'woke',
#   'find',
#   'summer',
#   'gone',
#   'think',
#   'tim',
#   'mcgraw',
#   'hope',
#   'think',
#   'favorite',
#   'song',
#   'one',
#   'danced',
#   'night',
#   'long',
#   'moon',
#   'like',
#   'spotlight',
#   'lake',
#   'think',
#   'happiness',
#   'hope',
#   'think',
#   'little',
#   'black',
#   'dress',
#   'think',
#   'head',
#   'chest',
#   'old',
#   'faded',
#   'blue',
#   'jeans',
#   'think',
#   'tim',
#   'mcgraw',
#   'hope',
#   'think',
#   'september',
#   'saw',
#   'month',
#   'tears',
#   'thankin',
#   'god',
#   'werent',
#   'see',
#   'like',
#   'box',
#   'beneath',
#   'bed',
#   'letter',
#   'never',
#   'read',
#   'three',
#   'summers',
#   'back',
#   'hard',
#   'find',
#   'little',
#   'bittersweet',
#   'lookin',
#   'back',
#   'nice',
#   'believe',
#   'think',
#   'tim',
#   'mcgraw',
#   'hope',
#   'think',
#   'favorite',
#   'song',
#   'one',
#   'danced',
#   'night',
#   'long',
#   'moon',
#   'like',
#   'spotlight',
#   'lake',
#   'think',
#   'happiness',
#   'hope',
#   'think',
#   'little',
#   'black',
#   'dress',
#   'think',
#   'head',
#   'chest',
#   'old',
#   'faded',
#   'blue',
#   'jeans',
#   'think',
#   'tim',
#   'mcgraw',
#   'hope',
#   'think',
#   'im',
#   'back',
#   'first',
#   'time',
#   'since',
#   'im',
#   'standin',
#   'street',
#   'theres',
#   'letter',
#   'left',
#   'doorstep',
#   'first',
#   'thing',
#   'youll',
#   'read',
#   'think',
#   'tim',
#   'mcgraw',
#   'hope',
#   'think',
#   'favorite',
#   'song',
#   'someday',
#   'youll',
#   'turn',
#   'radio',
#   'hope',
#   'takes',
#   'back',
#   'place',
#   'think',
#   'happiness',
#   'hope',
#   'think',
#   'little',
#   'black',
#   'dress',
#   'think',
#   'head',
#   'chest',
#   'old',
#   'faded',
#   'blue',
#   'jeans',
#   'think',
#   'tim',
#   'mcgraw',
#   'hope',
#   'think',
#   'oh',
#   'think',
#   'mmmm',
#   'said',
#   'way',
#   'blue',
#   'eyes',
#   'shined',
#   'put',
#   'georgia',
#   'stars',
#   'shame',
#   'night',
#   'said',
#   'thats',
#   'lie',
#   ''],
#  ('taylorswift', 'untouchable'): ['untouchable',
#   'untouchable',
#   'like',
#   'distant',
#   'diamond',
#   'sky',
#   'im',
#   'reaching',
#   'cant',
#   'tell',
#   'im',
#   'caught',
#   'im',
#   'caught',
#   'untouchable',
#   'burning',
#   'brighter',
#   'sun',
#   'youre',
#   'close',
#   'feel',
#   'like',
#   'coming',
#   'undone',
#   'middle',
#   'night',
#   'im',
#   'dream',
#   'like',
#   'million',
#   'little',
#   'stars',
#   'spelling',
#   'name',
#   'gotta',
#   'come',
#   'come',
#   'say',
#   'well',
#   'together',
#   'come',
#   'come',
#   'little',
#   'taste',
#   'heaven',
#   'half',
#   'full',
#   'wont',
#   'wait',
#   'day',
#   'know',
#   'youre',
#   'saying',
#   'youd',
#   'anyway',
#   'youre',
#   'untouchable',
#   'burning',
#   'brighter',
#   'sun',
#   'youre',
#   'close',
#   'feel',
#   'like',
#   'coming',
#   'undone',
#   'middle',
#   'night',
#   'im',
#   'dream',
#   'like',
#   'million',
#   'little',
#   'stars',
#   'spelling',
#   'name',
#   'gotta',
#   'come',
#   'come',
#   'say',
#   'well',
#   'together',
#   'come',
#   'come',
#   'oh',
#   'middle',
#   'night',
#   'waking',
#   'dream',
#   'wanna',
#   'feel',
#   'side',
#   'standing',
#   'next',
#   'gotta',
#   'come',
#   'come',
#   'say',
#   'well',
#   'together',
#   'come',
#   'come',
#   'little',
#   'taste',
#   'heaven',
#   'im',
#   'caught',
#   'oh',
#   'oh',
#   'youre',
#   'untouchable',
#   'burning',
#   'brighter',
#   'sun',
#   'youre',
#   'close',
#   'feel',
#   'like',
#   'coming',
#   'undone',
#   'middle',
#   'night',
#   'im',
#   'dream',
#   'like',
#   'million',
#   'little',
#   'stars',
#   'spelling',
#   'name',
#   'gotta',
#   'come',
#   'come',
#   'say',
#   'well',
#   'together',
#   'come',
#   'come',
#   'oh',
#   'oh',
#   'middle',
#   'night',
#   'im',
#   'dream',
#   'like',
#   'million',
#   'little',
#   'stars',
#   'spelling',
#   'name',
#   'gotta',
#   'come',
#   'come',
#   'say',
#   'well',
#   'together',
#   'come',
#   'come',
#   'come',
#   'middle',
#   'night',
#   'waking',
#   'dream',
#   'wanna',
#   'feel',
#   'side',
#   'standing',
#   'next',
#   'gotta',
#   'come',
#   'come',
#   'say',
#   'well',
#   'together',
#   'come',
#   'come',
#   'little',
#   'taste',
#   'heaven',
#   'middle',
#   'night',
#   'im',
#   'dream',
#   'like',
#   'million',
#   'little',
#   'stars',
#   'spelling',
#   'name',
#   'gotta',
#   'come',
#   'come',
#   'come',
#   'come',
#   'come',
#   'come',
#   'oh',
#   'oh',
#   'oh',
#   'like',
#   'million',
#   'little',
#   'stars',
#   'spelling',
#   'name',
#   'theyre',
#   'spelling',
#   'name',
#   'oh',
#   ''],
#  ('taylorswift', 'whitechristmas'): ['white',
#   'christmas',
#   'im',
#   'dreaming',
#   'white',
#   'christmas',
#   'like',
#   'ones',
#   'used',
#   'know',
#   'tree',
#   'tops',
#   'glisten',
#   'children',
#   'listen',
#   'hear',
#   'sleigh',
#   'bells',
#   'snow',
#   'im',
#   'dreaming',
#   'white',
#   'christmas',
#   'every',
#   'christmas',
#   'card',
#   'write',
#   'may',
#   'days',
#   'merry',
#   'bright',
#   'may',
#   'christmases',
#   'white',
#   'im',
#   'dreaming',
#   'white',
#   'christmas',
#   'like',
#   'ones',
#   'used',
#   'know',
#   'may',
#   'days',
#   'merry',
#   'bright',
#   'may',
#   'christmases',
#   'white',
#   'may',
#   'days',
#   'merry',
#   'bright',
#   'may',
#   'christmases',
#   'white',
#   '']}
